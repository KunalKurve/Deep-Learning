# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Tensorflow

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import sys
sys.path.insert(0, r'G:\My Drive\DNN')
from collections.abc import Callable
from typing import Literal

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import tensorflow as tf

from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print (fn_plot_tf_hist.__doc__)
# Out:
#     Args:
#         hist_df: a dataframe with following ccolumns
#             column 0: loss
#             column 1: accuracy
#             column 2: val_loss
#             column 3: val_accuracy
#             While plotting columns are accessed by index
#             so that even if the column names are different it will not throw exceptions.

# %%
print (fn_plot_confusion_matrix.__doc__)
# Out:
#     Args:
#         y_true: Ground Truth
#         y_pred : Predictions
#         labels : dictonary
#                   {0: 'Goal Keeper',
#                   1: 'Defender',
#                   2: 'Mid-Fielder',
#                   3: 'Forward'}

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../input'
outDir = '../output'
modelDir = './models'
subDir = 'fifa_2019'
logDir = './logs'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 1001 # number of epochs
BATCH_SIZE = 32
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2
REG_LAMBDA = 0.001

PATIENCE = 20 # EarlyStopping -> If n no. of epochs give similar o/p, then it will stop the execution
LR_PATIENCE = 10
LR_FACTOR = 0.1

# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'medium',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Basic Hygiene

# %%
# Check if all directories are present
if not os.path.exists(os.path.join(outDir)):
    os.makedirs(os.path.join(outDir))
    print ('Created {} directory'.format(outDir))

if not os.path.exists(os.path.join(modelDir, subDir)):
    os.makedirs(os.path.join(modelDir, subDir))
    print ('Created {} directory'.format(os.path.join(modelDir, subDir)))

# %% [markdown]
# ## Read FIFA 2019 data set

# %%
data_df = pd.read_csv(os.path.join(inpDir, 'fifa_2019.csv'))
data_df.shape
# Out:
# (18207, 89)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
#  13  Special                   18207 non-null  int64
#  14  Preferred Foot            18159 non-null  object
#  15  International Reputation  18159 non-null  float64
#  16  Weak Foot                 18159 non-null  float64
#  17  Skill Moves               18159 non-null  float64
#  18  Work Rate                 18159 non-null  object
#  19  Body Type                 18159 non-null  object
#  20  Real Face                 18159 non-null  object
#  21  Position                  18147 non-null  object
#  22  Jersey Number             18147 non-null  float64
#  23  Joined                    16654 non-null  object
#  24  Loaned From               1264 non-null   object
#  25  Contract Valid Until      17918 non-null  object
#  26  Height                    18159 non-null  object
#  27  Weight                    18159 non-null  object
#  28  LS                        16122 non-null  object
#  29  ST                        16122 non-null  object
#  30  RS                        16122 non-null  object
#  31  LW                        16122 non-null  object
#  32  LF                        16122 non-null  object
#  33  CF                        16122 non-null  object
#  34  RF                        16122 non-null  object
#  35  RW                        16122 non-null  object
#  36  LAM                       16122 non-null  object
#  37  CAM                       16122 non-null  object
#  38  RAM                       16122 non-null  object
#  39  LM                        16122 non-null  object
#  40  LCM                       16122 non-null  object
#  41  CM                        16122 non-null  object
#  42  RCM                       16122 non-null  object
#  43  RM                        16122 non-null  object
#  44  LWB                       16122 non-null  object
#  45  LDM                       16122 non-null  object
#  46  CDM                       16122 non-null  object
#  47  RDM                       16122 non-null  object
#  48  RWB                       16122 non-null  object
#  49  LB                        16122 non-null  object
#  50  LCB                       16122 non-null  object
#  51  CB                        16122 non-null  object
#  52  RCB                       16122 non-null  object
#  53  RB                        16122 non-null  object
#  54  Crossing                  18159 non-null  float64
#  55  Finishing                 18159 non-null  float64
#  56  HeadingAccuracy           18159 non-null  float64
#  57  ShortPassing              18159 non-null  float64
#  58  Volleys                   18159 non-null  float64
#  59  Dribbling                 18159 non-null  float64
#  60  Curve                     18159 non-null  float64
#  61  FKAccuracy                18159 non-null  float64
#  62  LongPassing               18159 non-null  float64
#  63  BallControl               18159 non-null  float64
#  64  Acceleration              18159 non-null  float64
#  65  SprintSpeed               18159 non-null  float64
#  66  Agility                   18159 non-null  float64
#  67  Reactions                 18159 non-null  float64
#  68  Balance                   18159 non-null  float64
#  69  ShotPower                 18159 non-null  float64
#  70  Jumping                   18159 non-null  float64
#  71  Stamina                   18159 non-null  float64
#  72  Strength                  18159 non-null  float64
#  73  LongShots                 18159 non-null  float64
#  74  Aggression                18159 non-null  float64
#  75  Interceptions             18159 non-null  float64
#  76  Positioning               18159 non-null  float64
#  77  Vision                    18159 non-null  float64
#  78  Penalties                 18159 non-null  float64
#  79  Composure                 18159 non-null  float64
#  80  Marking                   18159 non-null  float64
#  81  StandingTackle            18159 non-null  float64
#  82  SlidingTackle             18159 non-null  float64
#  83  GKDiving                  18159 non-null  float64
#  84  GKHandling                18159 non-null  float64
#  85  GKKicking                 18159 non-null  float64
#  86  GKPositioning             18159 non-null  float64
#  87  GKReflexes                18159 non-null  float64
#  88  Release Clause            16643 non-null  object
# dtypes: float64(38), int64(6), object(45)
# memory usage: 12.4+ MB

# %%
data_df.describe().T
# Out:
#                             count           mean           std    min  \
# Unnamed: 0                18207.0    9103.000000   5256.052511    0.0
# ID                        18207.0  214298.338606  29965.244204   16.0
# Age                       18207.0      25.122206      4.669943   16.0
# Overall                   18207.0      66.238699      6.908930   46.0
# Potential                 18207.0      71.307299      6.136496   48.0
# Special                   18207.0    1597.809908    272.586016  731.0
# International Reputation  18159.0       1.113222      0.394031    1.0
# Weak Foot                 18159.0       2.947299      0.660456    1.0
# Skill Moves               18159.0       2.361308      0.756164    1.0
# Jersey Number             18147.0      19.546096     15.947765    1.0
# Crossing                  18159.0      49.734181     18.364524    5.0
# Finishing                 18159.0      45.550911     19.525820    2.0
# HeadingAccuracy           18159.0      52.298144     17.379909    4.0
# ShortPassing              18159.0      58.686712     14.699495    7.0
# Volleys                   18159.0      42.909026     17.694408    4.0
# Dribbling                 18159.0      55.371001     18.910371    4.0
# Curve                     18159.0      47.170824     18.395264    6.0
# FKAccuracy                18159.0      42.863153     17.478763    3.0
# LongPassing               18159.0      52.711933     15.327870    9.0
# BallControl               18159.0      58.369459     16.686595    5.0
# Acceleration              18159.0      64.614076     14.927780   12.0
# SprintSpeed               18159.0      64.726967     14.649953   12.0
# Agility                   18159.0      63.503607     14.766049   14.0
# Reactions                 18159.0      61.836610      9.010464   21.0
# Balance                   18159.0      63.966573     14.136166   16.0
# ShotPower                 18159.0      55.460047     17.237958    2.0
# Jumping                   18159.0      65.089432     11.820044   15.0
# Stamina                   18159.0      63.219946     15.894741   12.0
# Strength                  18159.0      65.311967     12.557000   17.0
# LongShots                 18159.0      47.109973     19.260524    3.0
# Aggression                18159.0      55.868991     17.367967   11.0
# Interceptions             18159.0      46.698276     20.696909    3.0
# Positioning               18159.0      49.958478     19.529036    2.0
# Vision                    18159.0      53.400903     14.146881   10.0
# Penalties                 18159.0      48.548598     15.704053    5.0
# Composure                 18159.0      58.648274     11.436133    3.0
# Marking                   18159.0      47.281623     19.904397    3.0
# StandingTackle            18159.0      47.697836     21.664004    2.0
# SlidingTackle             18159.0      45.661435     21.289135    3.0
# GKDiving                  18159.0      16.616223     17.695349    1.0
# GKHandling                18159.0      16.391596     16.906900    1.0
# GKKicking                 18159.0      16.232061     16.502864    1.0
# GKPositioning             18159.0      16.388898     17.034669    1.0
# GKReflexes                18159.0      16.710887     17.955119    1.0
#
#                                25%       50%       75%       max
# Unnamed: 0                  4551.5    9103.0   13654.5   18206.0
# ID                        200315.5  221759.0  236529.5  246620.0
# Age                           21.0      25.0      28.0      45.0
# Overall                       62.0      66.0      71.0      94.0
# Potential                     67.0      71.0      75.0      95.0
# Special                     1457.0    1635.0    1787.0    2346.0
# International Reputation       1.0       1.0       1.0       5.0
# Weak Foot                      3.0       3.0       3.0       5.0
# Skill Moves                    2.0       2.0       3.0       5.0
# Jersey Number                  8.0      17.0      26.0      99.0
# Crossing                      38.0      54.0      64.0      93.0
# Finishing                     30.0      49.0      62.0      95.0
# HeadingAccuracy               44.0      56.0      64.0      94.0
# ShortPassing                  54.0      62.0      68.0      93.0
# Volleys                       30.0      44.0      57.0      90.0
# Dribbling                     49.0      61.0      68.0      97.0
# Curve                         34.0      48.0      62.0      94.0
# FKAccuracy                    31.0      41.0      57.0      94.0
# LongPassing                   43.0      56.0      64.0      93.0
# BallControl                   54.0      63.0      69.0      96.0
# Acceleration                  57.0      67.0      75.0      97.0
# SprintSpeed                   57.0      67.0      75.0      96.0
# Agility                       55.0      66.0      74.0      96.0
# Reactions                     56.0      62.0      68.0      96.0
# Balance                       56.0      66.0      74.0      96.0
# ShotPower                     45.0      59.0      68.0      95.0
# Jumping                       58.0      66.0      73.0      95.0
# Stamina                       56.0      66.0      74.0      96.0
# Strength                      58.0      67.0      74.0      97.0
# LongShots                     33.0      51.0      62.0      94.0
# Aggression                    44.0      59.0      69.0      95.0
# Interceptions                 26.0      52.0      64.0      92.0
# Positioning                   38.0      55.0      64.0      95.0
# Vision                        44.0      55.0      64.0      94.0
# Penalties                     39.0      49.0      60.0      92.0
# Composure                     51.0      60.0      67.0      96.0
# Marking                       30.0      53.0      64.0      94.0
# StandingTackle                27.0      55.0      66.0      93.0
# SlidingTackle                 24.0      52.0      64.0      91.0
# GKDiving                       8.0      11.0      14.0      90.0
# GKHandling                     8.0      11.0      14.0      92.0
# GKKicking                      8.0      11.0      14.0      91.0
# GKPositioning                  8.0      11.0      14.0      90.0
# GKReflexes                     8.0      11.0      14.0      94.0

# %%
data_df.isna().sum().sum()
# Out:
# 76984

# %%
# removing rows with position = null
data_df = data_df[data_df["Position"].notnull()]
data_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
data_df[data_df['Name']=="S. Chhetri"]
# Out:
#       Unnamed: 0      ID        Name  Age  \
# 8605        8605  190939  S. Chhetri   33
#
#                                                Photo Nationality  \
# 8605  https://cdn.sofifa.org/players/4/19/190939.png       India
#
#                                       Flag  Overall  Potential Club  ...  \
# 8605  https://cdn.sofifa.org/flags/159.png       67         67  NaN  ...
#
#      Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 8605      67.0    30.0           24.0           44.0     10.0         7.0
#
#       GKKicking  GKPositioning GKReflexes Release Clause
# 8605       11.0            9.0       10.0            NaN
#
# [1 rows x 89 columns]

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ["Position", 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
#Assign labels to goalkeepers
data_df.loc[data_df["Position"] == "GK", "Position"] = 0

#Defenders
data_df.loc[data_df["Position"].isin(defender), "Position"] = 1

#Midfielders
data_df.loc[data_df["Position"].isin(midfielder), "Position"] = 2

#Forward
data_df.loc[data_df["Position"].isin(forward), "Position"] = 3

# Convert Column "Position" to numeric so that Pandas does not complain
data_df['Position'] = pd.to_numeric(data_df['Position'], downcast="integer")

# %%
data_df = data_df[rel_cols]
data_df.head()
# Out:
#    Position  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0         3       95.0             70.0          90.0     86.0       97.0
# 1         3       94.0             89.0          81.0     87.0       88.0
# 2         3       87.0             62.0          84.0     84.0       96.0
# 3         0       13.0             21.0          50.0     13.0       18.0
# 4         2       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0   93.0        94.0         87.0         96.0  ...       75.0       96.0
# 1   81.0        76.0         77.0         94.0  ...       85.0       95.0
# 2   88.0        87.0         78.0         95.0  ...       81.0       94.0
# 3   21.0        19.0         51.0         42.0  ...       40.0       68.0
# 4   85.0        83.0         91.0         91.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 34 columns]

# %%
labels = {0: 'Goal Keeper', 1: 'Defender', 2: 'Mid-Fielder', 3: 'Forward'}

# %%
features_df = data_df.drop('Position', axis=1)
labels_df = data_df['Position'].to_numpy()

# %%
features_df.shape
# Out:
# (18147, 33)

# %%
# splitting in train ans test datasets
X_train, X_test, y_train, y_test = train_test_split(features_df,
                                     labels_df,
                                     stratify=labels_df,
                                     test_size=TEST_SIZE, 
                                     random_state=RANDOM_STATE)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14517, 33), (3630, 33), (14517,), (3630,))

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
type(X_train), type(X_test), type(y_train), type(y_test)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
# 33, 23, 12, 4, 4

# %% [markdown]
# Callbacks

# %%
checkpoint_path = os.path.join(modelDir, subDir, 'weights_tf_fifa')

model_ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    monitor='val_loss',
    verbose=2,
    save_best_only=True,
    save_weights_only=True,
    mode='auto' # how to track the monitoring -> auto = autoset; 
)

es_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    # min_delta=0, It defines for how many decimal places we want to be considered the monitor value
    patience=PATIENCE,
    verbose=2,
    mode='auto',
    restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=LR_FACTOR,
    patience=LR_PATIENCE,
    verbose=2,
    mode='auto',
    min_lr=0.00001
)


log_dir = os.path.join(logDir, 'fit')
tb_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq =1)

# %% [markdown]
# TensorBoard: Used to give graphic information

# %%
# L2
k_init = tf.keras.initializers.GlorotUniform(
    seed=RANDOM_STATE
)
k_reg = None

###-----------
# Drop Our Rates
###-----------
dor1 = 0.33
dor2 = 0.23
dor3 = 0.13
dor4 = 0.03

model = tf.keras.Sequential([
    ###-----------
    # Input Layer
    ###-----------
    tf.keras.layers.InputLayer(input_shape = (33,)),

    ###-----------
    # Set 1
    ###-----------
    tf.keras.layers.Dense(33, 
                        #   activation = 'relu',
                           kernel_initializer = k_init,
                           kernel_regularizer = k_reg), 
    tf.keras.layers.BatchNormalization(), # Batch Normalization
    tf.keras.layers.ReLU(), 
    # tf.keras.layers.Dropout(dor1),

    ###-----------
    # Set 2
    ###-----------
    tf.keras.layers.Dense(23, 
                        #   activation = 'relu', 
                          kernel_initializer = k_init,
                           kernel_regularizer = k_reg),
    tf.keras.layers.BatchNormalization(), # Batch Normalization
    tf.keras.layers.ReLU(), 

    # tf.keras.layers.Dropout(dor2),

    ###-----------
    # Set 3
    ###-----------
    tf.keras.layers.Dense(12, activation = 'relu', 
                          kernel_initializer = k_init,
                           kernel_regularizer = k_reg),
    tf.keras.layers.BatchNormalization(), # Batch Normalization
    tf.keras.layers.ReLU(), 

    # tf.keras.layers.Dropout(dor3),

    ###-----------
    # Set 4
    ###-----------
    tf.keras.layers.Dense(4, activation = 'relu', kernel_initializer = k_init,
                           kernel_regularizer = k_reg),

    tf.keras.layers.BatchNormalization(), # Batch Normalization
    tf.keras.layers.ReLU(), 

    # tf.keras.layers.Dropout(dor4),

    tf.keras.layers.Dense(4)
    ])
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits= True)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)

# %%
model.compile(optimizer= optimizer, loss=loss_fn, metrics= ['accuracy'])

history = model.fit(X_train, y_train, 
                    validation_data= (X_test, y_test),
                    batch_size= BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks = [model_ckpt_callback, 
                                 es_callback, 
                                 lr_callback, 
                                 tb_callback],
                    verbose= 2)
# Out:
# Epoch 1/1001
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#
# Epoch 1: val_loss improved from inf to 0.60474, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 6s - loss: 0.8888 - accuracy: 0.7722 - val_loss: 0.6047 - val_accuracy: 0.8391 - lr: 0.0010 - 6s/epoch - 13ms/step
# Epoch 2/1001
#
# Epoch 2: val_loss improved from 0.60474 to 0.46153, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.5626 - accuracy: 0.8408 - val_loss: 0.4615 - val_accuracy: 0.8587 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 3/1001
#
# Epoch 3: val_loss improved from 0.46153 to 0.39291, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.4555 - accuracy: 0.8518 - val_loss: 0.3929 - val_accuracy: 0.8625 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 4/1001
#
# Epoch 4: val_loss improved from 0.39291 to 0.35448, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.4087 - accuracy: 0.8536 - val_loss: 0.3545 - val_accuracy: 0.8631 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 5/1001
#
# Epoch 5: val_loss improved from 0.35448 to 0.32463, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 2s - loss: 0.3661 - accuracy: 0.8613 - val_loss: 0.3246 - val_accuracy: 0.8716 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 6/1001
#
# Epoch 6: val_loss improved from 0.32463 to 0.32012, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3516 - accuracy: 0.8601 - val_loss: 0.3201 - val_accuracy: 0.8713 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 7/1001
#
# Epoch 7: val_loss improved from 0.32012 to 0.30918, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3416 - accuracy: 0.8642 - val_loss: 0.3092 - val_accuracy: 0.8722 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 8/1001
#
# Epoch 8: val_loss did not improve from 0.30918
# 454/454 - 2s - loss: 0.3312 - accuracy: 0.8655 - val_loss: 0.3104 - val_accuracy: 0.8672 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 9/1001
#
# Epoch 9: val_loss improved from 0.30918 to 0.30376, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3249 - accuracy: 0.8680 - val_loss: 0.3038 - val_accuracy: 0.8691 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 10/1001
#
# Epoch 10: val_loss improved from 0.30376 to 0.30260, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3235 - accuracy: 0.8683 - val_loss: 0.3026 - val_accuracy: 0.8727 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 11/1001
#
# Epoch 11: val_loss did not improve from 0.30260
# 454/454 - 2s - loss: 0.3182 - accuracy: 0.8703 - val_loss: 0.3056 - val_accuracy: 0.8716 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 12/1001
#
# Epoch 12: val_loss improved from 0.30260 to 0.29974, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3163 - accuracy: 0.8702 - val_loss: 0.2997 - val_accuracy: 0.8736 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 13/1001
#
# Epoch 13: val_loss did not improve from 0.29974
# 454/454 - 2s - loss: 0.3139 - accuracy: 0.8691 - val_loss: 0.3007 - val_accuracy: 0.8725 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 14/1001
#
# Epoch 14: val_loss improved from 0.29974 to 0.29732, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3101 - accuracy: 0.8733 - val_loss: 0.2973 - val_accuracy: 0.8758 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 15/1001
#
# Epoch 15: val_loss did not improve from 0.29732
# 454/454 - 3s - loss: 0.3139 - accuracy: 0.8728 - val_loss: 0.3025 - val_accuracy: 0.8702 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 16/1001
#
# Epoch 16: val_loss improved from 0.29732 to 0.29596, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.3080 - accuracy: 0.8730 - val_loss: 0.2960 - val_accuracy: 0.8738 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 17/1001
#
# Epoch 17: val_loss did not improve from 0.29596
# 454/454 - 2s - loss: 0.3061 - accuracy: 0.8737 - val_loss: 0.2994 - val_accuracy: 0.8744 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 18/1001
#
# Epoch 18: val_loss did not improve from 0.29596
# 454/454 - 3s - loss: 0.3056 - accuracy: 0.8743 - val_loss: 0.3041 - val_accuracy: 0.8672 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 19/1001
#
# Epoch 19: val_loss did not improve from 0.29596
# 454/454 - 3s - loss: 0.3013 - accuracy: 0.8769 - val_loss: 0.2968 - val_accuracy: 0.8755 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 20/1001
#
# Epoch 20: val_loss did not improve from 0.29596
# 454/454 - 2s - loss: 0.3004 - accuracy: 0.8767 - val_loss: 0.3015 - val_accuracy: 0.8705 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 21/1001
#
# Epoch 21: val_loss did not improve from 0.29596
# 454/454 - 2s - loss: 0.3058 - accuracy: 0.8730 - val_loss: 0.2990 - val_accuracy: 0.8727 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 22/1001
#
# Epoch 22: val_loss did not improve from 0.29596
# 454/454 - 2s - loss: 0.3035 - accuracy: 0.8786 - val_loss: 0.2974 - val_accuracy: 0.8749 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 23/1001
#
# Epoch 23: val_loss did not improve from 0.29596
# 454/454 - 2s - loss: 0.3001 - accuracy: 0.8781 - val_loss: 0.2966 - val_accuracy: 0.8771 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 24/1001
#
# Epoch 24: val_loss did not improve from 0.29596
# 454/454 - 2s - loss: 0.3004 - accuracy: 0.8741 - val_loss: 0.2995 - val_accuracy: 0.8752 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 25/1001
#
# Epoch 25: val_loss did not improve from 0.29596
# 454/454 - 3s - loss: 0.2946 - accuracy: 0.8782 - val_loss: 0.2965 - val_accuracy: 0.8730 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 26/1001
#
# Epoch 26: val_loss improved from 0.29596 to 0.29474, saving model to ./models\fifa_2019\weights_tf_fifa
# 454/454 - 3s - loss: 0.2951 - accuracy: 0.8794 - val_loss: 0.2947 - val_accuracy: 0.8777 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 27/1001
#
# Epoch 27: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2968 - accuracy: 0.8786 - val_loss: 0.2975 - val_accuracy: 0.8755 - lr: 0.0010 - 2s/epoch - 6ms/step
# Epoch 28/1001
#
# Epoch 28: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2996 - accuracy: 0.8747 - val_loss: 0.3000 - val_accuracy: 0.8780 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 29/1001
#
# Epoch 29: val_loss did not improve from 0.29474
# 454/454 - 3s - loss: 0.2886 - accuracy: 0.8797 - val_loss: 0.3017 - val_accuracy: 0.8758 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 30/1001
#
# Epoch 30: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2924 - accuracy: 0.8778 - val_loss: 0.3033 - val_accuracy: 0.8744 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 31/1001
#
# Epoch 31: val_loss did not improve from 0.29474
# 454/454 - 3s - loss: 0.2884 - accuracy: 0.8817 - val_loss: 0.3053 - val_accuracy: 0.8741 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 32/1001
#
# Epoch 32: val_loss did not improve from 0.29474
# 454/454 - 3s - loss: 0.2927 - accuracy: 0.8796 - val_loss: 0.3010 - val_accuracy: 0.8755 - lr: 0.0010 - 3s/epoch - 6ms/step
# Epoch 33/1001
#
# Epoch 33: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2909 - accuracy: 0.8774 - val_loss: 0.3026 - val_accuracy: 0.8758 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 34/1001
#
# Epoch 34: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2924 - accuracy: 0.8770 - val_loss: 0.2992 - val_accuracy: 0.8799 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 35/1001
#
# Epoch 35: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2831 - accuracy: 0.8838 - val_loss: 0.3016 - val_accuracy: 0.8758 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 36/1001
#
# Epoch 36: val_loss did not improve from 0.29474
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 454/454 - 2s - loss: 0.2907 - accuracy: 0.8804 - val_loss: 0.3093 - val_accuracy: 0.8736 - lr: 0.0010 - 2s/epoch - 5ms/step
# Epoch 37/1001
#
# Epoch 37: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2845 - accuracy: 0.8813 - val_loss: 0.2989 - val_accuracy: 0.8780 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 38/1001
#
# Epoch 38: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2770 - accuracy: 0.8856 - val_loss: 0.2979 - val_accuracy: 0.8777 - lr: 1.0000e-04 - 2s/epoch - 4ms/step
# Epoch 39/1001
#
# Epoch 39: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2789 - accuracy: 0.8865 - val_loss: 0.2973 - val_accuracy: 0.8802 - lr: 1.0000e-04 - 2s/epoch - 4ms/step
# Epoch 40/1001
#
# Epoch 40: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2794 - accuracy: 0.8832 - val_loss: 0.2976 - val_accuracy: 0.8785 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 41/1001
#
# Epoch 41: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2730 - accuracy: 0.8839 - val_loss: 0.2977 - val_accuracy: 0.8780 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 42/1001
#
# Epoch 42: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2815 - accuracy: 0.8837 - val_loss: 0.2980 - val_accuracy: 0.8785 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 43/1001
#
# Epoch 43: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2766 - accuracy: 0.8853 - val_loss: 0.2986 - val_accuracy: 0.8799 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 44/1001
#
# Epoch 44: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2808 - accuracy: 0.8832 - val_loss: 0.2981 - val_accuracy: 0.8796 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 45/1001
#
# Epoch 45: val_loss did not improve from 0.29474
# 454/454 - 2s - loss: 0.2763 - accuracy: 0.8843 - val_loss: 0.2991 - val_accuracy: 0.8785 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 46/1001
#
# Epoch 46: val_loss did not improve from 0.29474
# Restoring model weights from the end of the best epoch: 26.
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 454/454 - 2s - loss: 0.2731 - accuracy: 0.8869 - val_loss: 0.2991 - val_accuracy: 0.8785 - lr: 1.0000e-04 - 2s/epoch - 5ms/step
# Epoch 46: early stopping

# %%
fn_plot_tf_hist(pd.DataFrame(history.history))

# %%
model.evaluate(X_test, y_test)
# Out:
# 114/114 [==============================] - 0s 3ms/step - loss: 0.2947 - accuracy: 0.8777
# [0.29474326968193054, 0.8776859641075134]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 33)                1122
#
#  batch_normalization (Batch  (None, 33)                132
#  Normalization)
#
#  re_lu (ReLU)                (None, 33)                0
#
#  dense_1 (Dense)             (None, 23)                782
#
#  batch_normalization_1 (Bat  (None, 23)                92
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 23)                0
#
#  dense_2 (Dense)             (None, 12)                288
#
#  batch_normalization_2 (Bat  (None, 12)                48
#  chNormalization)
#
#  re_lu_2 (ReLU)              (None, 12)                0
#
#  dense_3 (Dense)             (None, 4)                 52
#
#  batch_normalization_3 (Bat  (None, 4)                 16
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 4)                 0
#
#  dense_4 (Dense)             (None, 4)                 20
#
# =================================================================
# Total params: 2552 (9.97 KB)
# Trainable params: 2408 (9.41 KB)
# Non-trainable params: 144 (576.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - In BN the fluctuation will be there due to the **"Normalization"** on Batches
