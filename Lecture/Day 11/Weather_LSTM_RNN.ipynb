# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Image Processing with Neural Network
#
# ## Template 03
# ## FIFA dataset

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np
import pandas as pd
import sys
sys.path.insert(0, r'G:\My Drive\DNN')

from collections.abc import Callable
from typing import Literal

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

import tensorflow as tf

from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print (fn_plot_tf_hist.__doc__)
# Out:
#     Args:
#         hist_df: a dataframe with following ccolumns
#             column 0: loss
#             column 1: accuracy
#             column 2: val_loss
#             column 3: val_accuracy
#             While plotting columns are accessed by index
#             so that even if the column names are different it will not throw exceptions.

# %%
print (fn_plot_confusion_matrix.__doc__)
# Out:
#     Args:
#         y_true: Ground Truth
#         y_pred : Predictions
#         labels : dictonary
#                   {0: 'Goal Keeper',
#                   1: 'Defender',
#                   2: 'Mid-Fielder',
#                   3: 'Forward'}

# %%
###----------------------
### Some basic parameters
###----------------------

inpDir = '../input'
outDir = '../output'
modelDir = './models'
subDir = 'weather'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results
tf.random.set_seed(RANDOM_STATE)
EPOCHS = 101 # number of epochs
BATCH_SIZE = 32
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2

# parameters for Matplotlib
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Basic Hygiene

# %%
# Check if all directories are present
if not os.path.exists(os.path.join(outDir)):
    os.makedirs(os.path.join(outDir))
    print ('Created {} directory'.format(outDir))

if not os.path.exists(os.path.join(modelDir, subDir)):
    os.makedirs(os.path.join(modelDir, subDir))
    print ('Created {} directory'.format(os.path.join(modelDir, subDir)))

# %% [markdown]
# ## Read FIFA 2019 data set

# %%
data_df = pd.read_csv(os.path.join(inpDir, 'weatherHistory.csv'))
data_df.shape
# Out:
# (96453, 12)

# %%
data_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %% [markdown]
# Take care of time zones

# %%
data_df['datetime'] = pd.to_datetime(data_df['Formatted Date'], utc=True)

# %%
data_df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary                  datetime
# 0  Partly cloudy throughout the day. 2006-03-31 22:00:00+00:00
# 1  Partly cloudy throughout the day. 2006-03-31 23:00:00+00:00
# 2  Partly cloudy throughout the day. 2006-04-01 00:00:00+00:00
# 3  Partly cloudy throughout the day. 2006-04-01 01:00:00+00:00
# 4  Partly cloudy throughout the day. 2006-04-01 02:00:00+00:00

# %% [markdown]
# Apparent Temp: Feels like temp. Its mixture of temp, humidity and wind.

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
#  12  datetime                  96453 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(8), object(4)
# memory usage: 9.6+ MB

# %%
data_df.describe().T
# Out:
#                             count         mean         std        min  \
# Temperature (C)           96453.0    11.932678    9.551546 -21.822222
# Apparent Temperature (C)  96453.0    10.855029   10.696847 -27.716667
# Humidity                  96453.0     0.734899    0.195473   0.000000
# Wind Speed (km/h)         96453.0    10.810640    6.913571   0.000000
# Wind Bearing (degrees)    96453.0   187.509232  107.383428   0.000000
# Visibility (km)           96453.0    10.347325    4.192123   0.000000
# Loud Cover                96453.0     0.000000    0.000000   0.000000
# Pressure (millibars)      96453.0  1003.235956  116.969906   0.000000
#
#                                   25%        50%          75%          max
# Temperature (C)              4.688889    12.0000    18.838889    39.905556
# Apparent Temperature (C)     2.311111    12.0000    18.838889    39.344444
# Humidity                     0.600000     0.7800     0.890000     1.000000
# Wind Speed (km/h)            5.828200     9.9659    14.135800    63.852600
# Wind Bearing (degrees)     116.000000   180.0000   290.000000   359.000000
# Visibility (km)              8.339800    10.0464    14.812000    16.100000
# Loud Cover                   0.000000     0.0000     0.000000     0.000000
# Pressure (millibars)      1011.900000  1016.4500  1021.090000  1046.380000

# %%
data_df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary', 'datetime'],
#       dtype='object')

# %% [markdown]
# Picking the numerical columns

# %%
num_cols = ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
       'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover', 'Pressure (millibars)']

len(num_cols)
# Out:
# 8

# %%
import seaborn as sns

fig,axes = plt.subplots(2,4)

axes = axes.ravel()

for count, col in enumerate (num_cols):
    ax = axes[count]

    sns.histplot(data_df, x = col, ax = ax, bins=5)

plt.tight_layout()

# %%
import seaborn as sns

fig,axes = plt.subplots(2,4)

axes = axes.ravel()

for count, col in enumerate (num_cols):
    ax = axes[count]

    sns.histplot(data_df, x = col, ax = ax, bins=10)

plt.tight_layout()

# %%
import seaborn as sns

fig,axes = plt.subplots(2,4)

axes = axes.ravel()

for count, col in enumerate (num_cols):
    ax = axes[count]

    sns.histplot(data_df, x = col, ax = ax, bins=25)

plt.tight_layout()

# %%
import seaborn as sns

fig,axes = plt.subplots(2,4)

axes = axes.ravel()

for count, col in enumerate (num_cols):
    ax = axes[count]

    sns.histplot(data_df, x = col, ax = ax, bins=50)

plt.tight_layout()

# %%
import seaborn as sns

fig,axes = plt.subplots(2,4)

axes = axes.ravel()

for count, col in enumerate (num_cols):
    ax = axes[count]

    sns.boxplot(data= data_df, y= col, ax = ax)

plt.tight_layout()

# %%
data_df[num_cols].corr()
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
# Wind Bearing (degrees)           0.029988                  0.029031  0.000735
# Visibility (km)                  0.392847                  0.381718 -0.369173
# Loud Cover                            NaN                       NaN       NaN
# Pressure (millibars)            -0.005447                 -0.000219  0.005454
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008957                0.029988
# Apparent Temperature (C)          -0.056650                0.029031
# Humidity                          -0.224951                0.000735
# Wind Speed (km/h)                  1.000000                0.103822
# Wind Bearing (degrees)             0.103822                1.000000
# Visibility (km)                    0.100749                0.047594
# Loud Cover                              NaN                     NaN
# Pressure (millibars)              -0.049263               -0.011651
#
#                           Visibility (km)  Loud Cover  Pressure (millibars)
# Temperature (C)                  0.392847         NaN             -0.005447
# Apparent Temperature (C)         0.381718         NaN             -0.000219
# Humidity                        -0.369173         NaN              0.005454
# Wind Speed (km/h)                0.100749         NaN             -0.049263
# Wind Bearing (degrees)           0.047594         NaN             -0.011651
# Visibility (km)                  1.000000         NaN              0.059818
# Loud Cover                            NaN         NaN                   NaN
# Pressure (millibars)             0.059818         NaN              1.000000

# %%
sns.heatmap(data_df[num_cols].corr(), annot=True, cmap='Dark2_r')
# Out:
# <Axes: >

# %%
temp_df = data_df[['datetime', 'Temperature (C)']]
temp_df = temp_df.sort_values('datetime', ascending= True, axis=0)
temp_df = temp_df.reset_index(drop = True)
temp_df.head()
# Out:
#                    datetime  Temperature (C)
# 0 2005-12-31 23:00:00+00:00         0.577778
# 1 2006-01-01 00:00:00+00:00         1.161111
# 2 2006-01-01 01:00:00+00:00         1.666667
# 3 2006-01-01 02:00:00+00:00         1.711111
# 4 2006-01-01 03:00:00+00:00         1.183333

# %%
temp_df = temp_df.rename({'Temperature (C)' : 'temp'}, axis= 1)
temp_df.head()
# Out:
#                    datetime      temp
# 0 2005-12-31 23:00:00+00:00  0.577778
# 1 2006-01-01 00:00:00+00:00  1.161111
# 2 2006-01-01 01:00:00+00:00  1.666667
# 3 2006-01-01 02:00:00+00:00  1.711111
# 4 2006-01-01 03:00:00+00:00  1.183333

# %%
temp_df.plot(x= 'datetime', y= 'temp', style='.');

# %% [markdown]
# Model Definition:
# ### LSTM

# %%
h_units = 100
input_shape = (1,10000)

model = tf.keras.Sequential()

model.add(tf.keras.layers.LSTM(units= h_units,
                                    input_shape=input_shape,
                                    activation='tanh'))
model.add(tf.keras.layers.Dense(1, activation='linear'))
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               4040400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 4040501 (15.41 MB)
# Trainable params: 4040501 (15.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
wax = model.get_weights()[0].shape # Weight of ax
waa = model.get_weights()[1].shape # Weight of aa
baa = model.get_weights()[2].shape # Bias of aa
way = model.get_weights()[3].shape # Weight of ay
bay = model.get_weights()[4].shape # Bias of ay

wax, waa, baa, way, bay
# Out:
# ((10000, 400), (100, 400), (400,), (100, 1), (1,))

# %%
temp_df.head(30)
# Out:
#                     datetime      temp
# 0  2005-12-31 23:00:00+00:00  0.577778
# 1  2006-01-01 00:00:00+00:00  1.161111
# 2  2006-01-01 01:00:00+00:00  1.666667
# 3  2006-01-01 02:00:00+00:00  1.711111
# 4  2006-01-01 03:00:00+00:00  1.183333
# 5  2006-01-01 04:00:00+00:00  1.205556
# 6  2006-01-01 05:00:00+00:00  2.222222
# 7  2006-01-01 06:00:00+00:00  2.072222
# 8  2006-01-01 07:00:00+00:00  2.200000
# 9  2006-01-01 08:00:00+00:00  2.733333
# 10 2006-01-01 09:00:00+00:00  2.788889
# 11 2006-01-01 10:00:00+00:00  3.822222
# 12 2006-01-01 11:00:00+00:00  4.911111
# 13 2006-01-01 12:00:00+00:00  6.205556
# 14 2006-01-01 13:00:00+00:00  7.438889
# 15 2006-01-01 14:00:00+00:00  6.950000
# 16 2006-01-01 15:00:00+00:00  5.972222
# 17 2006-01-01 16:00:00+00:00  5.905556
# 18 2006-01-01 17:00:00+00:00  4.955556
# 19 2006-01-01 18:00:00+00:00  5.472222
# 20 2006-01-01 19:00:00+00:00  5.972222
# 21 2006-01-01 20:00:00+00:00  4.933333
# 22 2006-01-01 21:00:00+00:00  5.472222
# 23 2006-01-01 22:00:00+00:00  5.422222
# 24 2006-01-01 23:00:00+00:00  5.422222
# 25 2006-01-02 00:00:00+00:00  2.350000
# 26 2006-01-02 01:00:00+00:00  5.422222
# 27 2006-01-02 02:00:00+00:00  5.905556
# 28 2006-01-02 03:00:00+00:00  5.966667
# 29 2006-01-02 04:00:00+00:00  5.950000

# %%
time_step = 24

y_idx = np.arange(time_step, temp_df.shape[0], time_step)
y_idx.shape
# Out:
# (4018,)

# %%
y_df = temp_df.iloc[y_idx]
y_df.head()
# Out:
#                      datetime      temp
# 24  2006-01-01 23:00:00+00:00  5.422222
# 48  2006-01-02 23:00:00+00:00  1.694444
# 72  2006-01-03 23:00:00+00:00  2.200000
# 96  2006-01-04 23:00:00+00:00  1.666667
# 120 2006-01-05 23:00:00+00:00  1.805556

# %%
y_df.shape
# Out:
# (4018, 2)

# %%
y_df.shape[0] * time_step
# Out:
# 96432

# %%
X_df = temp_df.iloc[range(len(y_df) * time_step)]
X_df.shape
# Out:
# (96432, 2)

# %%
X_df.head()
# Out:
#                    datetime      temp
# 0 2005-12-31 23:00:00+00:00  0.577778
# 1 2006-01-01 00:00:00+00:00  1.161111
# 2 2006-01-01 01:00:00+00:00  1.666667
# 3 2006-01-01 02:00:00+00:00  1.711111
# 4 2006-01-01 03:00:00+00:00  1.183333

# %%
X = np.reshape(X_df['temp'].to_numpy(), (y_df.shape[0], time_step))
X.shape
# Out:
# (4018, 24)

# %%
X = X[:, :23]
X.shape
# Out:
# (4018, 23)

# %% [markdown]
# Input shape expectations = `[batch, timestep, feature]`

# %%
X = np.reshape(X, [X.shape[0], X.shape[1], 1])
X.shape
# Out:
# (4018, 23, 1)

# %%
split = int(y_df.shape[0] * (1 - TEST_SIZE))
X_train = X[:split]
X_test = X[split:]

y_train = y_df['temp'].to_numpy()[:split]
y_test = y_df['temp'].to_numpy()[split:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3214, 23, 1), (804, 23, 1), (3214,), (804,))

# %%
h_units = 256
input_shape = (time_step-1, 1)

model = tf.keras.Sequential()

model.add(tf.keras.layers.SimpleRNN(units= h_units,
                                    input_shape=input_shape,
                                    activation='tanh'))

model.add(tf.keras.layers.Dense(1, activation='linear'))

model.compile(optimizer='adam', 
              metrics = [tf.keras.metrics.RootMeanSquaredError()],
              loss='mean_squared_error')
# Out:
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 256)               66048
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 66305 (259.00 KB)
# Trainable params: 66305 (259.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, 
                    validation_data = [X_test, y_test],
                    batch_size = BATCH_SIZE,
                    epochs = EPOCHS, 
                    verbose = 2)
# Out:
# Epoch 1/101
# WARNING:tensorflow:From c:\Users\Administrator.DAI-PC2\.conda\envs\New\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 101/101 - 3s - loss: 11.4485 - root_mean_squared_error: 3.3836 - val_loss: 1.0861 - val_root_mean_squared_error: 1.0422 - 3s/epoch - 34ms/step
# Epoch 2/101
# 101/101 - 2s - loss: 1.7188 - root_mean_squared_error: 1.3110 - val_loss: 0.9560 - val_root_mean_squared_error: 0.9777 - 2s/epoch - 18ms/step
# Epoch 3/101
# 101/101 - 2s - loss: 1.3991 - root_mean_squared_error: 1.1829 - val_loss: 0.8211 - val_root_mean_squared_error: 0.9062 - 2s/epoch - 17ms/step
# Epoch 4/101
# 101/101 - 2s - loss: 1.2356 - root_mean_squared_error: 1.1116 - val_loss: 0.8741 - val_root_mean_squared_error: 0.9349 - 2s/epoch - 18ms/step
# Epoch 5/101
# 101/101 - 2s - loss: 1.1520 - root_mean_squared_error: 1.0733 - val_loss: 0.7462 - val_root_mean_squared_error: 0.8638 - 2s/epoch - 20ms/step
# Epoch 6/101
# 101/101 - 2s - loss: 1.1731 - root_mean_squared_error: 1.0831 - val_loss: 0.9187 - val_root_mean_squared_error: 0.9585 - 2s/epoch - 18ms/step
# Epoch 7/101
# 101/101 - 2s - loss: 1.1633 - root_mean_squared_error: 1.0786 - val_loss: 0.9649 - val_root_mean_squared_error: 0.9823 - 2s/epoch - 18ms/step
# Epoch 8/101
# 101/101 - 2s - loss: 1.3718 - root_mean_squared_error: 1.1712 - val_loss: 1.0650 - val_root_mean_squared_error: 1.0320 - 2s/epoch - 19ms/step
# Epoch 9/101
# 101/101 - 2s - loss: 1.1291 - root_mean_squared_error: 1.0626 - val_loss: 1.1979 - val_root_mean_squared_error: 1.0945 - 2s/epoch - 18ms/step
# Epoch 10/101
# 101/101 - 2s - loss: 1.1727 - root_mean_squared_error: 1.0829 - val_loss: 0.9067 - val_root_mean_squared_error: 0.9522 - 2s/epoch - 17ms/step
# Epoch 11/101
# 101/101 - 2s - loss: 1.0876 - root_mean_squared_error: 1.0429 - val_loss: 0.7273 - val_root_mean_squared_error: 0.8528 - 2s/epoch - 20ms/step
# Epoch 12/101
# 101/101 - 2s - loss: 1.0532 - root_mean_squared_error: 1.0263 - val_loss: 0.7016 - val_root_mean_squared_error: 0.8376 - 2s/epoch - 17ms/step
# Epoch 13/101
# 101/101 - 2s - loss: 1.0543 - root_mean_squared_error: 1.0268 - val_loss: 0.7497 - val_root_mean_squared_error: 0.8659 - 2s/epoch - 18ms/step
# Epoch 14/101
# 101/101 - 2s - loss: 1.0876 - root_mean_squared_error: 1.0429 - val_loss: 0.7714 - val_root_mean_squared_error: 0.8783 - 2s/epoch - 19ms/step
# Epoch 15/101
# 101/101 - 2s - loss: 1.0539 - root_mean_squared_error: 1.0266 - val_loss: 0.7751 - val_root_mean_squared_error: 0.8804 - 2s/epoch - 18ms/step
# Epoch 16/101
# 101/101 - 2s - loss: 1.0696 - root_mean_squared_error: 1.0342 - val_loss: 0.6714 - val_root_mean_squared_error: 0.8194 - 2s/epoch - 17ms/step
# Epoch 17/101
# 101/101 - 2s - loss: 1.0354 - root_mean_squared_error: 1.0176 - val_loss: 1.1813 - val_root_mean_squared_error: 1.0869 - 2s/epoch - 17ms/step
# Epoch 18/101
# 101/101 - 2s - loss: 1.0571 - root_mean_squared_error: 1.0282 - val_loss: 0.7320 - val_root_mean_squared_error: 0.8556 - 2s/epoch - 19ms/step
# Epoch 19/101
# 101/101 - 2s - loss: 1.0649 - root_mean_squared_error: 1.0319 - val_loss: 0.8437 - val_root_mean_squared_error: 0.9185 - 2s/epoch - 15ms/step
# Epoch 20/101
# 101/101 - 2s - loss: 1.1164 - root_mean_squared_error: 1.0566 - val_loss: 1.1814 - val_root_mean_squared_error: 1.0869 - 2s/epoch - 17ms/step
# Epoch 21/101
# 101/101 - 2s - loss: 1.0735 - root_mean_squared_error: 1.0361 - val_loss: 0.7239 - val_root_mean_squared_error: 0.8508 - 2s/epoch - 15ms/step
# Epoch 22/101
# 101/101 - 2s - loss: 1.0766 - root_mean_squared_error: 1.0376 - val_loss: 1.1078 - val_root_mean_squared_error: 1.0525 - 2s/epoch - 16ms/step
# Epoch 23/101
# 101/101 - 2s - loss: 1.0423 - root_mean_squared_error: 1.0209 - val_loss: 0.7467 - val_root_mean_squared_error: 0.8641 - 2s/epoch - 16ms/step
# Epoch 24/101
# 101/101 - 2s - loss: 1.0552 - root_mean_squared_error: 1.0273 - val_loss: 0.6783 - val_root_mean_squared_error: 0.8236 - 2s/epoch - 15ms/step
# Epoch 25/101
# 101/101 - 2s - loss: 1.0363 - root_mean_squared_error: 1.0180 - val_loss: 0.7123 - val_root_mean_squared_error: 0.8440 - 2s/epoch - 16ms/step
# Epoch 26/101
# 101/101 - 2s - loss: 1.0344 - root_mean_squared_error: 1.0171 - val_loss: 0.8156 - val_root_mean_squared_error: 0.9031 - 2s/epoch - 16ms/step
# Epoch 27/101
# 101/101 - 2s - loss: 1.0560 - root_mean_squared_error: 1.0276 - val_loss: 0.6707 - val_root_mean_squared_error: 0.8190 - 2s/epoch - 16ms/step
# Epoch 28/101
# 101/101 - 2s - loss: 1.0721 - root_mean_squared_error: 1.0354 - val_loss: 0.6913 - val_root_mean_squared_error: 0.8315 - 2s/epoch - 15ms/step
# Epoch 29/101
# 101/101 - 2s - loss: 1.0855 - root_mean_squared_error: 1.0419 - val_loss: 0.6806 - val_root_mean_squared_error: 0.8250 - 2s/epoch - 16ms/step
# Epoch 30/101
# 101/101 - 2s - loss: 1.0140 - root_mean_squared_error: 1.0070 - val_loss: 0.6929 - val_root_mean_squared_error: 0.8324 - 2s/epoch - 15ms/step
# Epoch 31/101
# 101/101 - 1s - loss: 1.1643 - root_mean_squared_error: 1.0790 - val_loss: 0.6562 - val_root_mean_squared_error: 0.8101 - 1s/epoch - 14ms/step
# Epoch 32/101
# 101/101 - 1s - loss: 1.0481 - root_mean_squared_error: 1.0238 - val_loss: 0.7300 - val_root_mean_squared_error: 0.8544 - 1s/epoch - 14ms/step
# Epoch 33/101
# 101/101 - 2s - loss: 1.0535 - root_mean_squared_error: 1.0264 - val_loss: 0.6995 - val_root_mean_squared_error: 0.8363 - 2s/epoch - 15ms/step
# Epoch 34/101
# 101/101 - 1s - loss: 1.0455 - root_mean_squared_error: 1.0225 - val_loss: 0.7018 - val_root_mean_squared_error: 0.8377 - 1s/epoch - 15ms/step
# Epoch 35/101
# 101/101 - 2s - loss: 1.0266 - root_mean_squared_error: 1.0132 - val_loss: 0.6980 - val_root_mean_squared_error: 0.8354 - 2s/epoch - 15ms/step
# Epoch 36/101
# 101/101 - 2s - loss: 1.1284 - root_mean_squared_error: 1.0623 - val_loss: 0.7901 - val_root_mean_squared_error: 0.8889 - 2s/epoch - 17ms/step
# Epoch 37/101
# 101/101 - 2s - loss: 1.0381 - root_mean_squared_error: 1.0189 - val_loss: 0.7688 - val_root_mean_squared_error: 0.8768 - 2s/epoch - 16ms/step
# Epoch 38/101
# 101/101 - 2s - loss: 1.0988 - root_mean_squared_error: 1.0482 - val_loss: 0.7361 - val_root_mean_squared_error: 0.8580 - 2s/epoch - 15ms/step
# Epoch 39/101
# 101/101 - 2s - loss: 1.0417 - root_mean_squared_error: 1.0206 - val_loss: 0.7129 - val_root_mean_squared_error: 0.8443 - 2s/epoch - 16ms/step
# Epoch 40/101
# 101/101 - 2s - loss: 1.0497 - root_mean_squared_error: 1.0246 - val_loss: 0.7018 - val_root_mean_squared_error: 0.8378 - 2s/epoch - 16ms/step
# Epoch 41/101
# 101/101 - 2s - loss: 1.0376 - root_mean_squared_error: 1.0186 - val_loss: 0.6855 - val_root_mean_squared_error: 0.8279 - 2s/epoch - 15ms/step
# Epoch 42/101
# 101/101 - 2s - loss: 1.0294 - root_mean_squared_error: 1.0146 - val_loss: 0.6617 - val_root_mean_squared_error: 0.8135 - 2s/epoch - 15ms/step
# Epoch 43/101
# 101/101 - 2s - loss: 1.0302 - root_mean_squared_error: 1.0150 - val_loss: 0.7263 - val_root_mean_squared_error: 0.8522 - 2s/epoch - 18ms/step
# Epoch 44/101
# 101/101 - 2s - loss: 1.0468 - root_mean_squared_error: 1.0231 - val_loss: 0.9501 - val_root_mean_squared_error: 0.9747 - 2s/epoch - 17ms/step
# Epoch 45/101
# 101/101 - 2s - loss: 1.0467 - root_mean_squared_error: 1.0231 - val_loss: 0.7314 - val_root_mean_squared_error: 0.8552 - 2s/epoch - 16ms/step
# Epoch 46/101
# 101/101 - 2s - loss: 1.0547 - root_mean_squared_error: 1.0270 - val_loss: 0.6772 - val_root_mean_squared_error: 0.8229 - 2s/epoch - 17ms/step
# Epoch 47/101
# 101/101 - 2s - loss: 1.0116 - root_mean_squared_error: 1.0058 - val_loss: 0.8993 - val_root_mean_squared_error: 0.9483 - 2s/epoch - 18ms/step
# Epoch 48/101
# 101/101 - 2s - loss: 1.0385 - root_mean_squared_error: 1.0191 - val_loss: 0.6842 - val_root_mean_squared_error: 0.8272 - 2s/epoch - 16ms/step
# Epoch 49/101
# 101/101 - 2s - loss: 1.0517 - root_mean_squared_error: 1.0255 - val_loss: 0.6889 - val_root_mean_squared_error: 0.8300 - 2s/epoch - 17ms/step
# Epoch 50/101
# 101/101 - 2s - loss: 1.0568 - root_mean_squared_error: 1.0280 - val_loss: 0.7532 - val_root_mean_squared_error: 0.8679 - 2s/epoch - 17ms/step
# Epoch 51/101
# 101/101 - 2s - loss: 1.0754 - root_mean_squared_error: 1.0370 - val_loss: 0.7589 - val_root_mean_squared_error: 0.8711 - 2s/epoch - 16ms/step
# Epoch 52/101
# 101/101 - 2s - loss: 1.0324 - root_mean_squared_error: 1.0161 - val_loss: 0.6761 - val_root_mean_squared_error: 0.8223 - 2s/epoch - 17ms/step
# Epoch 53/101
# 101/101 - 2s - loss: 1.0595 - root_mean_squared_error: 1.0293 - val_loss: 0.8282 - val_root_mean_squared_error: 0.9100 - 2s/epoch - 18ms/step
# Epoch 54/101
# 101/101 - 2s - loss: 1.0814 - root_mean_squared_error: 1.0399 - val_loss: 0.7740 - val_root_mean_squared_error: 0.8798 - 2s/epoch - 18ms/step
# Epoch 55/101
# 101/101 - 2s - loss: 1.1979 - root_mean_squared_error: 1.0945 - val_loss: 1.1739 - val_root_mean_squared_error: 1.0835 - 2s/epoch - 15ms/step
# Epoch 56/101
# 101/101 - 2s - loss: 1.4834 - root_mean_squared_error: 1.2179 - val_loss: 0.7251 - val_root_mean_squared_error: 0.8515 - 2s/epoch - 18ms/step
# Epoch 57/101
# 101/101 - 2s - loss: 1.0960 - root_mean_squared_error: 1.0469 - val_loss: 0.8537 - val_root_mean_squared_error: 0.9240 - 2s/epoch - 18ms/step
# Epoch 58/101
# 101/101 - 2s - loss: 1.1782 - root_mean_squared_error: 1.0855 - val_loss: 0.7873 - val_root_mean_squared_error: 0.8873 - 2s/epoch - 15ms/step
# Epoch 59/101
# 101/101 - 2s - loss: 1.1322 - root_mean_squared_error: 1.0640 - val_loss: 0.8689 - val_root_mean_squared_error: 0.9322 - 2s/epoch - 18ms/step
# Epoch 60/101
# 101/101 - 2s - loss: 1.0796 - root_mean_squared_error: 1.0391 - val_loss: 0.7500 - val_root_mean_squared_error: 0.8660 - 2s/epoch - 19ms/step
# Epoch 61/101
# 101/101 - 2s - loss: 1.0891 - root_mean_squared_error: 1.0436 - val_loss: 0.8518 - val_root_mean_squared_error: 0.9229 - 2s/epoch - 16ms/step
# Epoch 62/101
# 101/101 - 2s - loss: 1.1193 - root_mean_squared_error: 1.0580 - val_loss: 0.7266 - val_root_mean_squared_error: 0.8524 - 2s/epoch - 18ms/step
# Epoch 63/101
# 101/101 - 2s - loss: 1.0721 - root_mean_squared_error: 1.0354 - val_loss: 0.6381 - val_root_mean_squared_error: 0.7988 - 2s/epoch - 19ms/step
# Epoch 64/101
# 101/101 - 1s - loss: 1.0338 - root_mean_squared_error: 1.0168 - val_loss: 0.6983 - val_root_mean_squared_error: 0.8356 - 1s/epoch - 15ms/step
# Epoch 65/101
# 101/101 - 2s - loss: 1.0799 - root_mean_squared_error: 1.0392 - val_loss: 0.6731 - val_root_mean_squared_error: 0.8204 - 2s/epoch - 19ms/step
# Epoch 66/101
# 101/101 - 2s - loss: 1.0630 - root_mean_squared_error: 1.0310 - val_loss: 0.6830 - val_root_mean_squared_error: 0.8265 - 2s/epoch - 18ms/step
# Epoch 67/101
# 101/101 - 2s - loss: 1.1215 - root_mean_squared_error: 1.0590 - val_loss: 0.8256 - val_root_mean_squared_error: 0.9086 - 2s/epoch - 17ms/step
# Epoch 68/101
# 101/101 - 2s - loss: 1.0359 - root_mean_squared_error: 1.0178 - val_loss: 0.7888 - val_root_mean_squared_error: 0.8882 - 2s/epoch - 17ms/step
# Epoch 69/101
# 101/101 - 2s - loss: 1.0708 - root_mean_squared_error: 1.0348 - val_loss: 0.7352 - val_root_mean_squared_error: 0.8575 - 2s/epoch - 19ms/step
# Epoch 70/101
# 101/101 - 2s - loss: 1.0949 - root_mean_squared_error: 1.0464 - val_loss: 0.6655 - val_root_mean_squared_error: 0.8158 - 2s/epoch - 17ms/step
# Epoch 71/101
# 101/101 - 2s - loss: 1.0654 - root_mean_squared_error: 1.0322 - val_loss: 0.7695 - val_root_mean_squared_error: 0.8772 - 2s/epoch - 18ms/step
# Epoch 72/101
# 101/101 - 2s - loss: 1.1029 - root_mean_squared_error: 1.0502 - val_loss: 0.6633 - val_root_mean_squared_error: 0.8145 - 2s/epoch - 18ms/step
# Epoch 73/101
# 101/101 - 2s - loss: 1.0467 - root_mean_squared_error: 1.0231 - val_loss: 0.8667 - val_root_mean_squared_error: 0.9310 - 2s/epoch - 17ms/step
# Epoch 74/101
# 101/101 - 2s - loss: 1.0835 - root_mean_squared_error: 1.0409 - val_loss: 0.8629 - val_root_mean_squared_error: 0.9289 - 2s/epoch - 18ms/step
# Epoch 75/101
# 101/101 - 2s - loss: 1.0865 - root_mean_squared_error: 1.0423 - val_loss: 0.7231 - val_root_mean_squared_error: 0.8503 - 2s/epoch - 19ms/step
# Epoch 76/101
# 101/101 - 2s - loss: 1.0725 - root_mean_squared_error: 1.0356 - val_loss: 0.7748 - val_root_mean_squared_error: 0.8802 - 2s/epoch - 17ms/step
# Epoch 77/101
# 101/101 - 2s - loss: 1.0508 - root_mean_squared_error: 1.0251 - val_loss: 0.8389 - val_root_mean_squared_error: 0.9159 - 2s/epoch - 17ms/step
# Epoch 78/101
# 101/101 - 2s - loss: 1.0740 - root_mean_squared_error: 1.0364 - val_loss: 0.7338 - val_root_mean_squared_error: 0.8566 - 2s/epoch - 18ms/step
# Epoch 79/101
# 101/101 - 2s - loss: 1.1059 - root_mean_squared_error: 1.0516 - val_loss: 0.7470 - val_root_mean_squared_error: 0.8643 - 2s/epoch - 19ms/step
# Epoch 80/101
# 101/101 - 2s - loss: 1.0419 - root_mean_squared_error: 1.0208 - val_loss: 0.7064 - val_root_mean_squared_error: 0.8405 - 2s/epoch - 17ms/step
# Epoch 81/101
# 101/101 - 2s - loss: 1.0443 - root_mean_squared_error: 1.0219 - val_loss: 0.7153 - val_root_mean_squared_error: 0.8457 - 2s/epoch - 17ms/step
# Epoch 82/101
# 101/101 - 2s - loss: 1.0545 - root_mean_squared_error: 1.0269 - val_loss: 0.7611 - val_root_mean_squared_error: 0.8724 - 2s/epoch - 18ms/step
# Epoch 83/101
# 101/101 - 2s - loss: 1.0860 - root_mean_squared_error: 1.0421 - val_loss: 0.7441 - val_root_mean_squared_error: 0.8626 - 2s/epoch - 16ms/step
# Epoch 84/101
# 101/101 - 2s - loss: 1.0999 - root_mean_squared_error: 1.0488 - val_loss: 0.6893 - val_root_mean_squared_error: 0.8302 - 2s/epoch - 19ms/step
# Epoch 85/101
# 101/101 - 2s - loss: 1.0598 - root_mean_squared_error: 1.0295 - val_loss: 0.8625 - val_root_mean_squared_error: 0.9287 - 2s/epoch - 19ms/step
# Epoch 86/101
# 101/101 - 2s - loss: 1.0900 - root_mean_squared_error: 1.0440 - val_loss: 0.8889 - val_root_mean_squared_error: 0.9428 - 2s/epoch - 16ms/step
# Epoch 87/101
# 101/101 - 2s - loss: 1.0954 - root_mean_squared_error: 1.0466 - val_loss: 0.8013 - val_root_mean_squared_error: 0.8951 - 2s/epoch - 19ms/step
# Epoch 88/101
# 101/101 - 2s - loss: 1.1015 - root_mean_squared_error: 1.0495 - val_loss: 0.8702 - val_root_mean_squared_error: 0.9329 - 2s/epoch - 18ms/step
# Epoch 89/101
# 101/101 - 2s - loss: 1.0497 - root_mean_squared_error: 1.0246 - val_loss: 0.6962 - val_root_mean_squared_error: 0.8344 - 2s/epoch - 16ms/step
# Epoch 90/101
# 101/101 - 2s - loss: 1.0506 - root_mean_squared_error: 1.0250 - val_loss: 0.7290 - val_root_mean_squared_error: 0.8538 - 2s/epoch - 19ms/step
# Epoch 91/101
# 101/101 - 2s - loss: 1.0589 - root_mean_squared_error: 1.0290 - val_loss: 0.7019 - val_root_mean_squared_error: 0.8378 - 2s/epoch - 18ms/step
# Epoch 92/101
# 101/101 - 2s - loss: 1.0716 - root_mean_squared_error: 1.0352 - val_loss: 1.2575 - val_root_mean_squared_error: 1.1214 - 2s/epoch - 17ms/step
# Epoch 93/101
# 101/101 - 2s - loss: 1.0945 - root_mean_squared_error: 1.0462 - val_loss: 0.9228 - val_root_mean_squared_error: 0.9606 - 2s/epoch - 19ms/step
# Epoch 94/101
# 101/101 - 2s - loss: 1.0814 - root_mean_squared_error: 1.0399 - val_loss: 0.6537 - val_root_mean_squared_error: 0.8085 - 2s/epoch - 19ms/step
# Epoch 95/101
# 101/101 - 2s - loss: 1.0521 - root_mean_squared_error: 1.0257 - val_loss: 0.7766 - val_root_mean_squared_error: 0.8812 - 2s/epoch - 17ms/step
# Epoch 96/101
# 101/101 - 2s - loss: 1.1116 - root_mean_squared_error: 1.0543 - val_loss: 0.6588 - val_root_mean_squared_error: 0.8117 - 2s/epoch - 18ms/step
# Epoch 97/101
# 101/101 - 2s - loss: 1.0297 - root_mean_squared_error: 1.0147 - val_loss: 0.7947 - val_root_mean_squared_error: 0.8915 - 2s/epoch - 18ms/step
# Epoch 98/101
# 101/101 - 2s - loss: 1.0913 - root_mean_squared_error: 1.0447 - val_loss: 0.7373 - val_root_mean_squared_error: 0.8587 - 2s/epoch - 18ms/step
# Epoch 99/101
# 101/101 - 2s - loss: 1.0574 - root_mean_squared_error: 1.0283 - val_loss: 0.6758 - val_root_mean_squared_error: 0.8221 - 2s/epoch - 19ms/step
# Epoch 100/101
# 101/101 - 2s - loss: 1.0313 - root_mean_squared_error: 1.0155 - val_loss: 0.6950 - val_root_mean_squared_error: 0.8337 - 2s/epoch - 19ms/step
# Epoch 101/101
# 101/101 - 2s - loss: 1.0889 - root_mean_squared_error: 1.0435 - val_loss: 0.6887 - val_root_mean_squared_error: 0.8299 - 2s/epoch - 16ms/step

# %%
loss_df = pd.DataFrame(history.history)
fn_plot_tf_hist(loss_df)

# %%
loss_df[loss_df['val_loss'] == loss_df['val_loss'].min()]
# Out:
#         loss  root_mean_squared_error  val_loss  val_root_mean_squared_error
# 62  1.072125                 1.035435  0.638144                     0.798839

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

y_pred = np.append(y_train_pred, y_test_pred)

y_pred.shape
# Out:
# 101/101 [==============================] - 1s 8ms/step
# 26/26 [==============================] - 0s 9ms/step
# (4018,)

# %%
res_df = y_df.copy()
res_df['pred'] = y_pred
res_df['datetime'] = res_df['datetime'].dt.date
res_df.head()
# Out:
#        datetime      temp      pred
# 24   2006-01-01  5.422222  5.041257
# 48   2006-01-02  1.694444  1.513831
# 72   2006-01-03  2.200000  1.928412
# 96   2006-01-04  1.666667  1.693445
# 120  2006-01-05  1.805556  2.247304

# %% [markdown]
# #### How we can make it more Accurate ?
#
# - Add more Fatures
# - Add more Data (Interpret it Hourly basis or subgroups as Hourly)

# %%
fig, ax = plt.subplots(figsize = (30,6))

res_df[:500].plot(x = 'datetime', y = ['temp', 'pred'], ax = ax)
# Out:
# <Axes: xlabel='datetime'>
