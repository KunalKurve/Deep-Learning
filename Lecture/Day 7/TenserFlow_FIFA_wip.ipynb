# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Network
#
# ## Session 8a - Introduction to Tensorflow
# ## FIFA dataset
#
# <img src='../../../images/prasami_color_tutorials_small.png' width='400' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
###-----------------
### Import Libraries
###-----------------

import os
import numpy as np # type: ignore
import pandas as pd # type: ignore

from collections.abc import Callable
from typing import Literal

from sklearn.model_selection import train_test_split # type: ignore
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay # type: ignore
from sklearn.preprocessing import StandardScaler # type: ignore
import matplotlib.pyplot as plt # type: ignore

import tensorflow as tf # type: ignore


# os.chdir("/home/pgdai/Desktop/DNN-May24/study material-20240518T025337Z-001/study material/utils")
# from utils.helper import fn_plot_torch_hist, fn_plot_confusion_matrix
# Out:
# 2024-05-22 22:10:42.824851: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-22 22:10:42.871832: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-22 22:10:42.871872: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-22 22:10:42.872978: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-22 22:10:42.880103: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-22 22:10:43.906863: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
###----------------------
### Plot confusion matrix
###----------------------
def fn_plot_confusion_matrix(y_true, y_pred, labels):
    '''
    Args:
        y_true: Ground Truth 
        y_pred : Predictions
        labels : dictonary 
                  {0: 'Goal Keeper', 
                  1: 'Defender', 
                  2: 'Mid-Fielder', 
                  3: 'Forward'}
    
    '''
    
    cm  = confusion_matrix(y_true, y_pred)
    
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=labels.values())
    
    fig, ax = plt.subplots(figsize = (6,6))
    
    disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
    # Disable the grid
    ax.grid(False)

    plt.show();

# %%
###------------------------------
### Plot Loss Curve using pytorch
###------------------------------
def fn_plot_torch_hist(hist_df):
    
    # instantiate figure
    fig, axes = plt.subplots(1,2 , figsize = (15,6))
    
    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='cyan', alpha=0.5)

    # columns
    x = hist_df.columns[0]
    y1 = hist_df.columns[1]
    y2 = hist_df.columns[2]
    y3 = hist_df.columns[3]
    y4 = hist_df.columns[4]
    
    # Where was min loss
    best = hist_df[hist_df[y2] == hist_df[y2].min()]
    best = best.drop_duplicates(subset=y2)
    # pick first axis
    ax = axes[0]

    # Plot all losses
    hist_df.plot(x = x, y = [y1, y2], ax = ax)

    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y2].min())
    y_max = max(hist_df[y1].max(), hist_df[y2].max())
    offset = (y_max-y_min)/10.0

    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y2]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y2].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y2].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()+ offset, best[y2].to_numpy()[0]+offset), # location of text 
                fontsize=14,va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor='cyan', shrink=0.05)) # arrow
    
    # Draw vertical line at best value
    ax.axvline(x = best[x].to_numpy(), color = 'green', linestyle='-.', lw = 3);
    
    ax.set_xlabel(x.title())
    ax.set_ylabel(y1.title())
    ax.set_title('Errors')
    ax.grid()
    ax.legend(loc = 'upper left') # model legend to upper left

    # pick second axis
    ax = axes[1]

    # Plot accuracies
    hist_df.plot(x = x, y = [y3, y4], ax = ax)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y3],
                           hist_df.iloc[-1][y4]) #text to plot
        
    # calculate offset for arroe
    y_min = min(hist_df[y3].min(), hist_df[y4].min())
    y_max = max(hist_df[y3].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # place a text box in lower middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=12,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()- offset, best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=14,va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor='cyan', shrink=0.05)) # arrow
    
    
    # Draw a vertical line at best value
    ax.axvline(x = best[x].to_numpy(), 
               color = 'green', 
               linestyle='-.', lw = 3)
    
    # Labels
    ax.set_xlabel(x.title())
    ax.set_ylabel(y3.title())
    ax.set_title('Accuracies')
    ax.grid();
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
###------------------------------------------------
### Plot Loss Curve using Tensorflow history object
###------------------------------------------------
def fn_plot_tf_hist(hist_df):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
        
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)
    
    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y3].to_numpy()[0] + offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
print (fn_plot_torch_hist.__doc__)
# Out:
# None

# %%
print (fn_plot_confusion_matrix.__doc__)
# Out:
#     Args:
#         y_true: Ground Truth
#         y_pred : Predictions
#         labels : dictonary
#                   {0: 'Goal Keeper',
#                   1: 'Defender',
#                   2: 'Mid-Fielder',
#                   3: 'Forward'}

# %%
###----------------------
### Some basic parameters
###----------------------

#Directories so that we can save the trained model, the outputs and the inputs
inpDir = '/home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureThings/Day7/input'
outDir = '../../../output'
modelDir = '../../../models'
subDir = 'fifa_2019'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
np.random.seed(RANDOM_STATE)
rng = np.random.default_rng(seed = RANDOM_STATE) # Set Random Seed for reproducible  results

EPOCHS = 101 # number of epochs
BATCH_SIZE = 32 #default of tensorflow
ALPHA = 0.001 # learning rate
TEST_SIZE = 0.2
REG_LAMBDA = 0.001

L1_LAMBDA= 0.001
L2_LAMBDA= 0.001

# parameters for Matplotlib
params = {'legend.fontsize': 'medium',
          'figure.figsize': (15, 6),
          'axes.labelsize': 'medium',
          'axes.titlesize':'large',
          'xtick.labelsize':'medium',
          'ytick.labelsize':'medium'
         }

plt.rcParams.update(params)

CMAP = plt.cm.coolwarm
plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %% [markdown]
# ## Basic Hygiene

# %%
# Check if all directories are present
if not os.path.exists(os.path.join(outDir)):
    os.makedirs(os.path.join(outDir))
    print ('Created {} directory'.format(outDir))

if not os.path.exists(os.path.join(modelDir, subDir)):
    os.makedirs(os.path.join(modelDir, subDir))
    print ('Created {} directory'.format(os.path.join(modelDir, subDir)))

# %% [markdown]
# ## Read FIFA 2019 data set

# %%
data_df = pd.read_csv(os.path.join(inpDir, 'fifa_2019.csv'))
data_df.shape
# Out:
# (18207, 89)

# %%
for col in data_df.columns:
    print(f"{col}: {data_df[col].unique}")
# Out:
# Unnamed: 0: <bound method Series.unique of 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 18202    18202
# 18203    18203
# 18204    18204
# 18205    18205
# 18206    18206
# Name: Unnamed: 0, Length: 18207, dtype: int64>
# ID: <bound method Series.unique of 0        158023
# 1         20801
# 2        190871
# 3        193080
# 4        192985
#           ...
# 18202    238813
# 18203    243165
# 18204    241638
# 18205    246268
# 18206    246269
# Name: ID, Length: 18207, dtype: int64>
# Name: <bound method Series.unique of 0                  L. Messi
# 1         Cristiano Ronaldo
# 2                 Neymar Jr
# 3                    De Gea
# 4              K. De Bruyne
#                 ...
# 18202          J. Lundstram
# 18203    N. Christoffersson
# 18204             B. Worman
# 18205        D. Walker-Rice
# 18206             G. Nugent
# Name: Name, Length: 18207, dtype: object>
# Age: <bound method Series.unique of 0        31
# 1        33
# 2        26
# 3        27
# 4        27
#          ..
# 18202    19
# 18203    19
# 18204    16
# 18205    17
# 18206    16
# Name: Age, Length: 18207, dtype: int64>
# Photo: <bound method Series.unique of 0        https://cdn.sofifa.org/players/4/19/158023.png
# 1         https://cdn.sofifa.org/players/4/19/20801.png
# 2        https://cdn.sofifa.org/players/4/19/190871.png
# 3        https://cdn.sofifa.org/players/4/19/193080.png
# 4        https://cdn.sofifa.org/players/4/19/192985.png
#                               ...
# 18202    https://cdn.sofifa.org/players/4/19/238813.png
# 18203    https://cdn.sofifa.org/players/4/19/243165.png
# 18204    https://cdn.sofifa.org/players/4/19/241638.png
# 18205    https://cdn.sofifa.org/players/4/19/246268.png
# 18206    https://cdn.sofifa.org/players/4/19/246269.png
# Name: Photo, Length: 18207, dtype: object>
# Nationality: <bound method Series.unique of 0        Argentina
# 1         Portugal
# 2           Brazil
# 3            Spain
# 4          Belgium
#            ...
# 18202      England
# 18203       Sweden
# 18204      England
# 18205      England
# 18206      England
# Name: Nationality, Length: 18207, dtype: object>
# Flag: <bound method Series.unique of 0        https://cdn.sofifa.org/flags/52.png
# 1        https://cdn.sofifa.org/flags/38.png
# 2        https://cdn.sofifa.org/flags/54.png
# 3        https://cdn.sofifa.org/flags/45.png
# 4         https://cdn.sofifa.org/flags/7.png
#                         ...
# 18202    https://cdn.sofifa.org/flags/14.png
# 18203    https://cdn.sofifa.org/flags/46.png
# 18204    https://cdn.sofifa.org/flags/14.png
# 18205    https://cdn.sofifa.org/flags/14.png
# 18206    https://cdn.sofifa.org/flags/14.png
# Name: Flag, Length: 18207, dtype: object>
# Overall: <bound method Series.unique of 0        94
# 1        94
# 2        92
# 3        91
# 4        91
#          ..
# 18202    47
# 18203    47
# 18204    47
# 18205    47
# 18206    46
# Name: Overall, Length: 18207, dtype: int64>
# Potential: <bound method Series.unique of 0        94
# 1        94
# 2        93
# 3        93
# 4        92
#          ..
# 18202    65
# 18203    63
# 18204    67
# 18205    66
# 18206    66
# Name: Potential, Length: 18207, dtype: int64>
# Club: <bound method Series.unique of 0               FC Barcelona
# 1                   Juventus
# 2        Paris Saint-Germain
# 3          Manchester United
# 4            Manchester City
#                 ...
# 18202        Crewe Alexandra
# 18203         Trelleborgs FF
# 18204       Cambridge United
# 18205        Tranmere Rovers
# 18206        Tranmere Rovers
# Name: Club, Length: 18207, dtype: object>
# Club Logo: <bound method Series.unique of 0          https://cdn.sofifa.org/teams/2/light/241.png
# 1           https://cdn.sofifa.org/teams/2/light/45.png
# 2           https://cdn.sofifa.org/teams/2/light/73.png
# 3           https://cdn.sofifa.org/teams/2/light/11.png
# 4           https://cdn.sofifa.org/teams/2/light/10.png
#                               ...
# 18202      https://cdn.sofifa.org/teams/2/light/121.png
# 18203      https://cdn.sofifa.org/teams/2/light/703.png
# 18204     https://cdn.sofifa.org/teams/2/light/1944.png
# 18205    https://cdn.sofifa.org/teams/2/light/15048.png
# 18206    https://cdn.sofifa.org/teams/2/light/15048.png
# Name: Club Logo, Length: 18207, dtype: object>
# Value: <bound method Series.unique of 0        €110.5M
# 1           €77M
# 2        €118.5M
# 3           €72M
# 4          €102M
#           ...
# 18202       €60K
# 18203       €60K
# 18204       €60K
# 18205       €60K
# 18206       €60K
# Name: Value, Length: 18207, dtype: object>
# Wage: <bound method Series.unique of 0        €565K
# 1        €405K
# 2        €290K
# 3        €260K
# 4        €355K
#          ...
# 18202      €1K
# 18203      €1K
# 18204      €1K
# 18205      €1K
# 18206      €1K
# Name: Wage, Length: 18207, dtype: object>
# Special: <bound method Series.unique of 0        2202
# 1        2228
# 2        2143
# 3        1471
# 4        2281
#          ...
# 18202    1307
# 18203    1098
# 18204    1189
# 18205    1228
# 18206    1321
# Name: Special, Length: 18207, dtype: int64>
# Preferred Foot: <bound method Series.unique of 0         Left
# 1        Right
# 2        Right
# 3        Right
# 4        Right
#          ...
# 18202    Right
# 18203    Right
# 18204    Right
# 18205    Right
# 18206    Right
# Name: Preferred Foot, Length: 18207, dtype: object>
# International Reputation: <bound method Series.unique of 0        5.0
# 1        5.0
# 2        5.0
# 3        4.0
# 4        4.0
#         ...
# 18202    1.0
# 18203    1.0
# 18204    1.0
# 18205    1.0
# 18206    1.0
# Name: International Reputation, Length: 18207, dtype: float64>
# Weak Foot: <bound method Series.unique of 0        4.0
# 1        4.0
# 2        5.0
# 3        3.0
# 4        5.0
#         ...
# 18202    2.0
# 18203    2.0
# 18204    3.0
# 18205    3.0
# 18206    3.0
# Name: Weak Foot, Length: 18207, dtype: float64>
# Skill Moves: <bound method Series.unique of 0        4.0
# 1        5.0
# 2        5.0
# 3        1.0
# 4        4.0
#         ...
# 18202    2.0
# 18203    2.0
# 18204    2.0
# 18205    2.0
# 18206    2.0
# Name: Skill Moves, Length: 18207, dtype: float64>
# Work Rate: <bound method Series.unique of 0        Medium/ Medium
# 1             High/ Low
# 2          High/ Medium
# 3        Medium/ Medium
# 4            High/ High
#               ...
# 18202    Medium/ Medium
# 18203    Medium/ Medium
# 18204    Medium/ Medium
# 18205    Medium/ Medium
# 18206    Medium/ Medium
# Name: Work Rate, Length: 18207, dtype: object>
# Body Type: <bound method Series.unique of 0             Messi
# 1        C. Ronaldo
# 2            Neymar
# 3              Lean
# 4            Normal
#             ...
# 18202          Lean
# 18203        Normal
# 18204        Normal
# 18205          Lean
# 18206          Lean
# Name: Body Type, Length: 18207, dtype: object>
# Real Face: <bound method Series.unique of 0        Yes
# 1        Yes
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 18202     No
# 18203     No
# 18204     No
# 18205     No
# 18206     No
# Name: Real Face, Length: 18207, dtype: object>
# Position: <bound method Series.unique of 0         RF
# 1         ST
# 2         LW
# 3         GK
# 4        RCM
#         ...
# 18202     CM
# 18203     ST
# 18204     ST
# 18205     RW
# 18206     CM
# Name: Position, Length: 18207, dtype: object>
# Jersey Number: <bound method Series.unique of 0        10.0
# 1         7.0
# 2        10.0
# 3         1.0
# 4         7.0
#          ...
# 18202    22.0
# 18203    21.0
# 18204    33.0
# 18205    34.0
# 18206    33.0
# Name: Jersey Number, Length: 18207, dtype: float64>
# Joined: <bound method Series.unique of 0         Jul 1, 2004
# 1        Jul 10, 2018
# 2         Aug 3, 2017
# 3         Jul 1, 2011
# 4        Aug 30, 2015
#              ...
# 18202     May 3, 2017
# 18203    Mar 19, 2018
# 18204     Jul 1, 2017
# 18205    Apr 24, 2018
# 18206    Oct 30, 2018
# Name: Joined, Length: 18207, dtype: object>
# Loaned From: <bound method Series.unique of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18202    NaN
# 18203    NaN
# 18204    NaN
# 18205    NaN
# 18206    NaN
# Name: Loaned From, Length: 18207, dtype: object>
# Contract Valid Until: <bound method Series.unique of 0        2021
# 1        2022
# 2        2022
# 3        2020
# 4        2023
#          ...
# 18202    2019
# 18203    2020
# 18204    2021
# 18205    2019
# 18206    2019
# Name: Contract Valid Until, Length: 18207, dtype: object>
# Height: <bound method Series.unique of 0         5'7
# 1         6'2
# 2         5'9
# 3         6'4
# 4        5'11
#          ...
# 18202     5'9
# 18203     6'3
# 18204     5'8
# 18205    5'10
# 18206    5'10
# Name: Height, Length: 18207, dtype: object>
# Weight: <bound method Series.unique of 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object>
# LS: <bound method Series.unique of 0        88+2
# 1        91+3
# 2        84+3
# 3         NaN
# 4        82+3
#          ...
# 18202    42+2
# 18203    45+2
# 18204    45+2
# 18205    47+2
# 18206    43+2
# Name: LS, Length: 18207, dtype: object>
# ST: <bound method Series.unique of 0        88+2
# 1        91+3
# 2        84+3
# 3         NaN
# 4        82+3
#          ...
# 18202    42+2
# 18203    45+2
# 18204    45+2
# 18205    47+2
# 18206    43+2
# Name: ST, Length: 18207, dtype: object>
# RS: <bound method Series.unique of 0        88+2
# 1        91+3
# 2        84+3
# 3         NaN
# 4        82+3
#          ...
# 18202    42+2
# 18203    45+2
# 18204    45+2
# 18205    47+2
# 18206    43+2
# Name: RS, Length: 18207, dtype: object>
# LW: <bound method Series.unique of 0        92+2
# 1        89+3
# 2        89+3
# 3         NaN
# 4        87+3
#          ...
# 18202    44+2
# 18203    39+2
# 18204    45+2
# 18205    47+2
# 18206    45+2
# Name: LW, Length: 18207, dtype: object>
# LF: <bound method Series.unique of 0        93+2
# 1        90+3
# 2        89+3
# 3         NaN
# 4        87+3
#          ...
# 18202    44+2
# 18203    42+2
# 18204    46+2
# 18205    46+2
# 18206    44+2
# Name: LF, Length: 18207, dtype: object>
# CF: <bound method Series.unique of 0        93+2
# 1        90+3
# 2        89+3
# 3         NaN
# 4        87+3
#          ...
# 18202    44+2
# 18203    42+2
# 18204    46+2
# 18205    46+2
# 18206    44+2
# Name: CF, Length: 18207, dtype: object>
# RF: <bound method Series.unique of 0        93+2
# 1        90+3
# 2        89+3
# 3         NaN
# 4        87+3
#          ...
# 18202    44+2
# 18203    42+2
# 18204    46+2
# 18205    46+2
# 18206    44+2
# Name: RF, Length: 18207, dtype: object>
# RW: <bound method Series.unique of 0        92+2
# 1        89+3
# 2        89+3
# 3         NaN
# 4        87+3
#          ...
# 18202    44+2
# 18203    39+2
# 18204    45+2
# 18205    47+2
# 18206    45+2
# Name: RW, Length: 18207, dtype: object>
# LAM: <bound method Series.unique of 0        93+2
# 1        88+3
# 2        89+3
# 3         NaN
# 4        88+3
#          ...
# 18202    45+2
# 18203    40+2
# 18204    44+2
# 18205    45+2
# 18206    45+2
# Name: LAM, Length: 18207, dtype: object>
# CAM: <bound method Series.unique of 0        93+2
# 1        88+3
# 2        89+3
# 3         NaN
# 4        88+3
#          ...
# 18202    45+2
# 18203    40+2
# 18204    44+2
# 18205    45+2
# 18206    45+2
# Name: CAM, Length: 18207, dtype: object>
# RAM: <bound method Series.unique of 0        93+2
# 1        88+3
# 2        89+3
# 3         NaN
# 4        88+3
#          ...
# 18202    45+2
# 18203    40+2
# 18204    44+2
# 18205    45+2
# 18206    45+2
# Name: RAM, Length: 18207, dtype: object>
# LM: <bound method Series.unique of 0        91+2
# 1        88+3
# 2        88+3
# 3         NaN
# 4        88+3
#          ...
# 18202    44+2
# 18203    38+2
# 18204    44+2
# 18205    46+2
# 18206    46+2
# Name: LM, Length: 18207, dtype: object>
# LCM: <bound method Series.unique of 0        84+2
# 1        81+3
# 2        81+3
# 3         NaN
# 4        87+3
#          ...
# 18202    45+2
# 18203    35+2
# 18204    38+2
# 18205    39+2
# 18206    45+2
# Name: LCM, Length: 18207, dtype: object>
# CM: <bound method Series.unique of 0        84+2
# 1        81+3
# 2        81+3
# 3         NaN
# 4        87+3
#          ...
# 18202    45+2
# 18203    35+2
# 18204    38+2
# 18205    39+2
# 18206    45+2
# Name: CM, Length: 18207, dtype: object>
# RCM: <bound method Series.unique of 0        84+2
# 1        81+3
# 2        81+3
# 3         NaN
# 4        87+3
#          ...
# 18202    45+2
# 18203    35+2
# 18204    38+2
# 18205    39+2
# 18206    45+2
# Name: RCM, Length: 18207, dtype: object>
# RM: <bound method Series.unique of 0        91+2
# 1        88+3
# 2        88+3
# 3         NaN
# 4        88+3
#          ...
# 18202    44+2
# 18203    38+2
# 18204    44+2
# 18205    46+2
# 18206    46+2
# Name: RM, Length: 18207, dtype: object>
# LWB: <bound method Series.unique of 0        64+2
# 1        65+3
# 2        65+3
# 3         NaN
# 4        77+3
#          ...
# 18202    44+2
# 18203    30+2
# 18204    34+2
# 18205    36+2
# 18206    46+2
# Name: LWB, Length: 18207, dtype: object>
# LDM: <bound method Series.unique of 0        61+2
# 1        61+3
# 2        60+3
# 3         NaN
# 4        77+3
#          ...
# 18202    45+2
# 18203    31+2
# 18204    30+2
# 18205    32+2
# 18206    46+2
# Name: LDM, Length: 18207, dtype: object>
# CDM: <bound method Series.unique of 0        61+2
# 1        61+3
# 2        60+3
# 3         NaN
# 4        77+3
#          ...
# 18202    45+2
# 18203    31+2
# 18204    30+2
# 18205    32+2
# 18206    46+2
# Name: CDM, Length: 18207, dtype: object>
# RDM: <bound method Series.unique of 0        61+2
# 1        61+3
# 2        60+3
# 3         NaN
# 4        77+3
#          ...
# 18202    45+2
# 18203    31+2
# 18204    30+2
# 18205    32+2
# 18206    46+2
# Name: RDM, Length: 18207, dtype: object>
# RWB: <bound method Series.unique of 0        64+2
# 1        65+3
# 2        65+3
# 3         NaN
# 4        77+3
#          ...
# 18202    44+2
# 18203    30+2
# 18204    34+2
# 18205    36+2
# 18206    46+2
# Name: RWB, Length: 18207, dtype: object>
# LB: <bound method Series.unique of 0        59+2
# 1        61+3
# 2        60+3
# 3         NaN
# 4        73+3
#          ...
# 18202    45+2
# 18203    29+2
# 18204    33+2
# 18205    35+2
# 18206    46+2
# Name: LB, Length: 18207, dtype: object>
# LCB: <bound method Series.unique of 0        47+2
# 1        53+3
# 2        47+3
# 3         NaN
# 4        66+3
#          ...
# 18202    45+2
# 18203    32+2
# 18204    28+2
# 18205    31+2
# 18206    47+2
# Name: LCB, Length: 18207, dtype: object>
# CB: <bound method Series.unique of 0        47+2
# 1        53+3
# 2        47+3
# 3         NaN
# 4        66+3
#          ...
# 18202    45+2
# 18203    32+2
# 18204    28+2
# 18205    31+2
# 18206    47+2
# Name: CB, Length: 18207, dtype: object>
# RCB: <bound method Series.unique of 0        47+2
# 1        53+3
# 2        47+3
# 3         NaN
# 4        66+3
#          ...
# 18202    45+2
# 18203    32+2
# 18204    28+2
# 18205    31+2
# 18206    47+2
# Name: RCB, Length: 18207, dtype: object>
# RB: <bound method Series.unique of 0        59+2
# 1        61+3
# 2        60+3
# 3         NaN
# 4        73+3
#          ...
# 18202    45+2
# 18203    29+2
# 18204    33+2
# 18205    35+2
# 18206    46+2
# Name: RB, Length: 18207, dtype: object>
# Crossing: <bound method Series.unique of 0        84.0
# 1        84.0
# 2        79.0
# 3        17.0
# 4        93.0
#          ...
# 18202    34.0
# 18203    23.0
# 18204    25.0
# 18205    44.0
# 18206    41.0
# Name: Crossing, Length: 18207, dtype: float64>
# Finishing: <bound method Series.unique of 0        95.0
# 1        94.0
# 2        87.0
# 3        13.0
# 4        82.0
#          ...
# 18202    38.0
# 18203    52.0
# 18204    40.0
# 18205    50.0
# 18206    34.0
# Name: Finishing, Length: 18207, dtype: float64>
# HeadingAccuracy: <bound method Series.unique of 0        70.0
# 1        89.0
# 2        62.0
# 3        21.0
# 4        55.0
#          ...
# 18202    40.0
# 18203    52.0
# 18204    46.0
# 18205    39.0
# 18206    46.0
# Name: HeadingAccuracy, Length: 18207, dtype: float64>
# ShortPassing: <bound method Series.unique of 0        90.0
# 1        81.0
# 2        84.0
# 3        50.0
# 4        92.0
#          ...
# 18202    49.0
# 18203    43.0
# 18204    38.0
# 18205    42.0
# 18206    48.0
# Name: ShortPassing, Length: 18207, dtype: float64>
# Volleys: <bound method Series.unique of 0        86.0
# 1        87.0
# 2        84.0
# 3        13.0
# 4        82.0
#          ...
# 18202    25.0
# 18203    36.0
# 18204    38.0
# 18205    40.0
# 18206    30.0
# Name: Volleys, Length: 18207, dtype: float64>
# Dribbling: <bound method Series.unique of 0        97.0
# 1        88.0
# 2        96.0
# 3        18.0
# 4        86.0
#          ...
# 18202    42.0
# 18203    39.0
# 18204    45.0
# 18205    51.0
# 18206    43.0
# Name: Dribbling, Length: 18207, dtype: float64>
# Curve: <bound method Series.unique of 0        93.0
# 1        81.0
# 2        88.0
# 3        21.0
# 4        85.0
#          ...
# 18202    30.0
# 18203    32.0
# 18204    38.0
# 18205    34.0
# 18206    40.0
# Name: Curve, Length: 18207, dtype: float64>
# FKAccuracy: <bound method Series.unique of 0        94.0
# 1        76.0
# 2        87.0
# 3        19.0
# 4        83.0
#          ...
# 18202    34.0
# 18203    20.0
# 18204    27.0
# 18205    32.0
# 18206    34.0
# Name: FKAccuracy, Length: 18207, dtype: float64>
# LongPassing: <bound method Series.unique of 0        87.0
# 1        77.0
# 2        78.0
# 3        51.0
# 4        91.0
#          ...
# 18202    45.0
# 18203    25.0
# 18204    28.0
# 18205    32.0
# 18206    44.0
# Name: LongPassing, Length: 18207, dtype: float64>
# BallControl: <bound method Series.unique of 0        96.0
# 1        94.0
# 2        95.0
# 3        42.0
# 4        91.0
#          ...
# 18202    43.0
# 18203    40.0
# 18204    44.0
# 18205    52.0
# 18206    51.0
# Name: BallControl, Length: 18207, dtype: float64>
# Acceleration: <bound method Series.unique of 0        91.0
# 1        89.0
# 2        94.0
# 3        57.0
# 4        78.0
#          ...
# 18202    54.0
# 18203    41.0
# 18204    70.0
# 18205    61.0
# 18206    57.0
# Name: Acceleration, Length: 18207, dtype: float64>
# SprintSpeed: <bound method Series.unique of 0        86.0
# 1        91.0
# 2        90.0
# 3        58.0
# 4        76.0
#          ...
# 18202    57.0
# 18203    39.0
# 18204    69.0
# 18205    60.0
# 18206    55.0
# Name: SprintSpeed, Length: 18207, dtype: float64>
# Agility: <bound method Series.unique of 0        91.0
# 1        87.0
# 2        96.0
# 3        60.0
# 4        79.0
#          ...
# 18202    60.0
# 18203    38.0
# 18204    50.0
# 18205    52.0
# 18206    55.0
# Name: Agility, Length: 18207, dtype: float64>
# Reactions: <bound method Series.unique of 0        95.0
# 1        96.0
# 2        94.0
# 3        90.0
# 4        91.0
#          ...
# 18202    49.0
# 18203    40.0
# 18204    47.0
# 18205    21.0
# 18206    51.0
# Name: Reactions, Length: 18207, dtype: float64>
# Balance: <bound method Series.unique of 0        95.0
# 1        70.0
# 2        84.0
# 3        43.0
# 4        77.0
#          ...
# 18202    76.0
# 18203    52.0
# 18204    58.0
# 18205    71.0
# 18206    63.0
# Name: Balance, Length: 18207, dtype: float64>
# ShotPower: <bound method Series.unique of 0        85.0
# 1        95.0
# 2        80.0
# 3        31.0
# 4        91.0
#          ...
# 18202    43.0
# 18203    41.0
# 18204    45.0
# 18205    64.0
# 18206    43.0
# Name: ShotPower, Length: 18207, dtype: float64>
# Jumping: <bound method Series.unique of 0        68.0
# 1        95.0
# 2        61.0
# 3        67.0
# 4        63.0
#          ...
# 18202    55.0
# 18203    47.0
# 18204    60.0
# 18205    42.0
# 18206    62.0
# Name: Jumping, Length: 18207, dtype: float64>
# Stamina: <bound method Series.unique of 0        72.0
# 1        88.0
# 2        81.0
# 3        43.0
# 4        90.0
#          ...
# 18202    40.0
# 18203    43.0
# 18204    55.0
# 18205    40.0
# 18206    47.0
# Name: Stamina, Length: 18207, dtype: float64>
# Strength: <bound method Series.unique of 0        59.0
# 1        79.0
# 2        49.0
# 3        64.0
# 4        75.0
#          ...
# 18202    47.0
# 18203    67.0
# 18204    32.0
# 18205    48.0
# 18206    60.0
# Name: Strength, Length: 18207, dtype: float64>
# LongShots: <bound method Series.unique of 0        94.0
# 1        93.0
# 2        82.0
# 3        12.0
# 4        91.0
#          ...
# 18202    38.0
# 18203    42.0
# 18204    45.0
# 18205    34.0
# 18206    32.0
# Name: LongShots, Length: 18207, dtype: float64>
# Aggression: <bound method Series.unique of 0        48.0
# 1        63.0
# 2        56.0
# 3        38.0
# 4        76.0
#          ...
# 18202    46.0
# 18203    47.0
# 18204    32.0
# 18205    33.0
# 18206    56.0
# Name: Aggression, Length: 18207, dtype: float64>
# Interceptions: <bound method Series.unique of 0        22.0
# 1        29.0
# 2        36.0
# 3        30.0
# 4        61.0
#          ...
# 18202    46.0
# 18203    16.0
# 18204    15.0
# 18205    22.0
# 18206    42.0
# Name: Interceptions, Length: 18207, dtype: float64>
# Positioning: <bound method Series.unique of 0        94.0
# 1        95.0
# 2        89.0
# 3        12.0
# 4        87.0
#          ...
# 18202    39.0
# 18203    46.0
# 18204    48.0
# 18205    44.0
# 18206    34.0
# Name: Positioning, Length: 18207, dtype: float64>
# Vision: <bound method Series.unique of 0        94.0
# 1        82.0
# 2        87.0
# 3        68.0
# 4        94.0
#          ...
# 18202    52.0
# 18203    33.0
# 18204    43.0
# 18205    47.0
# 18206    49.0
# Name: Vision, Length: 18207, dtype: float64>
# Penalties: <bound method Series.unique of 0        75.0
# 1        85.0
# 2        81.0
# 3        40.0
# 4        79.0
#          ...
# 18202    43.0
# 18203    43.0
# 18204    55.0
# 18205    50.0
# 18206    33.0
# Name: Penalties, Length: 18207, dtype: float64>
# Composure: <bound method Series.unique of 0        96.0
# 1        95.0
# 2        94.0
# 3        68.0
# 4        88.0
#          ...
# 18202    45.0
# 18203    42.0
# 18204    41.0
# 18205    46.0
# 18206    43.0
# Name: Composure, Length: 18207, dtype: float64>
# Marking: <bound method Series.unique of 0        33.0
# 1        28.0
# 2        27.0
# 3        15.0
# 4        68.0
#          ...
# 18202    40.0
# 18203    22.0
# 18204    32.0
# 18205    20.0
# 18206    40.0
# Name: Marking, Length: 18207, dtype: float64>
# StandingTackle: <bound method Series.unique of 0        28.0
# 1        31.0
# 2        24.0
# 3        21.0
# 4        58.0
#          ...
# 18202    48.0
# 18203    15.0
# 18204    13.0
# 18205    25.0
# 18206    43.0
# Name: StandingTackle, Length: 18207, dtype: float64>
# SlidingTackle: <bound method Series.unique of 0        26.0
# 1        23.0
# 2        33.0
# 3        13.0
# 4        51.0
#          ...
# 18202    47.0
# 18203    19.0
# 18204    11.0
# 18205    27.0
# 18206    50.0
# Name: SlidingTackle, Length: 18207, dtype: float64>
# GKDiving: <bound method Series.unique of 0         6.0
# 1         7.0
# 2         9.0
# 3        90.0
# 4        15.0
#          ...
# 18202    10.0
# 18203    10.0
# 18204     6.0
# 18205    14.0
# 18206    10.0
# Name: GKDiving, Length: 18207, dtype: float64>
# GKHandling: <bound method Series.unique of 0        11.0
# 1        11.0
# 2         9.0
# 3        85.0
# 4        13.0
#          ...
# 18202    13.0
# 18203     9.0
# 18204     5.0
# 18205     6.0
# 18206    15.0
# Name: GKHandling, Length: 18207, dtype: float64>
# GKKicking: <bound method Series.unique of 0        15.0
# 1        15.0
# 2        15.0
# 3        87.0
# 4         5.0
#          ...
# 18202     7.0
# 18203     9.0
# 18204    10.0
# 18205    14.0
# 18206     9.0
# Name: GKKicking, Length: 18207, dtype: float64>
# GKPositioning: <bound method Series.unique of 0        14.0
# 1        14.0
# 2        15.0
# 3        88.0
# 4        10.0
#          ...
# 18202     8.0
# 18203     5.0
# 18204     6.0
# 18205     8.0
# 18206    12.0
# Name: GKPositioning, Length: 18207, dtype: float64>
# GKReflexes: <bound method Series.unique of 0         8.0
# 1        11.0
# 2        11.0
# 3        94.0
# 4        13.0
#          ...
# 18202     9.0
# 18203    12.0
# 18204    13.0
# 18205     9.0
# 18206     9.0
# Name: GKReflexes, Length: 18207, dtype: float64>
# Release Clause: <bound method Series.unique of 0        €226.5M
# 1        €127.1M
# 2        €228.1M
# 3        €138.6M
# 4        €196.4M
#           ...
# 18202      €143K
# 18203      €113K
# 18204      €165K
# 18205      €143K
# 18206      €165K
# Name: Release Clause, Length: 18207, dtype: object>

# %%
# removing rows with position = null
data_df = data_df[data_df["Position"].notnull()]
data_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
data_df.describe().T
# Out:
#                             count           mean           std    min  \
# Unnamed: 0                18147.0    9089.239599   5257.923360    0.0
# ID                        18147.0  214279.818868  29970.319078   16.0
# Age                       18147.0      25.121122      4.669796   16.0
# Overall                   18147.0      66.253926      6.913320   46.0
# Potential                 18147.0      71.324076      6.132286   48.0
# Special                   18147.0    1598.002645    272.882706  731.0
# International Reputation  18147.0       1.113297      0.394150    1.0
# Weak Foot                 18147.0       2.947154      0.660498    1.0
# Skill Moves               18147.0       2.361492      0.756274    1.0
# Jersey Number             18147.0      19.546096     15.947765    1.0
# Crossing                  18147.0      49.738414     18.364255    5.0
# Finishing                 18147.0      45.550229     19.527445    2.0
# HeadingAccuracy           18147.0      52.300766     17.381753    4.0
# ShortPassing              18147.0      58.695432     14.696075    7.0
# Volleys                   18147.0      42.912217     17.695900    4.0
# Dribbling                 18147.0      55.375158     18.912224    4.0
# Curve                     18147.0      47.176283     18.396009    6.0
# FKAccuracy                18147.0      42.866038     17.480034    3.0
# LongPassing               18147.0      52.721386     15.325211    9.0
# BallControl               18147.0      58.374828     16.685643    5.0
# Acceleration              18147.0      64.612829     14.930320   12.0
# SprintSpeed               18147.0      64.726236     14.651776   12.0
# Agility                   18147.0      63.501295     14.768956   14.0
# Reactions                 18147.0      61.839147      9.011056   21.0
# Balance                   18147.0      63.964292     14.136073   16.0
# ShotPower                 18147.0      55.465201     17.235534    2.0
# Jumping                   18147.0      65.091034     11.822327   15.0
# Stamina                   18147.0      63.221579     15.896381   12.0
# Strength                  18147.0      65.318620     12.552479   17.0
# LongShots                 18147.0      47.113187     19.263142    3.0
# Aggression                18147.0      55.876068     17.366534   11.0
# Interceptions             18147.0      46.702761     20.697462    3.0
# Positioning               18147.0      49.962198     19.530469    2.0
# Vision                    18147.0      53.407781     14.146594   10.0
# Penalties                 18147.0      48.546371     15.703113    5.0
# Composure                 18147.0      58.651127     11.437138    3.0
# Marking                   18147.0      47.286053     19.900450    3.0
# StandingTackle            18147.0      47.701879     21.663630    2.0
# SlidingTackle             18147.0      45.666336     21.287961    3.0
# GKDiving                  18147.0      16.616906     17.698612    1.0
# GKHandling                18147.0      16.393839     16.909971    1.0
# GKKicking                 18147.0      16.233041     16.504103    1.0
# GKPositioning             18147.0      16.389651     17.037031    1.0
# GKReflexes                18147.0      16.712019     17.957521    1.0
#
#                                25%       50%       75%       max
# Unnamed: 0                  4536.5    9076.0   13662.5   18206.0
# ID                        200305.5  221740.0  236512.5  246620.0
# Age                           21.0      25.0      28.0      45.0
# Overall                       62.0      66.0      71.0      94.0
# Potential                     67.0      71.0      75.0      95.0
# Special                     1457.0    1635.0    1787.0    2346.0
# International Reputation       1.0       1.0       1.0       5.0
# Weak Foot                      3.0       3.0       3.0       5.0
# Skill Moves                    2.0       2.0       3.0       5.0
# Jersey Number                  8.0      17.0      26.0      99.0
# Crossing                      38.0      54.0      64.0      93.0
# Finishing                     30.0      49.0      62.0      95.0
# HeadingAccuracy               44.0      56.0      64.0      94.0
# ShortPassing                  54.0      62.0      68.0      93.0
# Volleys                       30.0      44.0      57.0      90.0
# Dribbling                     49.0      61.0      68.0      97.0
# Curve                         34.0      48.0      62.0      94.0
# FKAccuracy                    31.0      41.0      57.0      94.0
# LongPassing                   43.0      56.0      64.0      93.0
# BallControl                   54.0      63.0      69.0      96.0
# Acceleration                  57.0      67.0      75.0      97.0
# SprintSpeed                   57.0      67.0      75.0      96.0
# Agility                       55.0      66.0      74.0      96.0
# Reactions                     56.0      62.0      68.0      96.0
# Balance                       56.0      66.0      74.0      96.0
# ShotPower                     45.0      59.0      68.0      95.0
# Jumping                       58.0      66.0      73.0      95.0
# Stamina                       56.0      66.0      74.0      96.0
# Strength                      58.0      67.0      74.0      97.0
# LongShots                     33.0      51.0      62.0      94.0
# Aggression                    44.0      59.0      69.0      95.0
# Interceptions                 26.0      52.0      64.0      92.0
# Positioning                   38.0      55.0      64.0      95.0
# Vision                        44.0      55.0      64.0      94.0
# Penalties                     39.0      49.0      60.0      92.0
# Composure                     51.0      60.0      67.0      96.0
# Marking                       30.0      53.0      64.0      94.0
# StandingTackle                27.0      55.0      66.0      93.0
# SlidingTackle                 24.0      52.0      64.0      91.0
# GKDiving                       8.0      11.0      14.0      90.0
# GKHandling                     8.0      11.0      14.0      92.0
# GKKicking                      8.0      11.0      14.0      91.0
# GKPositioning                  8.0      11.0      14.0      90.0
# GKReflexes                     8.0      11.0      14.0      94.0

# %%
data_df['Position'].isnull().sum()
# Out:
# 0

# %%
# Following columns appear to be relevant for our analysis
rel_cols = ["Position", 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
            'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
            'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
            'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
            'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
            'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
            'GKKicking', 'GKPositioning', 'GKReflexes']

# %%
class_labels = {0: 'Goal Keeper', 1: 'Defender', 2: 'Mid-Fielder', 3: 'Forward'}

# %%
goalkeeper = 'GK'
forward = ['ST', 'LW', 'RW', 'LF', 'RF', 'RS','LS', 'CF']
midfielder = ['CM','RCM','LCM', 'CDM','RDM','LDM', 'CAM', 'LAM', 'RAM', 'RM', 'LM']
defender = ['CB', 'RCB', 'LCB', 'LWB', 'RWB', 'LB', 'RB']

# %%
#Assign labels to goalkeepers
data_df.loc[data_df["Position"] == "GK", "Position"] = 0

#Defenders
data_df.loc[data_df["Position"].isin(defender), "Position"] = 1

#Midfielders
data_df.loc[data_df["Position"].isin(midfielder), "Position"] = 2

#Forward
data_df.loc[data_df["Position"].isin(forward), "Position"] = 3

# Convert Column "Position" to numeric so that Pandas does not complain
data_df['Position'] = pd.to_numeric(data_df['Position'], downcast="integer")

# %%
data_df = data_df[rel_cols]
data_df.head()
# Out:
#    Position  Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  \
# 0         3       95.0             70.0          90.0     86.0       97.0
# 1         3       94.0             89.0          81.0     87.0       88.0
# 2         3       87.0             62.0          84.0     84.0       96.0
# 3         0       13.0             21.0          50.0     13.0       18.0
# 4         2       82.0             55.0          92.0     82.0       86.0
#
#    Curve  FKAccuracy  LongPassing  BallControl  ...  Penalties  Composure  \
# 0   93.0        94.0         87.0         96.0  ...       75.0       96.0
# 1   81.0        76.0         77.0         94.0  ...       85.0       95.0
# 2   88.0        87.0         78.0         95.0  ...       81.0       94.0
# 3   21.0        19.0         51.0         42.0  ...       40.0       68.0
# 4   85.0        83.0         91.0         91.0  ...       79.0       88.0
#
#    Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0     33.0            28.0           26.0       6.0        11.0       15.0
# 1     28.0            31.0           23.0       7.0        11.0       15.0
# 2     27.0            24.0           33.0       9.0         9.0       15.0
# 3     15.0            21.0           13.0      90.0        85.0       87.0
# 4     68.0            58.0           51.0      15.0        13.0        5.0
#
#    GKPositioning  GKReflexes
# 0           14.0         8.0
# 1           14.0        11.0
# 2           15.0        11.0
# 3           88.0        94.0
# 4           10.0        13.0
#
# [5 rows x 34 columns]

# %%
labels = {0: 'Goal Keeper', 1: 'Defender', 2: 'Mid-Fielder', 3: 'Forward'}

# %%
features_df = data_df.drop("Position", axis = 1)
labels = data_df['Position']

# %%
# splitting in train ans test datasets
X_train, X_test, y_train, y_test = train_test_split(features_df, labels,
                                     stratify=labels,
                                     test_size=TEST_SIZE, 
                                     random_state=RANDOM_STATE )
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14517, 33), (3630, 33), (14517,), (3630,))

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
fig = plt.figure(figsize=(8,8))
data_df['Position'].value_counts().plot(kind = "bar");

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((14517, 33), (3630, 33), (14517,), (3630,))

# %% [markdown]
# # Prepare Model

# %% [markdown]
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/InputLayer

# %%
# tf.keras.layers.InputLayer(
#     shape=None,
#     batch_size=None,
#     dtype=None,
#     sparse=None,
#     batch_shape=None,
#     input_tensor=None,
#     name=None,
#     **kwargs
# )

# %%
k_init = tf.keras.initializers.GlorotUniform(seed=RANDOM_STATE)
k_reg = tf.keras.regularizers.L1L2(l1=L1_LAMBDA, l2=L2_LAMBDA)

# %% [markdown]
# ## Implement L2
#
# - To implement Kernal Regularizer:
# - Lasso - l1
# - Ridge - l2
# - Elastic Net - l1l2

# %%
# # Calling class Sequential and pass all layers as a list
# model = tf.keras.models.Sequential([
#   tf.keras.layers.InputLayer(input_shape = [33,]),
#   tf.keras.layers.Dense(33, activation='relu', kernel_initializer = k_init, kernel_regularizer = 'l2'),
#   # tf.keras.layers.ReLU(),
#   tf.keras.layers.Dense(23, activation='relu', kernel_initializer = k_init, kernel_regularizer = 'l2'),
#   tf.keras.layers.Dense(12, activation='relu', kernel_initializer = k_init, kernel_regularizer = 'l2'),
#   tf.keras.layers.Dense(4, activation='relu', kernel_initializer = k_init, kernel_regularizer = 'l2'),
#   tf.keras.layers.Dense(4)
# ])

# %%
# Calling class Sequential and pass all layers as a list
model = tf.keras.models.Sequential([
    ### -----------------
    ### Input Layer
    ### -----------------
  tf.keras.layers.InputLayer(input_shape = [33,]),
    ### -----------------
    ### Set 1
    ### -----------------
  tf.keras.layers.Dense(33, activation='relu', kernel_initializer = k_init, kernel_regularizer = k_reg),
  # tf.keras.layers.ReLU(),
     ### -----------------
    ### Set 2
    ### -----------------
  tf.keras.layers.Dense(23, activation='relu', kernel_initializer = k_init, kernel_regularizer = k_reg),
     ### -----------------
    ### set 3
    ### -----------------
  tf.keras.layers.Dense(12, activation='relu', kernel_initializer = k_init, kernel_regularizer = k_reg),
     ### -----------------
    ### Set 4
    ### -----------------
  tf.keras.layers.Dense(4, activation='relu', kernel_initializer = k_init, kernel_regularizer = k_reg),
  tf.keras.layers.Dense(4)
])

# %%
model(X_train[:1])
# Out:
# <tf.Tensor: shape=(1, 4), dtype=float32, numpy=
# array([[ 0.17435771, -0.11916332,  0.08697547, -0.21939021]],
#       dtype=float32)>

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA)

# %%
history = model.fit(X_train, y_train, validation_data=[X_test,y_test], batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=2)
# Out:
# Epoch 1/101
# 454/454 - 3s - loss: 0.9369 - accuracy: 0.7795 - val_loss: 0.6311 - val_accuracy: 0.8639 - 3s/epoch - 6ms/step
# Epoch 2/101
# 454/454 - 1s - loss: 0.5681 - accuracy: 0.8693 - val_loss: 0.5295 - val_accuracy: 0.8614 - 1s/epoch - 3ms/step
# Epoch 3/101
# 454/454 - 2s - loss: 0.5006 - accuracy: 0.8746 - val_loss: 0.5000 - val_accuracy: 0.8642 - 2s/epoch - 3ms/step
# Epoch 4/101
# 454/454 - 1s - loss: 0.4664 - accuracy: 0.8768 - val_loss: 0.4585 - val_accuracy: 0.8672 - 1s/epoch - 3ms/step
# Epoch 5/101
# 454/454 - 1s - loss: 0.4449 - accuracy: 0.8772 - val_loss: 0.4459 - val_accuracy: 0.8667 - 1s/epoch - 3ms/step
# Epoch 6/101
# 454/454 - 1s - loss: 0.4300 - accuracy: 0.8766 - val_loss: 0.4387 - val_accuracy: 0.8656 - 1s/epoch - 3ms/step
# Epoch 7/101
# 454/454 - 2s - loss: 0.4176 - accuracy: 0.8777 - val_loss: 0.4170 - val_accuracy: 0.8741 - 2s/epoch - 3ms/step
# Epoch 8/101
# 454/454 - 1s - loss: 0.4091 - accuracy: 0.8772 - val_loss: 0.4140 - val_accuracy: 0.8680 - 1s/epoch - 3ms/step
# Epoch 9/101
# 454/454 - 1s - loss: 0.3988 - accuracy: 0.8810 - val_loss: 0.4018 - val_accuracy: 0.8741 - 1s/epoch - 3ms/step
# Epoch 10/101
# 454/454 - 1s - loss: 0.3943 - accuracy: 0.8799 - val_loss: 0.4016 - val_accuracy: 0.8680 - 1s/epoch - 3ms/step
# Epoch 11/101
# 454/454 - 1s - loss: 0.3895 - accuracy: 0.8810 - val_loss: 0.3931 - val_accuracy: 0.8760 - 1s/epoch - 3ms/step
# Epoch 12/101
# 454/454 - 1s - loss: 0.3864 - accuracy: 0.8784 - val_loss: 0.3987 - val_accuracy: 0.8683 - 1s/epoch - 3ms/step
# Epoch 13/101
# 454/454 - 1s - loss: 0.3815 - accuracy: 0.8802 - val_loss: 0.3947 - val_accuracy: 0.8661 - 1s/epoch - 3ms/step
# Epoch 14/101
# 454/454 - 1s - loss: 0.3788 - accuracy: 0.8828 - val_loss: 0.3824 - val_accuracy: 0.8760 - 1s/epoch - 3ms/step
# Epoch 15/101
# 454/454 - 1s - loss: 0.3765 - accuracy: 0.8807 - val_loss: 0.3825 - val_accuracy: 0.8771 - 1s/epoch - 3ms/step
# Epoch 16/101
# 454/454 - 2s - loss: 0.3728 - accuracy: 0.8817 - val_loss: 0.3788 - val_accuracy: 0.8747 - 2s/epoch - 3ms/step
# Epoch 17/101
# 454/454 - 2s - loss: 0.3707 - accuracy: 0.8820 - val_loss: 0.3784 - val_accuracy: 0.8736 - 2s/epoch - 3ms/step
# Epoch 18/101
# 454/454 - 2s - loss: 0.3682 - accuracy: 0.8808 - val_loss: 0.3803 - val_accuracy: 0.8736 - 2s/epoch - 3ms/step
# Epoch 19/101
# 454/454 - 2s - loss: 0.3665 - accuracy: 0.8828 - val_loss: 0.3731 - val_accuracy: 0.8741 - 2s/epoch - 3ms/step
# Epoch 20/101
# 454/454 - 1s - loss: 0.3642 - accuracy: 0.8832 - val_loss: 0.3695 - val_accuracy: 0.8774 - 1s/epoch - 3ms/step
# Epoch 21/101
# 454/454 - 2s - loss: 0.3638 - accuracy: 0.8820 - val_loss: 0.3680 - val_accuracy: 0.8747 - 2s/epoch - 3ms/step
# Epoch 22/101
# 454/454 - 2s - loss: 0.3597 - accuracy: 0.8833 - val_loss: 0.3682 - val_accuracy: 0.8758 - 2s/epoch - 3ms/step
# Epoch 23/101
# 454/454 - 1s - loss: 0.3578 - accuracy: 0.8849 - val_loss: 0.3664 - val_accuracy: 0.8744 - 1s/epoch - 3ms/step
# Epoch 24/101
# 454/454 - 2s - loss: 0.3576 - accuracy: 0.8842 - val_loss: 0.3684 - val_accuracy: 0.8752 - 2s/epoch - 3ms/step
# Epoch 25/101
# 454/454 - 1s - loss: 0.3565 - accuracy: 0.8823 - val_loss: 0.3619 - val_accuracy: 0.8777 - 1s/epoch - 3ms/step
# Epoch 26/101
# 454/454 - 2s - loss: 0.3538 - accuracy: 0.8827 - val_loss: 0.3645 - val_accuracy: 0.8758 - 2s/epoch - 3ms/step
# Epoch 27/101
# 454/454 - 1s - loss: 0.3537 - accuracy: 0.8837 - val_loss: 0.3637 - val_accuracy: 0.8730 - 1s/epoch - 3ms/step
# Epoch 28/101
# 454/454 - 1s - loss: 0.3514 - accuracy: 0.8846 - val_loss: 0.3583 - val_accuracy: 0.8777 - 1s/epoch - 3ms/step
# Epoch 29/101
# 454/454 - 2s - loss: 0.3509 - accuracy: 0.8832 - val_loss: 0.3601 - val_accuracy: 0.8777 - 2s/epoch - 3ms/step
# Epoch 30/101
# 454/454 - 2s - loss: 0.3501 - accuracy: 0.8845 - val_loss: 0.3629 - val_accuracy: 0.8727 - 2s/epoch - 3ms/step
# Epoch 31/101
# 454/454 - 1s - loss: 0.3490 - accuracy: 0.8835 - val_loss: 0.3585 - val_accuracy: 0.8777 - 1s/epoch - 3ms/step
# Epoch 32/101
# 454/454 - 2s - loss: 0.3489 - accuracy: 0.8837 - val_loss: 0.3560 - val_accuracy: 0.8804 - 2s/epoch - 3ms/step
# Epoch 33/101
# 454/454 - 1s - loss: 0.3476 - accuracy: 0.8839 - val_loss: 0.3562 - val_accuracy: 0.8796 - 1s/epoch - 3ms/step
# Epoch 34/101
# 454/454 - 1s - loss: 0.3474 - accuracy: 0.8810 - val_loss: 0.3563 - val_accuracy: 0.8763 - 1s/epoch - 3ms/step
# Epoch 35/101
# 454/454 - 2s - loss: 0.3466 - accuracy: 0.8837 - val_loss: 0.3560 - val_accuracy: 0.8791 - 2s/epoch - 3ms/step
# Epoch 36/101
# 454/454 - 2s - loss: 0.3451 - accuracy: 0.8834 - val_loss: 0.3555 - val_accuracy: 0.8785 - 2s/epoch - 3ms/step
# Epoch 37/101
# 454/454 - 2s - loss: 0.3454 - accuracy: 0.8839 - val_loss: 0.3598 - val_accuracy: 0.8769 - 2s/epoch - 3ms/step
# Epoch 38/101
# 454/454 - 2s - loss: 0.3455 - accuracy: 0.8843 - val_loss: 0.3531 - val_accuracy: 0.8766 - 2s/epoch - 3ms/step
# Epoch 39/101
# 454/454 - 1s - loss: 0.3446 - accuracy: 0.8839 - val_loss: 0.3540 - val_accuracy: 0.8802 - 1s/epoch - 3ms/step
# Epoch 40/101
# 454/454 - 2s - loss: 0.3436 - accuracy: 0.8842 - val_loss: 0.3523 - val_accuracy: 0.8760 - 2s/epoch - 3ms/step
# Epoch 41/101
# 454/454 - 1s - loss: 0.3445 - accuracy: 0.8846 - val_loss: 0.3546 - val_accuracy: 0.8804 - 1s/epoch - 3ms/step
# Epoch 42/101
# 454/454 - 1s - loss: 0.3434 - accuracy: 0.8838 - val_loss: 0.3598 - val_accuracy: 0.8744 - 1s/epoch - 3ms/step
# Epoch 43/101
# 454/454 - 2s - loss: 0.3425 - accuracy: 0.8842 - val_loss: 0.3522 - val_accuracy: 0.8785 - 2s/epoch - 3ms/step
# Epoch 44/101
# 454/454 - 2s - loss: 0.3417 - accuracy: 0.8844 - val_loss: 0.3512 - val_accuracy: 0.8791 - 2s/epoch - 3ms/step
# Epoch 45/101
# 454/454 - 1s - loss: 0.3416 - accuracy: 0.8833 - val_loss: 0.3557 - val_accuracy: 0.8749 - 1s/epoch - 3ms/step
# Epoch 46/101
# 454/454 - 2s - loss: 0.3413 - accuracy: 0.8842 - val_loss: 0.3489 - val_accuracy: 0.8799 - 2s/epoch - 3ms/step
# Epoch 47/101
# 454/454 - 2s - loss: 0.3408 - accuracy: 0.8843 - val_loss: 0.3535 - val_accuracy: 0.8760 - 2s/epoch - 3ms/step
# Epoch 48/101
# 454/454 - 2s - loss: 0.3401 - accuracy: 0.8851 - val_loss: 0.3508 - val_accuracy: 0.8774 - 2s/epoch - 3ms/step
# Epoch 49/101
# 454/454 - 2s - loss: 0.3407 - accuracy: 0.8837 - val_loss: 0.3508 - val_accuracy: 0.8774 - 2s/epoch - 3ms/step
# Epoch 50/101
# 454/454 - 2s - loss: 0.3388 - accuracy: 0.8855 - val_loss: 0.3524 - val_accuracy: 0.8763 - 2s/epoch - 3ms/step
# Epoch 51/101
# 454/454 - 2s - loss: 0.3395 - accuracy: 0.8827 - val_loss: 0.3490 - val_accuracy: 0.8793 - 2s/epoch - 3ms/step
# Epoch 52/101
# 454/454 - 2s - loss: 0.3390 - accuracy: 0.8834 - val_loss: 0.3525 - val_accuracy: 0.8788 - 2s/epoch - 3ms/step
# Epoch 53/101
# 454/454 - 2s - loss: 0.3387 - accuracy: 0.8830 - val_loss: 0.3475 - val_accuracy: 0.8793 - 2s/epoch - 3ms/step
# Epoch 54/101
# 454/454 - 1s - loss: 0.3376 - accuracy: 0.8834 - val_loss: 0.3506 - val_accuracy: 0.8774 - 1s/epoch - 3ms/step
# Epoch 55/101
# 454/454 - 1s - loss: 0.3372 - accuracy: 0.8848 - val_loss: 0.3613 - val_accuracy: 0.8650 - 1s/epoch - 3ms/step
# Epoch 56/101
# 454/454 - 2s - loss: 0.3372 - accuracy: 0.8848 - val_loss: 0.3442 - val_accuracy: 0.8807 - 2s/epoch - 3ms/step
# Epoch 57/101
# 454/454 - 2s - loss: 0.3360 - accuracy: 0.8852 - val_loss: 0.3567 - val_accuracy: 0.8782 - 2s/epoch - 3ms/step
# Epoch 58/101
# 454/454 - 2s - loss: 0.3367 - accuracy: 0.8844 - val_loss: 0.3471 - val_accuracy: 0.8791 - 2s/epoch - 3ms/step
# Epoch 59/101
# 454/454 - 1s - loss: 0.3368 - accuracy: 0.8840 - val_loss: 0.3451 - val_accuracy: 0.8802 - 1s/epoch - 3ms/step
# Epoch 60/101
# 454/454 - 1s - loss: 0.3349 - accuracy: 0.8857 - val_loss: 0.3515 - val_accuracy: 0.8758 - 1s/epoch - 3ms/step
# Epoch 61/101
# 454/454 - 1s - loss: 0.3350 - accuracy: 0.8845 - val_loss: 0.3454 - val_accuracy: 0.8785 - 1s/epoch - 3ms/step
# Epoch 62/101
# 454/454 - 2s - loss: 0.3354 - accuracy: 0.8846 - val_loss: 0.3451 - val_accuracy: 0.8760 - 2s/epoch - 3ms/step
# Epoch 63/101
# 454/454 - 2s - loss: 0.3345 - accuracy: 0.8859 - val_loss: 0.3447 - val_accuracy: 0.8802 - 2s/epoch - 3ms/step
# Epoch 64/101
# 454/454 - 2s - loss: 0.3340 - accuracy: 0.8846 - val_loss: 0.3454 - val_accuracy: 0.8766 - 2s/epoch - 3ms/step
# Epoch 65/101
# 454/454 - 1s - loss: 0.3331 - accuracy: 0.8851 - val_loss: 0.3466 - val_accuracy: 0.8796 - 1s/epoch - 3ms/step
# Epoch 66/101
# 454/454 - 2s - loss: 0.3335 - accuracy: 0.8846 - val_loss: 0.3451 - val_accuracy: 0.8780 - 2s/epoch - 3ms/step
# Epoch 67/101
# 454/454 - 1s - loss: 0.3336 - accuracy: 0.8834 - val_loss: 0.3436 - val_accuracy: 0.8791 - 1s/epoch - 3ms/step
# Epoch 68/101
# 454/454 - 2s - loss: 0.3333 - accuracy: 0.8854 - val_loss: 0.3524 - val_accuracy: 0.8719 - 2s/epoch - 3ms/step
# Epoch 69/101
# 454/454 - 1s - loss: 0.3327 - accuracy: 0.8823 - val_loss: 0.3447 - val_accuracy: 0.8791 - 1s/epoch - 3ms/step
# Epoch 70/101
# 454/454 - 2s - loss: 0.3325 - accuracy: 0.8849 - val_loss: 0.3452 - val_accuracy: 0.8780 - 2s/epoch - 3ms/step
# Epoch 71/101
# 454/454 - 1s - loss: 0.3317 - accuracy: 0.8851 - val_loss: 0.3460 - val_accuracy: 0.8793 - 1s/epoch - 3ms/step
# Epoch 72/101
# 454/454 - 2s - loss: 0.3330 - accuracy: 0.8836 - val_loss: 0.3434 - val_accuracy: 0.8769 - 2s/epoch - 3ms/step
# Epoch 73/101
# 454/454 - 2s - loss: 0.3326 - accuracy: 0.8852 - val_loss: 0.3435 - val_accuracy: 0.8777 - 2s/epoch - 4ms/step
# Epoch 74/101
# 454/454 - 2s - loss: 0.3322 - accuracy: 0.8839 - val_loss: 0.3450 - val_accuracy: 0.8782 - 2s/epoch - 3ms/step
# Epoch 75/101
# 454/454 - 2s - loss: 0.3319 - accuracy: 0.8839 - val_loss: 0.3422 - val_accuracy: 0.8835 - 2s/epoch - 3ms/step
# Epoch 76/101
# 454/454 - 2s - loss: 0.3314 - accuracy: 0.8852 - val_loss: 0.3424 - val_accuracy: 0.8807 - 2s/epoch - 3ms/step
# Epoch 77/101
# 454/454 - 2s - loss: 0.3319 - accuracy: 0.8857 - val_loss: 0.3429 - val_accuracy: 0.8796 - 2s/epoch - 3ms/step
# Epoch 78/101
# 454/454 - 2s - loss: 0.3314 - accuracy: 0.8847 - val_loss: 0.3406 - val_accuracy: 0.8788 - 2s/epoch - 3ms/step
# Epoch 79/101
# 454/454 - 1s - loss: 0.3309 - accuracy: 0.8848 - val_loss: 0.3423 - val_accuracy: 0.8763 - 1s/epoch - 3ms/step
# Epoch 80/101
# 454/454 - 1s - loss: 0.3299 - accuracy: 0.8844 - val_loss: 0.3449 - val_accuracy: 0.8777 - 1s/epoch - 3ms/step
# Epoch 81/101
# 454/454 - 2s - loss: 0.3306 - accuracy: 0.8852 - val_loss: 0.3406 - val_accuracy: 0.8799 - 2s/epoch - 4ms/step
# Epoch 82/101
# 454/454 - 2s - loss: 0.3306 - accuracy: 0.8857 - val_loss: 0.3406 - val_accuracy: 0.8799 - 2s/epoch - 3ms/step
# Epoch 83/101
# 454/454 - 1s - loss: 0.3300 - accuracy: 0.8843 - val_loss: 0.3449 - val_accuracy: 0.8780 - 1s/epoch - 3ms/step
# Epoch 84/101
# 454/454 - 1s - loss: 0.3311 - accuracy: 0.8840 - val_loss: 0.3424 - val_accuracy: 0.8785 - 1s/epoch - 3ms/step
# Epoch 85/101
# 454/454 - 1s - loss: 0.3302 - accuracy: 0.8845 - val_loss: 0.3453 - val_accuracy: 0.8730 - 1s/epoch - 3ms/step
# Epoch 86/101
# 454/454 - 1s - loss: 0.3304 - accuracy: 0.8829 - val_loss: 0.3407 - val_accuracy: 0.8796 - 1s/epoch - 3ms/step
# Epoch 87/101
# 454/454 - 2s - loss: 0.3292 - accuracy: 0.8845 - val_loss: 0.3463 - val_accuracy: 0.8769 - 2s/epoch - 3ms/step
# Epoch 88/101
# 454/454 - 1s - loss: 0.3285 - accuracy: 0.8859 - val_loss: 0.3468 - val_accuracy: 0.8716 - 1s/epoch - 3ms/step
# Epoch 89/101
# 454/454 - 1s - loss: 0.3284 - accuracy: 0.8846 - val_loss: 0.3507 - val_accuracy: 0.8747 - 1s/epoch - 3ms/step
# Epoch 90/101
# 454/454 - 2s - loss: 0.3291 - accuracy: 0.8858 - val_loss: 0.3404 - val_accuracy: 0.8793 - 2s/epoch - 4ms/step
# Epoch 91/101
# 454/454 - 1s - loss: 0.3308 - accuracy: 0.8845 - val_loss: 0.3406 - val_accuracy: 0.8793 - 1s/epoch - 3ms/step
# Epoch 92/101
# 454/454 - 2s - loss: 0.3295 - accuracy: 0.8848 - val_loss: 0.3485 - val_accuracy: 0.8730 - 2s/epoch - 3ms/step
# Epoch 93/101
# 454/454 - 1s - loss: 0.3298 - accuracy: 0.8850 - val_loss: 0.3504 - val_accuracy: 0.8749 - 1s/epoch - 3ms/step
# Epoch 94/101
# 454/454 - 1s - loss: 0.3289 - accuracy: 0.8860 - val_loss: 0.3413 - val_accuracy: 0.8788 - 1s/epoch - 3ms/step
# Epoch 95/101
# 454/454 - 1s - loss: 0.3278 - accuracy: 0.8848 - val_loss: 0.3392 - val_accuracy: 0.8824 - 1s/epoch - 3ms/step
# Epoch 96/101
# 454/454 - 1s - loss: 0.3280 - accuracy: 0.8874 - val_loss: 0.3390 - val_accuracy: 0.8774 - 1s/epoch - 3ms/step
# Epoch 97/101
# 454/454 - 2s - loss: 0.3279 - accuracy: 0.8872 - val_loss: 0.3466 - val_accuracy: 0.8758 - 2s/epoch - 3ms/step
# Epoch 98/101
# 454/454 - 1s - loss: 0.3278 - accuracy: 0.8854 - val_loss: 0.3402 - val_accuracy: 0.8736 - 1s/epoch - 3ms/step
# Epoch 99/101
# 454/454 - 2s - loss: 0.3285 - accuracy: 0.8845 - val_loss: 0.3398 - val_accuracy: 0.8769 - 2s/epoch - 3ms/step
# Epoch 100/101
# 454/454 - 1s - loss: 0.3268 - accuracy: 0.8850 - val_loss: 0.3387 - val_accuracy: 0.8782 - 1s/epoch - 3ms/step
# Epoch 101/101
# 454/454 - 2s - loss: 0.3275 - accuracy: 0.8844 - val_loss: 0.3458 - val_accuracy: 0.8780 - 2s/epoch - 3ms/step

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.936859  0.779500  0.631058      0.863912
# 1  0.568110  0.869326  0.529457      0.861432
# 2  0.500646  0.874561  0.499973      0.864187
# 3  0.466417  0.876765  0.458496      0.867218
# 4  0.444943  0.877247  0.445929      0.866667

# %%
fn_plot_tf_hist(loss_df)


# the red line should follow the blue line as closely as poosible till the end. At the end, it should diverge a bit

# %%
loss_df[loss_df['val_loss'] == loss_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 99  0.326772  0.885031    0.3387      0.878237
