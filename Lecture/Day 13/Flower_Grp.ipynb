# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
# By Pramod Sharma : pramod.sharma@prasami.com

###-----------------
### Import Libraries
###-----------------

import os
import datetime
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# from utils.log_event import fn_log_event


# verify if the directory exists
def fn_dir_exists(_dir):
    '''
    Args:
    	_dir: path if a directory
     '''

    res = os.path.exists(_dir)

    fn_log_event ('-- Directory "{}" exist : {}'.format(_dir, res), 'debug')

    if not res:

        fn_log_event ('-- Directory "{}" does not exists.'.format(_dir), 'debug')

        sys.exit('-- Directory "{}" does not exists.'.format(_dir))

    return res



def fn_file_exists(_file):
    '''
        verify if the file exists
    '''
    res = os.path.exists(_file)

    fn_log_event ('-- File "{}" exist : {}'.format(_file, res), 'debug')

    if not res:

        fn_log_event ('-- File "{}" does not exists.'.format(_file), 'debug')

        sys.exit('-- File "{}" does not exists.'.format(_file))

    return res


###-----------------------------
### Verify or create a directory
###-----------------------------
def fn_verify_dir(_path : str):
    '''
    Arg:
        path: path to verify the directory
    returns:
        create dir if it does not exists
    '''
    if os.path.exists(_path): # check if the path exists. Maybe a file or a folder

        print(_path, ' exists') # advised the user

    else:

        os.makedirs(_path) # create the path

        print("Created folder : ", _path)

###------------------------------------------------
### Plot Loss Curve using Tensorflow history object
###------------------------------------------------
def fn_plot_tf_hist(hist_df):

    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index
            so that even if the column names are different it will not throw exceptions.
    '''

    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm

    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]

    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y3].to_numpy()[0] + offset), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y4].to_numpy()[0]-offset), # location of text
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow


    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')

    plt.tight_layout()



###------------------------------
### Plot Loss Curve using pytorch
###------------------------------
def fn_plot_torch_hist(hist_df):

    # instantiate figure
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch
    props = dict(boxstyle='round', facecolor='cyan', alpha=0.5)

    # columns
    x = hist_df.columns[0]
    y1 = hist_df.columns[1]
    y2 = hist_df.columns[2]
    y3 = hist_df.columns[3]
    y4 = hist_df.columns[4]

    # Where was min loss
    best = hist_df[hist_df[y2] == hist_df[y2].min()]
    best = best.drop_duplicates(subset=y2)
    # pick first axis
    ax = axes[0]

    # Plot all losses
    hist_df.plot(x = x, y = [y1, y2], ax = ax)

    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y2].min())
    y_max = max(hist_df[y1].max(), hist_df[y2].max())
    offset = (y_max-y_min)/10.0

    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y2]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y2].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y2].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()+ offset, best[y2].to_numpy()[0]+offset), # location of text
                fontsize=14,va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor='cyan', shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best[x].to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel(x.title())
    ax.set_ylabel(y1.title())
    ax.set_title('Errors')
    ax.grid()
    ax.legend(loc = 'upper left') # model legend to upper left

    # pick second axis
    ax = axes[1]

    # Plot accuracies
    hist_df.plot(x = x, y = [y3, y4], ax = ax)

    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y3],
                           hist_df.iloc[-1][y4]) #text to plot

    # calculate offset for arroe
    y_min = min(hist_df[y3].min(), hist_df[y4].min())
    y_max = max(hist_df[y3].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # place a text box in lower middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=12,
            verticalalignment='top', bbox=props)

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best[x].to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best[x].to_numpy()- offset, best[y4].to_numpy()[0]-offset), # location of text
                fontsize=14,va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor='cyan', shrink=0.05)) # arrow


    # Draw a vertical line at best value
    ax.axvline(x = best[x].to_numpy(),
               color = 'green',
               linestyle='-.', lw = 3)

    # Labels
    ax.set_xlabel(x.title())
    ax.set_ylabel(y3.title())
    ax.set_title('Accuracies')
    ax.grid();
    ax.legend(loc = 'lower left')

    plt.tight_layout()



###---------------------------------------------------
### Plot count of classes in training and testing sets
###---------------------------------------------------
def fn_plot_labels(tr_ds, ts_ds, class_names = None):

    '''
        Args:
            tr_ds :  Training Dataset
            ts_ds : Testing dataset
        Returns : none
    '''

    # create figure and axes
    fig, axes = plt.subplots(1,2, figsize = (15,5))

    # get names of the classes
    if not class_names:
        tr_class_names = tr_ds.class_names
        ts_class_names = tr_ds.class_names

    # pick first axis
    ax = axes[0]

    # create dict of training labels
    class_counts = {}
    for imgs, lbls in tr_ds:
        for lbl in lbls.numpy():
            class_counts[lbl] = class_counts.get(lbl, 0) +1

    # bar plot
    ax.bar(tr_class_names, [class_counts.get(i, 0) for i in range(len(tr_class_names))],
           align='center',color = 'DarkBlue', alpha = 0.7)

    # add title
    ax.set_title('Training Set')

    # grids make it look good
    ax.grid()


    #pick second image
    ax = axes[1]

    # create dict of training labels
    class_counts = {}
    for imgs, lbls in ts_ds:
        for lbl in lbls.numpy():
            class_counts[lbl] = class_counts.get(lbl, 0) +1

    # bar plot
    ax.bar(ts_class_names, [class_counts.get(i, 0) for i in range(len(ts_class_names))],
           align='center',color = 'orange', alpha = 0.7)

    # add title
    ax.set_title('Test Set')


    # grids make it look good
    ax.grid()

    # fit the subplot(s) in to the figure area
    plt.tight_layout()

    # display all open figures
    plt.show()

def fn_convert_timestamp(tstr):
    '''
        Function to conver string of form "2015-11-12 1444"
    '''

    return datetime.strptime(tstr, "%Y-%m-%d_%H%M")

###----------------------
### Plot confusion matrix
###----------------------
def fn_plot_confusion_matrix(y_true, y_pred, labels):
    '''
    Args:
        y_true: Ground Truth
        y_pred : Predictions
        labels : dictonary
                  {0: 'Goal Keeper',
                  1: 'Defender',
                  2: 'Mid-Fielder',
                  3: 'Forward'}

    '''

    cm  = confusion_matrix(y_true, y_pred)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                  display_labels=labels.values())

    fig, ax = plt.subplots(figsize = (6,6))

    disp.plot(ax = ax, cmap = 'Blues', xticks_rotation = 'vertical', colorbar=False)
    # Disable the grid
    ax.grid(False)

    plt.show();

# %%
###-----------------
### Import Libraries
# ###-----------------
# import sys
# sys.path.insert(0, r'G:\My Drive\DNN')

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import tensorflow as tf

# from utils.helper import fn_plot_tf_hist, fn_plot_confusion_matrix

# %%
###----------------------
### Some basic parameters
###----------------------


inpDir = '../input'
outDir = '../output'
modelDir = './models'
subDir = 'flower_photos'
altName = 'cnn_base'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well

TEST_SIZE = 0.2

ALPHA = 0.001
EPOCHS = 100 # number of cycles to run
PATIENCE = 20
LR_PATIENCE = 10
FACTOR_LR = 0.5
BATCH_SIZE = 32 # inline of Training Rows being 60000
IMG_HEIGHT = 190 # ??????????????
IMG_WIDTH = 190 # ??????????????

REG_LAMBDA = 0.001
PATIENCE = 20 # EarlyStopping -> If n no. of epochs give similar o/p, then it will stop the execution
LR_PATIENCE = 10
LR_FACTOR = 0.1

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (15,10),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

CMAP = plt.cm.coolwarm

plt.rcParams.update(params) # update rcParams

plt.style.use('seaborn-v0_8-darkgrid') # plt.style.use('ggplot')

# %%
physical_devices = tf.config.list_physical_devices('GPU')

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
def fn_plot_label(tr_ds, ts_ds):

    plt.figure(figsize = (15,5)) # instantiate the figure

    plt.subplot(1,2,1) # first out of 2

    train_labels = tf.concat([lbl for img, lbl in tr_ds], axis = 0).numpy() # get the labels

    unique, _, counts = tf.unique_with_counts(train_labels) # get counts

    plt.bar(range(len(unique)), counts, align='center', color = 'DarkBlue') # barplot the counts

    plt.xticks(range(len(unique)), class_names)

    plt.title('Training Set')

    plt.subplot(1,2,2)

    test_labels = tf.concat([lbl for img, lbl in ts_ds], axis = 0).numpy()

    unique, _, counts = tf.unique_with_counts(test_labels)

    plt.bar(range(len(unique)), counts, align='center', color = 'Orange')

    plt.xticks(range(len(unique)), class_names)

    plt.title('Test Set')

# %%
import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                   fname='flower_photos',
                                   untar=True)
data_dir = pathlib.Path(data_dir)


# data_dir = os.path.join(inpDir, subDir)
# data_dir

# %%
os.listdir(data_dir)
# Out:
# ['roses', 'daisy', 'sunflowers', 'dandelion', 'LICENSE.txt', 'tulips']

# %%
# create training data
train_ds =tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, # path the the data directory
    validation_split=TEST_SIZE, # what ratio of validation data
    subset='training', # purpose
    seed=RANDOM_STATE,
    image_size=[IMG_HEIGHT, IMG_WIDTH], ## @@@ WHAT!
    batch_size=BATCH_SIZE
)
# test data
test_ds =tf.keras.preprocessing.image_dataset_from_directory(
    data_dir, # path the the data directory
    validation_split=TEST_SIZE, # what ratio of validation data
    subset='validation', # purpose
    seed=RANDOM_STATE,
    image_size=[IMG_HEIGHT, IMG_WIDTH], ## @@@ WHAT!
    batch_size=BATCH_SIZE
)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %%
# To be deleted

# labels = []
# for count, data in enumerate(train_ds):
#   imgs, lbls = data
#   # print (count, ':', imgs.shape, lbls.shape)
#   labels.append(lbls)

# unique, A, counts = tf.unique.

# %%
# is it picking class names
class_names = train_ds.class_names
class_names
# Out:
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
class_dict = {k: v for k, v in enumerate(class_names)}
class_dict
# Out:
# {0: 'daisy', 1: 'dandelion', 2: 'roses', 3: 'sunflowers', 4: 'tulips'}

# %%
num_classes = len(class_names)

# %%
# plt.figure(figsize=(15,8))

# for images, labels in train_ds.take(1):
#     for i in range (BATCH_SIZE):
#         plt.subplot(int(BATCH_SIZE/8), 8, i +1)
#         plt.grid(False)
#         plt.imshow(images[i].numpy().astype('uint8'))
#         plt.title(class_names[labels[i]])
#         plt.axis('off')
#     plt.tight_layout()
# plt.show()

# %%
# plt.figure(figsize=(15,8))

# for images, labels in test_ds.take(1): # get me one batch

#     for i in range (BATCH_SIZE): # loop over batch

#         plt.subplot(int(BATCH_SIZE/8), 8, i +1) # access the axis

#         plt.grid(False) # no to grid

#         plt.imshow(images[i].numpy().astype('uint8')) # show image convert to numpy and int

#         plt.title(class_names[labels[i]])

#         plt.axis('off')

#     plt.tight_layout()

# plt.show()

# %%
fn_plot_label(train_ds, test_ds)

# %%
input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)
input_shape
# Out:
# (190, 190, 3)

# %%
def build_model(input_shape, num_classes):

  knl_init = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)
  model = tf.keras.Sequential()

  dor1 = 0.08
  dor2 = 0.16
  dor3 = 0.24
  dor4 = 0.32
  dor5 = 0.4
  dor6 = 0.48
  # dor7 = 0.54
  # dor8 = 0.6

  # Pre-processing
  model.add(tf.keras.layers.Rescaling(1./255.))

  model.add(tf.keras.layers.RandomRotation((-0.5, 0.5), fill_mode = 'nearest', seed = RANDOM_STATE))

  ####
  # Set 1
  ####
  model.add(tf.keras.layers.Conv2D(
      32, (3, 3), # filters = 32; kernel_size = 3
      padding='same',
      # activation= 'relu',
      kernel_initializer=knl_init,
      input_shape = input_shape,
      )) # o/p: 188 x 188 x 32

  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2))) # 94 x 94 x 32
  model.add(tf.keras.layers.Dropout(dor1))
  model.add(tf.keras.layers.Activation('swish'))

  ####
  # Set 2
  ####
  model.add(tf.keras.layers.Conv2D(
      64, (3,3), # filters = 64; kernel_size = 3
      padding='valid',
      kernel_initializer=knl_init,
      # activation= 'relu'
      )) # o/p: 92 x 92 x 64

  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.MaxPooling2D()) # 46 x 46 x 64
  model.add(tf.keras.layers.Dropout(dor2))
  model.add(tf.keras.layers.Activation('swish'))

  ####
  # Set 3
  ####
  model.add(tf.keras.layers.Conv2D(
      128, (3,3), # filters = 128; kernel_size = 3
      padding='valid',
      kernel_initializer=knl_init,
      # activation= 'relu'
      )) # o/p: 44 x 44 x 128

  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.MaxPooling2D()) # 22 x 22 x 128
  model.add(tf.keras.layers.Dropout(dor3))
  model.add(tf.keras.layers.Activation('swish'))

  ####
  # Set 4
  ####
  model.add(tf.keras.layers.Conv2D(
      256, (3,3), # filters = 256; kernel_size = 3
      padding='valid',
      kernel_initializer=knl_init,
      # activation= 'relu'
      )) # o/p: 20 x 20 x 256

  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.MaxPooling2D()) # 10 x 10 x 256
  model.add(tf.keras.layers.Dropout(dor4))
  model.add(tf.keras.layers.Activation('swish'))

  ####
  # Set 5
  ####
  model.add(tf.keras.layers.Conv2D(
      512, (3,3), # filters = 512; kernel_size = 3
      padding='valid',
      kernel_initializer=knl_init,
      # activation= 'relu'
      )) # o/p: 8 x 8 x 512

  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.MaxPooling2D()) # 4 x 4 x 512
  model.add(tf.keras.layers.Dropout(dor5))
  model.add(tf.keras.layers.Activation('swish'))

  ####
  # Set 6
  ####
  model.add(tf.keras.layers.Conv2D(
      1024, (3,3), # filters = 1024; kernel_size = 3
      padding='valid',
      kernel_initializer=knl_init,
      # activation= 'relu'
      )) # o/p: 2 x 2 x 1024


  model.add(tf.keras.layers.BatchNormalization())
  model.add(tf.keras.layers.Dropout(dor6))
  model.add(tf.keras.layers.Activation('swish'))
  ####
  # HEAD
  ####
  # Flatten
  model.add(tf.keras.layers.Flatten())

  # Dense 1
  model.add(tf.keras.layers.Dense(512, kernel_initializer=knl_init))
  model.add(tf.keras.layers.BatchNormalization())
  # model.add(tf.keras.layers.Dropout(dor7))
  model.add(tf.keras.layers.Activation('swish'))
  # Dense 2
  model.add(tf.keras.layers.Dense(64, kernel_initializer=knl_init))
  model.add(tf.keras.layers.BatchNormalization())
  # model.add(tf.keras.layers.Dropout(dor8))
  model.add(tf.keras.layers.Activation('swish'))
  # Dense 3
  model.add(tf.keras.layers.Dense(num_classes))

  return model

# %%
model = build_model(input_shape, num_classes)
model

# %%
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

model.compile(loss= loss_fn,
              optimizer= 'adam',
              metrics=['accuracy'])

# %%
checkpoint_path = os.path.join('/content/ckpt', 'weights_tf')

model_ckpt_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
    mode='auto' # how to track the monitoring -> auto = autoset;
)

es_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    # min_delta=0, It defines for how many decimal places we want to be considered the monitor value
    patience=PATIENCE,
    verbose=1,
    mode='auto',
    restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=LR_FACTOR,
    patience=LR_PATIENCE,
    verbose=1,
)


# log_dir = os.path.join('/content/ckpt', 'fit')
# tb_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq =1)

# %%
history = model.fit(train_ds,
                    epochs= EPOCHS,
                    batch_size = BATCH_SIZE,
                    callbacks = [model_ckpt_callback,
                                 es_callback,
                                 lr_callback],
                    validation_data=test_ds)
# Out:
# Epoch 1/100
# 92/92 [==============================] - ETA: 0s - loss: 1.1802 - accuracy: 0.5160
# Epoch 1: val_loss improved from inf to 5.45776, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 32s 169ms/step - loss: 1.1802 - accuracy: 0.5160 - val_loss: 5.4578 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 2/100
# 92/92 [==============================] - ETA: 0s - loss: 1.0161 - accuracy: 0.5892
# Epoch 2: val_loss improved from 5.45776 to 4.26870, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 133ms/step - loss: 1.0161 - accuracy: 0.5892 - val_loss: 4.2687 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 3/100
# 92/92 [==============================] - ETA: 0s - loss: 0.9563 - accuracy: 0.6168
# Epoch 3: val_loss improved from 4.26870 to 3.70394, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 133ms/step - loss: 0.9563 - accuracy: 0.6168 - val_loss: 3.7039 - val_accuracy: 0.2384 - lr: 0.0010
# Epoch 4/100
# 92/92 [==============================] - ETA: 0s - loss: 0.8821 - accuracy: 0.6587
# Epoch 4: val_loss improved from 3.70394 to 2.48218, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 12s 133ms/step - loss: 0.8821 - accuracy: 0.6587 - val_loss: 2.4822 - val_accuracy: 0.2548 - lr: 0.0010
# Epoch 5/100
# 92/92 [==============================] - ETA: 0s - loss: 0.8518 - accuracy: 0.6642
# Epoch 5: val_loss improved from 2.48218 to 1.43303, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 133ms/step - loss: 0.8518 - accuracy: 0.6642 - val_loss: 1.4330 - val_accuracy: 0.4591 - lr: 0.0010
# Epoch 6/100
# 92/92 [==============================] - ETA: 0s - loss: 0.8275 - accuracy: 0.6686
# Epoch 6: val_loss improved from 1.43303 to 1.05247, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 136ms/step - loss: 0.8275 - accuracy: 0.6686 - val_loss: 1.0525 - val_accuracy: 0.5736 - lr: 0.0010
# Epoch 7/100
# 92/92 [==============================] - ETA: 0s - loss: 0.8150 - accuracy: 0.6781
# Epoch 7: val_loss improved from 1.05247 to 0.85755, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 137ms/step - loss: 0.8150 - accuracy: 0.6781 - val_loss: 0.8576 - val_accuracy: 0.6662 - lr: 0.0010
# Epoch 8/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7901 - accuracy: 0.6822
# Epoch 8: val_loss did not improve from 0.85755
# 92/92 [==============================] - 12s 128ms/step - loss: 0.7901 - accuracy: 0.6822 - val_loss: 0.9160 - val_accuracy: 0.6376 - lr: 0.0010
# Epoch 9/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7658 - accuracy: 0.6972
# Epoch 9: val_loss did not improve from 0.85755
# 92/92 [==============================] - 12s 129ms/step - loss: 0.7658 - accuracy: 0.6972 - val_loss: 0.9054 - val_accuracy: 0.6540 - lr: 0.0010
# Epoch 10/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7495 - accuracy: 0.7061
# Epoch 10: val_loss improved from 0.85755 to 0.82818, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 133ms/step - loss: 0.7495 - accuracy: 0.7061 - val_loss: 0.8282 - val_accuracy: 0.6771 - lr: 0.0010
# Epoch 11/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7518 - accuracy: 0.7033
# Epoch 11: val_loss did not improve from 0.82818
# 92/92 [==============================] - 12s 129ms/step - loss: 0.7518 - accuracy: 0.7033 - val_loss: 0.9237 - val_accuracy: 0.6294 - lr: 0.0010
# Epoch 12/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7126 - accuracy: 0.7153
# Epoch 12: val_loss did not improve from 0.82818
# 92/92 [==============================] - 13s 136ms/step - loss: 0.7126 - accuracy: 0.7153 - val_loss: 0.9589 - val_accuracy: 0.6499 - lr: 0.0010
# Epoch 13/100
# 92/92 [==============================] - ETA: 0s - loss: 0.7087 - accuracy: 0.7210
# Epoch 13: val_loss did not improve from 0.82818
# 92/92 [==============================] - 13s 133ms/step - loss: 0.7087 - accuracy: 0.7210 - val_loss: 1.0761 - val_accuracy: 0.6008 - lr: 0.0010
# Epoch 14/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6947 - accuracy: 0.7234
# Epoch 14: val_loss did not improve from 0.82818
# 92/92 [==============================] - 12s 128ms/step - loss: 0.6947 - accuracy: 0.7234 - val_loss: 1.0519 - val_accuracy: 0.6281 - lr: 0.0010
# Epoch 15/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6785 - accuracy: 0.7214
# Epoch 15: val_loss did not improve from 0.82818
# 92/92 [==============================] - 12s 129ms/step - loss: 0.6785 - accuracy: 0.7214 - val_loss: 0.8675 - val_accuracy: 0.6635 - lr: 0.0010
# Epoch 16/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6812 - accuracy: 0.7289
# Epoch 16: val_loss improved from 0.82818 to 0.78737, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 134ms/step - loss: 0.6812 - accuracy: 0.7289 - val_loss: 0.7874 - val_accuracy: 0.7044 - lr: 0.0010
# Epoch 17/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6609 - accuracy: 0.7384
# Epoch 17: val_loss did not improve from 0.78737
# 92/92 [==============================] - 12s 129ms/step - loss: 0.6609 - accuracy: 0.7384 - val_loss: 0.8757 - val_accuracy: 0.6717 - lr: 0.0010
# Epoch 18/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6425 - accuracy: 0.7500
# Epoch 18: val_loss did not improve from 0.78737
# 92/92 [==============================] - 12s 128ms/step - loss: 0.6425 - accuracy: 0.7500 - val_loss: 0.9451 - val_accuracy: 0.6717 - lr: 0.0010
# Epoch 19/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6321 - accuracy: 0.7609
# Epoch 19: val_loss improved from 0.78737 to 0.72256, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 12s 133ms/step - loss: 0.6321 - accuracy: 0.7609 - val_loss: 0.7226 - val_accuracy: 0.7084 - lr: 0.0010
# Epoch 20/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6248 - accuracy: 0.7463
# Epoch 20: val_loss did not improve from 0.72256
# 92/92 [==============================] - 12s 129ms/step - loss: 0.6248 - accuracy: 0.7463 - val_loss: 1.4369 - val_accuracy: 0.5490 - lr: 0.0010
# Epoch 21/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6151 - accuracy: 0.7544
# Epoch 21: val_loss did not improve from 0.72256
# 92/92 [==============================] - 12s 129ms/step - loss: 0.6151 - accuracy: 0.7544 - val_loss: 0.9655 - val_accuracy: 0.6308 - lr: 0.0010
# Epoch 22/100
# 92/92 [==============================] - ETA: 0s - loss: 0.6070 - accuracy: 0.7606
# Epoch 22: val_loss did not improve from 0.72256
# 92/92 [==============================] - 12s 128ms/step - loss: 0.6070 - accuracy: 0.7606 - val_loss: 0.8310 - val_accuracy: 0.6853 - lr: 0.0010
# Epoch 23/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5922 - accuracy: 0.7612
# Epoch 23: val_loss did not improve from 0.72256
# 92/92 [==============================] - 13s 139ms/step - loss: 0.5922 - accuracy: 0.7612 - val_loss: 0.9407 - val_accuracy: 0.6608 - lr: 0.0010
# Epoch 24/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5890 - accuracy: 0.7650
# Epoch 24: val_loss did not improve from 0.72256
# 92/92 [==============================] - 13s 135ms/step - loss: 0.5890 - accuracy: 0.7650 - val_loss: 0.8518 - val_accuracy: 0.6839 - lr: 0.0010
# Epoch 25/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5531 - accuracy: 0.7786
# Epoch 25: val_loss did not improve from 0.72256
# 92/92 [==============================] - 12s 128ms/step - loss: 0.5531 - accuracy: 0.7786 - val_loss: 0.8613 - val_accuracy: 0.6866 - lr: 0.0010
# Epoch 26/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5775 - accuracy: 0.7790
# Epoch 26: val_loss did not improve from 0.72256
# 92/92 [==============================] - 12s 129ms/step - loss: 0.5775 - accuracy: 0.7790 - val_loss: 0.9460 - val_accuracy: 0.6676 - lr: 0.0010
# Epoch 27/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5627 - accuracy: 0.7793
# Epoch 27: val_loss did not improve from 0.72256
# 92/92 [==============================] - 13s 130ms/step - loss: 0.5627 - accuracy: 0.7793 - val_loss: 0.8256 - val_accuracy: 0.6853 - lr: 0.0010
# Epoch 28/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5475 - accuracy: 0.7933
# Epoch 28: val_loss did not improve from 0.72256
# 92/92 [==============================] - 12s 130ms/step - loss: 0.5475 - accuracy: 0.7933 - val_loss: 0.8213 - val_accuracy: 0.6975 - lr: 0.0010
# Epoch 29/100
# 92/92 [==============================] - ETA: 0s - loss: 0.5350 - accuracy: 0.7827
# Epoch 29: val_loss did not improve from 0.72256
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 92/92 [==============================] - 12s 131ms/step - loss: 0.5350 - accuracy: 0.7827 - val_loss: 0.7895 - val_accuracy: 0.7398 - lr: 0.0010
# Epoch 30/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4721 - accuracy: 0.8120
# Epoch 30: val_loss improved from 0.72256 to 0.62446, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 14s 148ms/step - loss: 0.4721 - accuracy: 0.8120 - val_loss: 0.6245 - val_accuracy: 0.7793 - lr: 1.0000e-04
# Epoch 31/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4369 - accuracy: 0.8266
# Epoch 31: val_loss improved from 0.62446 to 0.60749, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 140ms/step - loss: 0.4369 - accuracy: 0.8266 - val_loss: 0.6075 - val_accuracy: 0.7807 - lr: 1.0000e-04
# Epoch 32/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4286 - accuracy: 0.8358
# Epoch 32: val_loss improved from 0.60749 to 0.58616, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 136ms/step - loss: 0.4286 - accuracy: 0.8358 - val_loss: 0.5862 - val_accuracy: 0.7902 - lr: 1.0000e-04
# Epoch 33/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4337 - accuracy: 0.8341
# Epoch 33: val_loss did not improve from 0.58616
# 92/92 [==============================] - 13s 133ms/step - loss: 0.4337 - accuracy: 0.8341 - val_loss: 0.5913 - val_accuracy: 0.7916 - lr: 1.0000e-04
# Epoch 34/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4155 - accuracy: 0.8403
# Epoch 34: val_loss did not improve from 0.58616
# 92/92 [==============================] - 13s 133ms/step - loss: 0.4155 - accuracy: 0.8403 - val_loss: 0.5916 - val_accuracy: 0.7902 - lr: 1.0000e-04
# Epoch 35/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.8392
# Epoch 35: val_loss did not improve from 0.58616
# 92/92 [==============================] - 13s 137ms/step - loss: 0.4148 - accuracy: 0.8392 - val_loss: 0.5935 - val_accuracy: 0.7793 - lr: 1.0000e-04
# Epoch 36/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4100 - accuracy: 0.8420
# Epoch 36: val_loss did not improve from 0.58616
# 92/92 [==============================] - 13s 138ms/step - loss: 0.4100 - accuracy: 0.8420 - val_loss: 0.6228 - val_accuracy: 0.7698 - lr: 1.0000e-04
# Epoch 37/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4052 - accuracy: 0.8406
# Epoch 37: val_loss did not improve from 0.58616
# 92/92 [==============================] - 13s 136ms/step - loss: 0.4052 - accuracy: 0.8406 - val_loss: 0.6171 - val_accuracy: 0.7766 - lr: 1.0000e-04
# Epoch 38/100
# 92/92 [==============================] - ETA: 0s - loss: 0.4001 - accuracy: 0.8539
# Epoch 38: val_loss did not improve from 0.58616
# 92/92 [==============================] - 13s 133ms/step - loss: 0.4001 - accuracy: 0.8539 - val_loss: 0.6139 - val_accuracy: 0.7738 - lr: 1.0000e-04
# Epoch 39/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3806 - accuracy: 0.8529
# Epoch 39: val_loss improved from 0.58616 to 0.57589, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 14s 151ms/step - loss: 0.3806 - accuracy: 0.8529 - val_loss: 0.5759 - val_accuracy: 0.7820 - lr: 1.0000e-04
# Epoch 40/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3875 - accuracy: 0.8495
# Epoch 40: val_loss did not improve from 0.57589
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3875 - accuracy: 0.8495 - val_loss: 0.6070 - val_accuracy: 0.7725 - lr: 1.0000e-04
# Epoch 41/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3814 - accuracy: 0.8539
# Epoch 41: val_loss did not improve from 0.57589
# 92/92 [==============================] - 13s 134ms/step - loss: 0.3814 - accuracy: 0.8539 - val_loss: 0.6027 - val_accuracy: 0.7847 - lr: 1.0000e-04
# Epoch 42/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3942 - accuracy: 0.8433
# Epoch 42: val_loss did not improve from 0.57589
# 92/92 [==============================] - 13s 136ms/step - loss: 0.3942 - accuracy: 0.8433 - val_loss: 0.5925 - val_accuracy: 0.7943 - lr: 1.0000e-04
# Epoch 43/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3673 - accuracy: 0.8559
# Epoch 43: val_loss did not improve from 0.57589
# 92/92 [==============================] - 13s 137ms/step - loss: 0.3673 - accuracy: 0.8559 - val_loss: 0.6153 - val_accuracy: 0.7779 - lr: 1.0000e-04
# Epoch 44/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3692 - accuracy: 0.8607
# Epoch 44: val_loss did not improve from 0.57589
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3692 - accuracy: 0.8607 - val_loss: 0.6153 - val_accuracy: 0.7766 - lr: 1.0000e-04
# Epoch 45/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3670 - accuracy: 0.8569
# Epoch 45: val_loss did not improve from 0.57589
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3670 - accuracy: 0.8569 - val_loss: 0.5905 - val_accuracy: 0.7888 - lr: 1.0000e-04
# Epoch 46/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3865 - accuracy: 0.8525
# Epoch 46: val_loss did not improve from 0.57589
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3865 - accuracy: 0.8525 - val_loss: 0.5769 - val_accuracy: 0.7902 - lr: 1.0000e-04
# Epoch 47/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3747 - accuracy: 0.8583
# Epoch 47: val_loss did not improve from 0.57589
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3747 - accuracy: 0.8583 - val_loss: 0.5862 - val_accuracy: 0.7875 - lr: 1.0000e-04
# Epoch 48/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3795 - accuracy: 0.8495
# Epoch 48: val_loss did not improve from 0.57589
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3795 - accuracy: 0.8495 - val_loss: 0.5810 - val_accuracy: 0.7861 - lr: 1.0000e-04
# Epoch 49/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3601 - accuracy: 0.8597
# Epoch 49: val_loss did not improve from 0.57589
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3601 - accuracy: 0.8597 - val_loss: 0.6118 - val_accuracy: 0.7793 - lr: 1.0000e-04
# Epoch 50/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3420 - accuracy: 0.8648
# Epoch 50: val_loss did not improve from 0.57589
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3420 - accuracy: 0.8648 - val_loss: 0.5867 - val_accuracy: 0.7834 - lr: 1.0000e-05
# Epoch 51/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3410 - accuracy: 0.8730
# Epoch 51: val_loss improved from 0.57589 to 0.56984, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 133ms/step - loss: 0.3410 - accuracy: 0.8730 - val_loss: 0.5698 - val_accuracy: 0.7861 - lr: 1.0000e-05
# Epoch 52/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3412 - accuracy: 0.8723
# Epoch 52: val_loss did not improve from 0.56984
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3412 - accuracy: 0.8723 - val_loss: 0.5751 - val_accuracy: 0.7807 - lr: 1.0000e-05
# Epoch 53/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3336 - accuracy: 0.8743
# Epoch 53: val_loss did not improve from 0.56984
# 92/92 [==============================] - 12s 131ms/step - loss: 0.3336 - accuracy: 0.8743 - val_loss: 0.5729 - val_accuracy: 0.7847 - lr: 1.0000e-05
# Epoch 54/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3472 - accuracy: 0.8644
# Epoch 54: val_loss did not improve from 0.56984
# 92/92 [==============================] - 12s 130ms/step - loss: 0.3472 - accuracy: 0.8644 - val_loss: 0.5792 - val_accuracy: 0.7834 - lr: 1.0000e-05
# Epoch 55/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3566 - accuracy: 0.8651
# Epoch 55: val_loss improved from 0.56984 to 0.56975, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 134ms/step - loss: 0.3566 - accuracy: 0.8651 - val_loss: 0.5697 - val_accuracy: 0.7875 - lr: 1.0000e-05
# Epoch 56/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3282 - accuracy: 0.8801
# Epoch 56: val_loss did not improve from 0.56975
# 92/92 [==============================] - 14s 144ms/step - loss: 0.3282 - accuracy: 0.8801 - val_loss: 0.5733 - val_accuracy: 0.7875 - lr: 1.0000e-05
# Epoch 57/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3396 - accuracy: 0.8730
# Epoch 57: val_loss did not improve from 0.56975
# 92/92 [==============================] - 12s 131ms/step - loss: 0.3396 - accuracy: 0.8730 - val_loss: 0.5728 - val_accuracy: 0.7888 - lr: 1.0000e-05
# Epoch 58/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3290 - accuracy: 0.8743
# Epoch 58: val_loss did not improve from 0.56975
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3290 - accuracy: 0.8743 - val_loss: 0.5755 - val_accuracy: 0.7847 - lr: 1.0000e-05
# Epoch 59/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3390 - accuracy: 0.8689
# Epoch 59: val_loss improved from 0.56975 to 0.56667, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 133ms/step - loss: 0.3390 - accuracy: 0.8689 - val_loss: 0.5667 - val_accuracy: 0.7888 - lr: 1.0000e-05
# Epoch 60/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3419 - accuracy: 0.8713
# Epoch 60: val_loss improved from 0.56667 to 0.56235, saving model to /content/ckpt/weights_tf
# 92/92 [==============================] - 13s 133ms/step - loss: 0.3419 - accuracy: 0.8713 - val_loss: 0.5623 - val_accuracy: 0.7929 - lr: 1.0000e-05
# Epoch 61/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3268 - accuracy: 0.8723
# Epoch 61: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3268 - accuracy: 0.8723 - val_loss: 0.5767 - val_accuracy: 0.7793 - lr: 1.0000e-05
# Epoch 62/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.8733
# Epoch 62: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3364 - accuracy: 0.8733 - val_loss: 0.5689 - val_accuracy: 0.7875 - lr: 1.0000e-05
# Epoch 63/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3399 - accuracy: 0.8702
# Epoch 63: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3399 - accuracy: 0.8702 - val_loss: 0.5734 - val_accuracy: 0.7888 - lr: 1.0000e-05
# Epoch 64/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3163 - accuracy: 0.8801
# Epoch 64: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3163 - accuracy: 0.8801 - val_loss: 0.5687 - val_accuracy: 0.7875 - lr: 1.0000e-05
# Epoch 65/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3274 - accuracy: 0.8815
# Epoch 65: val_loss did not improve from 0.56235
# 92/92 [==============================] - 13s 133ms/step - loss: 0.3274 - accuracy: 0.8815 - val_loss: 0.5721 - val_accuracy: 0.7929 - lr: 1.0000e-05
# Epoch 66/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.8798
# Epoch 66: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3165 - accuracy: 0.8798 - val_loss: 0.5716 - val_accuracy: 0.7861 - lr: 1.0000e-05
# Epoch 67/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3333 - accuracy: 0.8689
# Epoch 67: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3333 - accuracy: 0.8689 - val_loss: 0.5778 - val_accuracy: 0.7847 - lr: 1.0000e-05
# Epoch 68/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8685
# Epoch 68: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3446 - accuracy: 0.8685 - val_loss: 0.5699 - val_accuracy: 0.7916 - lr: 1.0000e-05
# Epoch 69/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3232 - accuracy: 0.8777
# Epoch 69: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 129ms/step - loss: 0.3232 - accuracy: 0.8777 - val_loss: 0.5740 - val_accuracy: 0.7888 - lr: 1.0000e-05
# Epoch 70/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3230 - accuracy: 0.8757
# Epoch 70: val_loss did not improve from 0.56235
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 92/92 [==============================] - 13s 142ms/step - loss: 0.3230 - accuracy: 0.8757 - val_loss: 0.5838 - val_accuracy: 0.7847 - lr: 1.0000e-05
# Epoch 71/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3195 - accuracy: 0.8794
# Epoch 71: val_loss did not improve from 0.56235
# 92/92 [==============================] - 13s 134ms/step - loss: 0.3195 - accuracy: 0.8794 - val_loss: 0.5784 - val_accuracy: 0.7847 - lr: 1.0000e-06
# Epoch 72/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3298 - accuracy: 0.8726
# Epoch 72: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3298 - accuracy: 0.8726 - val_loss: 0.5776 - val_accuracy: 0.7875 - lr: 1.0000e-06
# Epoch 73/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.8764
# Epoch 73: val_loss did not improve from 0.56235
# 92/92 [==============================] - 12s 128ms/step - loss: 0.3218 - accuracy: 0.8764 - val_loss: 0.5771 - val_accuracy: 0.7888 - lr: 1.0000e-06
# Epoch 74/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.8764
# Epoch 74: val_loss did not improve from 0.56235
# 92/92 [==============================] - 13s 141ms/step - loss: 0.3329 - accuracy: 0.8764 - val_loss: 0.5771 - val_accuracy: 0.7888 - lr: 1.0000e-06
# Epoch 75/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.8784
# Epoch 75: val_loss did not improve from 0.56235
# 92/92 [==============================] - 13s 133ms/step - loss: 0.3207 - accuracy: 0.8784 - val_loss: 0.5788 - val_accuracy: 0.7861 - lr: 1.0000e-06
# Epoch 76/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.8719
# Epoch 76: val_loss did not improve from 0.56235
# 92/92 [==============================] - 13s 136ms/step - loss: 0.3294 - accuracy: 0.8719 - val_loss: 0.5788 - val_accuracy: 0.7875 - lr: 1.0000e-06
# Epoch 77/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3206 - accuracy: 0.8750
# Epoch 77: val_loss did not improve from 0.56235
# 92/92 [==============================] - 13s 136ms/step - loss: 0.3206 - accuracy: 0.8750 - val_loss: 0.5793 - val_accuracy: 0.7847 - lr: 1.0000e-06
# Epoch 78/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3126 - accuracy: 0.8873
# Epoch 78: val_loss did not improve from 0.56235
# 92/92 [==============================] - 13s 142ms/step - loss: 0.3126 - accuracy: 0.8873 - val_loss: 0.5793 - val_accuracy: 0.7861 - lr: 1.0000e-06
# Epoch 79/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3374 - accuracy: 0.8689
# Epoch 79: val_loss did not improve from 0.56235
# 92/92 [==============================] - 13s 142ms/step - loss: 0.3374 - accuracy: 0.8689 - val_loss: 0.5778 - val_accuracy: 0.7875 - lr: 1.0000e-06
# Epoch 80/100
# 92/92 [==============================] - ETA: 0s - loss: 0.3271 - accuracy: 0.8791
# Epoch 80: val_loss did not improve from 0.56235
# Restoring model weights from the end of the best epoch: 60.
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 92/92 [==============================] - 13s 135ms/step - loss: 0.3271 - accuracy: 0.8791 - val_loss: 0.5788 - val_accuracy: 0.7875 - lr: 1.0000e-06
# Epoch 80: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 190, 190, 3)       0
#
#  random_rotation (RandomRot  (None, 190, 190, 3)       0
#  ation)
#
#  conv2d (Conv2D)             (None, 190, 190, 32)      896
#
#  batch_normalization (Batch  (None, 190, 190, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 95, 95, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 95, 95, 32)        0
#
#  activation (Activation)     (None, 95, 95, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 93, 93, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 93, 93, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 46, 46, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 46, 46, 64)        0
#
#  activation_1 (Activation)   (None, 46, 46, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 44, 44, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 44, 44, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 22, 22, 128)       0
#
#  activation_2 (Activation)   (None, 22, 22, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 256)       295168
#
#  batch_normalization_3 (Bat  (None, 20, 20, 256)       1024
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 10, 10, 256)       0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 10, 10, 256)       0
#
#  activation_3 (Activation)   (None, 10, 10, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  batch_normalization_4 (Bat  (None, 8, 8, 512)         2048
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 4, 4, 512)         0
#
#  activation_4 (Activation)   (None, 4, 4, 512)         0
#
#  conv2d_5 (Conv2D)           (None, 2, 2, 1024)        4719616
#
#  batch_normalization_5 (Bat  (None, 2, 2, 1024)        4096
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 2, 2, 1024)        0
#
#  activation_5 (Activation)   (None, 2, 2, 1024)        0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  batch_normalization_6 (Bat  (None, 512)               2048
#  chNormalization)
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dense_1 (Dense)             (None, 64)                32832
#
#  batch_normalization_7 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_7 (Activation)   (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 8429381 (32.16 MB)
# Trainable params: 8424197 (32.14 MB)
# Non-trainable params: 5184 (20.25 KB)
# _________________________________________________________________

# %%
loss_df = pd.DataFrame(history.history)
loss_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy     lr
# 0  1.180228  0.516008  5.457759      0.238420  0.001
# 1  1.016061  0.589237  4.268704      0.238420  0.001
# 2  0.956293  0.616826  3.703937      0.238420  0.001
# 3  0.882144  0.658719  2.482176      0.254768  0.001
# 4  0.851849  0.664169  1.433028      0.459128  0.001

# %%
fn_plot_tf_hist(loss_df)

# %% [markdown]
# |params|img|
# |----|----|
# |base|![image.png](data:image/png;base64,...)|
# |||
# |||
# |||

# %%
layer = tf.keras.layers.RandomRotation((-0.5, 0.5), fill_mode = 'nearest', seed = RANDOM_STATE)
plt.figure()

img_num = 0

for images, labels in train_ds.take(1):

  out_images = layer(images)

  plt.subplot(1,2,1)
  plt.title('Original')
  plt.imshow(images[img_num].numpy().astype('uint16'))
  plt.grid(False)

  plt.subplot(1,2,2)
  plt.title('Rotated')
  plt.imshow(out_images[img_num].numpy().astype('uint16'))
  plt.grid(False)
