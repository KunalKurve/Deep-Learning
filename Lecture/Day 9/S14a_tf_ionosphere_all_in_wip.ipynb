# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [markdown]
# # Deep Neural Networks
# ## Session 14a
#
# ## Sequential Model using ionosphere putting it together
#
# 1. Monitor validation set as well as training set
# 2. L2 Regularization
# 3. Dropouts
# 4. Batch Norm
# 5. Early stopping
#
# <img src='../../prasami_images/prasami_color_tutorials_small.png' style = 'width:400px;' alt="By Pramod Sharma : pramod.sharma@prasami.com" align="left"/>

# %%
# Lets import some libraries
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler, LabelEncoder

import tensorflow as tf

# from utils.helper import fn_plot_tf_hist

# %matplotlib inline

# %%
# Some basic parameters

inpDir = '/home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/input' # location where input data is stored
outDir = '/home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/output' # location to store outputs
modelDir = '/home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models'
subDir = 'ionosphere'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production

np.random.seed(RANDOM_STATE) # Set Random Seed for reproducible  results
 
tf.random.set_seed(RANDOM_STATE) # setting for Tensorflow as well


EPOCHS = 100         # number of epochs
ALPHA = 0.001        # learning rate
WEIGHT_DECAY = 0.001 # Weight decay
BATCH_SIZE = 16      # other sizes leave last batch partial

TRAIN_SIZE = int(BATCH_SIZE*18)

PATIENCE = 20
LR_PATIENCE = 5
LR_FACTOR = 0.1

# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (15,15),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

CMAP = plt.cm.brg

plt.rcParams.update(params) # update rcParams

# %%
###------------------------------------------------
### Plot Loss Curve using Tensorflow history object
###------------------------------------------------
def fn_plot_tf_hist(hist_df):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
        
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)
    facecolor = 'cyan'
    fontsize=12
    CMAP = plt.cm.coolwarm
    
    # Get columns by index to eliminate any column naming error
    y1 = hist_df.columns[0]
    y2 = hist_df.columns[1]
    y3 = hist_df.columns[2]
    y4 = hist_df.columns[3]

    # Where was min loss
    best = hist_df[hist_df[y3] == hist_df[y3].min()]
    
    ax = axes[0]

    hist_df.plot(y = [y1,y3], ax = ax, colormap=CMAP)


    # little beautification
    txtFmt = "Loss: \n  train: {:6.4f}\n   test: {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y1],
                           hist_df.iloc[-1][y3]) #text to plot
    
    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.95, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)
    
    # calculate offset for arroe
    y_min = min(hist_df[y1].min(), hist_df[y3].min())
    y_max = max(hist_df[y1].max(), hist_df[y3].max())
    offset = (y_max-y_min)/10.0
    
    # Mark arrow at lowest
    ax.annotate(f'Min: {best[y3].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y3].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y3].to_numpy()[0] + offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow

    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y1.capitalize())
    ax.set_title('Errors')
    ax.grid();
    ax.legend(loc = 'upper left') # model legend to upper left

    ax = axes[1]

    hist_df.plot( y = [y2, y4], ax = ax, colormap=CMAP)
    
    # little beautification
    txtFmt = "Accuracy: \n  train: {:6.4f}\n  test:  {:6.4f}"
    txtstr = txtFmt.format(hist_df.iloc[-1][y2],
                           hist_df.iloc[-1][y4]) #text to plot

    # place a text box in upper middle in axes coords
    ax.text(0.3, 0.2, txtstr, transform=ax.transAxes, fontsize=fontsize,
            verticalalignment='top', bbox=props)

    # calculate offset for arroe
    y_min = min(hist_df[y2].min(), hist_df[y4].min())
    y_max = max(hist_df[y2].max(), hist_df[y4].max())
    offset = (y_max-y_min)/10.0

    # Mark arrow at lowest
    ax.annotate(f'Best: {best[y4].to_numpy()[0]:6.4f}', # text to print
                xy=(best.index.to_numpy(), best[y4].to_numpy()[0]), # Arrow start
                xytext=(best.index.to_numpy(), best[y4].to_numpy()[0]-offset), # location of text 
                fontsize=fontsize, va='bottom', ha='right',bbox=props, # beautification of text
                arrowprops=dict(facecolor=facecolor, shrink=0.05)) # arrow
    
    
    # Draw vertical line at best value
    ax.axvline(x = best.index.to_numpy(), color = 'green', linestyle='-.', lw = 3);

    ax.set_xlabel("Epochs")
    ax.set_ylabel(y2.capitalize())
    ax.grid()
    ax.legend(loc = 'lower left')
    
    plt.tight_layout()

# %%
physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %% [markdown]
# ## Load Data
#
# ### Data Set Information:
#
# This radar data was collected by a system in Goose Bay, Labrador. This system consists of a phased array of 16 high-frequency antennas with a total transmitted power on the order of 6.4 kilowatts. See the paper for more details. The targets were free electrons in the ionosphere. "Good" radar returns are those showing evidence of some type of structure in the ionosphere. "Bad" returns are those that do not; their signals pass through the ionosphere.
#
# Received signals were processed using an autocorrelation function whose arguments are the time of a pulse and the pulse number. There were 17 pulse numbers for the Goose Bay system. Instances in this database are described by 2 attributes per pulse number, corresponding to the complex values returned by the function resulting from the complex electromagnetic signal.
#
# Attribute Information:
#
# -- All 34 are continuous
# -- The 35th attribute is either "good" or "bad" according to the definition summarized above. This is a binary classification task.
#
# We will model this as two class.

# %%
data_df = pd.read_csv(os.path.join(inpDir, subDir, 'ionosphere.data'), header = None)
data_df.shape
# Out:
# (351, 35)

# %%
data_df.head()
# Out:
#    0   1        2        3        4        5        6        7        8   \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#         9   ...       25       26       27       28       29       30  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#         31       32       33  34
# 0 -0.54487  0.18641 -0.45300   g
# 1 -0.06288 -0.13738 -0.02447   b
# 2 -0.24180  0.56045 -0.38238   g
# 3  1.00000 -0.32382  1.00000   b
# 4 -0.59573 -0.04608 -0.65697   g
#
# [5 rows x 35 columns]

# %%
X = data_df.drop(data_df.columns[-1], axis = 1).to_numpy()

y = data_df[data_df.columns[-1]].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y,
                                                   train_size = TRAIN_SIZE,
                                                   stratify=y,
                                                   random_state=RANDOM_STATE)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((288, 34), (63, 34), (288,), (63,))

# %%
le = LabelEncoder()

y_train = le.fit_transform(y_train)

y_test = le.transform(y_test)

# %%
class_name = list(le.classes_)
class_name
# Out:
# ['b', 'g']

# %%
sc = StandardScaler()

X_train = sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model1 = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( input_shape =(34,)  ),
    
    tf.keras.layers.Dense (26,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dense (18,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer),

   tf.keras.layers.Dense (10,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dense (2),
    
])

# %%
model1.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])

# %%
histroy = model1.fit( x = X_train, 
                     y= y_train,
                    epochs=EPOCHS,
                    batch_size = BATCH_SIZE,
                    validation_data=[X_test, y_test],
                    verbose = 2)
# Out:
# Epoch 1/100
# 18/18 - 1s - loss: 0.5535 - accuracy: 0.7535 - val_loss: 0.5141 - val_accuracy: 0.7619 - 861ms/epoch - 48ms/step
# Epoch 2/100
# 18/18 - 0s - loss: 0.4384 - accuracy: 0.8576 - val_loss: 0.4455 - val_accuracy: 0.8095 - 104ms/epoch - 6ms/step
# Epoch 3/100
# 18/18 - 0s - loss: 0.3698 - accuracy: 0.8750 - val_loss: 0.3882 - val_accuracy: 0.8413 - 64ms/epoch - 4ms/step
# Epoch 4/100
# 18/18 - 0s - loss: 0.3163 - accuracy: 0.8993 - val_loss: 0.3509 - val_accuracy: 0.8413 - 91ms/epoch - 5ms/step
# Epoch 5/100
# 18/18 - 0s - loss: 0.2757 - accuracy: 0.9028 - val_loss: 0.3248 - val_accuracy: 0.8571 - 70ms/epoch - 4ms/step
# Epoch 6/100
# 18/18 - 0s - loss: 0.2423 - accuracy: 0.9201 - val_loss: 0.2995 - val_accuracy: 0.8571 - 75ms/epoch - 4ms/step
# Epoch 7/100
# 18/18 - 0s - loss: 0.2128 - accuracy: 0.9271 - val_loss: 0.2803 - val_accuracy: 0.8571 - 80ms/epoch - 4ms/step
# Epoch 8/100
# 18/18 - 0s - loss: 0.1886 - accuracy: 0.9375 - val_loss: 0.2631 - val_accuracy: 0.8571 - 87ms/epoch - 5ms/step
# Epoch 9/100
# 18/18 - 0s - loss: 0.1678 - accuracy: 0.9444 - val_loss: 0.2572 - val_accuracy: 0.8571 - 62ms/epoch - 3ms/step
# Epoch 10/100
# 18/18 - 0s - loss: 0.1505 - accuracy: 0.9583 - val_loss: 0.2422 - val_accuracy: 0.8730 - 66ms/epoch - 4ms/step
# Epoch 11/100
# 18/18 - 0s - loss: 0.1358 - accuracy: 0.9618 - val_loss: 0.2302 - val_accuracy: 0.8730 - 87ms/epoch - 5ms/step
# Epoch 12/100
# 18/18 - 0s - loss: 0.1231 - accuracy: 0.9653 - val_loss: 0.2244 - val_accuracy: 0.9048 - 80ms/epoch - 4ms/step
# Epoch 13/100
# 18/18 - 0s - loss: 0.1125 - accuracy: 0.9653 - val_loss: 0.2249 - val_accuracy: 0.8889 - 102ms/epoch - 6ms/step
# Epoch 14/100
# 18/18 - 0s - loss: 0.0997 - accuracy: 0.9722 - val_loss: 0.2090 - val_accuracy: 0.9048 - 71ms/epoch - 4ms/step
# Epoch 15/100
# 18/18 - 0s - loss: 0.0929 - accuracy: 0.9757 - val_loss: 0.2077 - val_accuracy: 0.9206 - 80ms/epoch - 4ms/step
# Epoch 16/100
# 18/18 - 0s - loss: 0.0851 - accuracy: 0.9792 - val_loss: 0.2052 - val_accuracy: 0.9365 - 67ms/epoch - 4ms/step
# Epoch 17/100
# 18/18 - 0s - loss: 0.0771 - accuracy: 0.9826 - val_loss: 0.2018 - val_accuracy: 0.9048 - 92ms/epoch - 5ms/step
# Epoch 18/100
# 18/18 - 0s - loss: 0.0704 - accuracy: 0.9826 - val_loss: 0.2068 - val_accuracy: 0.9365 - 63ms/epoch - 4ms/step
# Epoch 19/100
# 18/18 - 0s - loss: 0.0655 - accuracy: 0.9826 - val_loss: 0.1937 - val_accuracy: 0.9365 - 96ms/epoch - 5ms/step
# Epoch 20/100
# 18/18 - 0s - loss: 0.0593 - accuracy: 0.9861 - val_loss: 0.2007 - val_accuracy: 0.9365 - 61ms/epoch - 3ms/step
# Epoch 21/100
# 18/18 - 0s - loss: 0.0552 - accuracy: 0.9861 - val_loss: 0.1991 - val_accuracy: 0.9365 - 100ms/epoch - 6ms/step
# Epoch 22/100
# 18/18 - 0s - loss: 0.0515 - accuracy: 0.9861 - val_loss: 0.2062 - val_accuracy: 0.9365 - 85ms/epoch - 5ms/step
# Epoch 23/100
# 18/18 - 0s - loss: 0.0483 - accuracy: 0.9861 - val_loss: 0.2075 - val_accuracy: 0.9365 - 98ms/epoch - 5ms/step
# Epoch 24/100
# 18/18 - 0s - loss: 0.0446 - accuracy: 0.9861 - val_loss: 0.2121 - val_accuracy: 0.9365 - 73ms/epoch - 4ms/step
# Epoch 25/100
# 18/18 - 0s - loss: 0.0423 - accuracy: 0.9861 - val_loss: 0.2110 - val_accuracy: 0.9365 - 89ms/epoch - 5ms/step
# Epoch 26/100
# 18/18 - 0s - loss: 0.0397 - accuracy: 0.9931 - val_loss: 0.2154 - val_accuracy: 0.9365 - 69ms/epoch - 4ms/step
# Epoch 27/100
# 18/18 - 0s - loss: 0.0375 - accuracy: 0.9931 - val_loss: 0.2189 - val_accuracy: 0.9365 - 64ms/epoch - 4ms/step
# Epoch 28/100
# 18/18 - 0s - loss: 0.0364 - accuracy: 0.9931 - val_loss: 0.2193 - val_accuracy: 0.9365 - 76ms/epoch - 4ms/step
# Epoch 29/100
# 18/18 - 0s - loss: 0.0335 - accuracy: 0.9931 - val_loss: 0.2231 - val_accuracy: 0.9524 - 76ms/epoch - 4ms/step
# Epoch 30/100
# 18/18 - 0s - loss: 0.0313 - accuracy: 0.9931 - val_loss: 0.2300 - val_accuracy: 0.9365 - 103ms/epoch - 6ms/step
# Epoch 31/100
# 18/18 - 0s - loss: 0.0309 - accuracy: 0.9931 - val_loss: 0.2322 - val_accuracy: 0.9365 - 84ms/epoch - 5ms/step
# Epoch 32/100
# 18/18 - 0s - loss: 0.0283 - accuracy: 0.9931 - val_loss: 0.2350 - val_accuracy: 0.9365 - 87ms/epoch - 5ms/step
# Epoch 33/100
# 18/18 - 0s - loss: 0.0277 - accuracy: 0.9931 - val_loss: 0.2392 - val_accuracy: 0.9206 - 68ms/epoch - 4ms/step
# Epoch 34/100
# 18/18 - 0s - loss: 0.0265 - accuracy: 0.9931 - val_loss: 0.2440 - val_accuracy: 0.9206 - 83ms/epoch - 5ms/step
# Epoch 35/100
# 18/18 - 0s - loss: 0.0247 - accuracy: 0.9931 - val_loss: 0.2460 - val_accuracy: 0.9365 - 85ms/epoch - 5ms/step
# Epoch 36/100
# 18/18 - 0s - loss: 0.0239 - accuracy: 0.9931 - val_loss: 0.2568 - val_accuracy: 0.9048 - 92ms/epoch - 5ms/step
# Epoch 37/100
# 18/18 - 0s - loss: 0.0225 - accuracy: 0.9931 - val_loss: 0.2543 - val_accuracy: 0.9365 - 96ms/epoch - 5ms/step
# Epoch 38/100
# 18/18 - 0s - loss: 0.0229 - accuracy: 0.9931 - val_loss: 0.2665 - val_accuracy: 0.9048 - 80ms/epoch - 4ms/step
# Epoch 39/100
# 18/18 - 0s - loss: 0.0218 - accuracy: 0.9931 - val_loss: 0.2669 - val_accuracy: 0.9365 - 81ms/epoch - 5ms/step
# Epoch 40/100
# 18/18 - 0s - loss: 0.0209 - accuracy: 0.9931 - val_loss: 0.2680 - val_accuracy: 0.9048 - 92ms/epoch - 5ms/step
# Epoch 41/100
# 18/18 - 0s - loss: 0.0197 - accuracy: 0.9931 - val_loss: 0.2727 - val_accuracy: 0.9365 - 81ms/epoch - 4ms/step
# Epoch 42/100
# 18/18 - 0s - loss: 0.0186 - accuracy: 0.9931 - val_loss: 0.2857 - val_accuracy: 0.9048 - 67ms/epoch - 4ms/step
# Epoch 43/100
# 18/18 - 0s - loss: 0.0168 - accuracy: 0.9965 - val_loss: 0.2834 - val_accuracy: 0.9206 - 59ms/epoch - 3ms/step
# Epoch 44/100
# 18/18 - 0s - loss: 0.0158 - accuracy: 0.9965 - val_loss: 0.2959 - val_accuracy: 0.9206 - 78ms/epoch - 4ms/step
# Epoch 45/100
# 18/18 - 0s - loss: 0.0165 - accuracy: 0.9931 - val_loss: 0.3011 - val_accuracy: 0.9048 - 73ms/epoch - 4ms/step
# Epoch 46/100
# 18/18 - 0s - loss: 0.0152 - accuracy: 0.9931 - val_loss: 0.3098 - val_accuracy: 0.9206 - 98ms/epoch - 5ms/step
# Epoch 47/100
# 18/18 - 0s - loss: 0.0143 - accuracy: 0.9931 - val_loss: 0.3212 - val_accuracy: 0.9206 - 69ms/epoch - 4ms/step
# Epoch 48/100
# 18/18 - 0s - loss: 0.0141 - accuracy: 0.9965 - val_loss: 0.3192 - val_accuracy: 0.9206 - 102ms/epoch - 6ms/step
# Epoch 49/100
# 18/18 - 0s - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.3434 - val_accuracy: 0.9206 - 88ms/epoch - 5ms/step
# Epoch 50/100
# 18/18 - 0s - loss: 0.0122 - accuracy: 0.9931 - val_loss: 0.3370 - val_accuracy: 0.9206 - 98ms/epoch - 5ms/step
# Epoch 51/100
# 18/18 - 0s - loss: 0.0111 - accuracy: 0.9965 - val_loss: 0.3484 - val_accuracy: 0.9365 - 93ms/epoch - 5ms/step
# Epoch 52/100
# 18/18 - 0s - loss: 0.0106 - accuracy: 0.9965 - val_loss: 0.3678 - val_accuracy: 0.9365 - 80ms/epoch - 4ms/step
# Epoch 53/100
# 18/18 - 0s - loss: 0.0097 - accuracy: 0.9965 - val_loss: 0.3521 - val_accuracy: 0.9365 - 100ms/epoch - 6ms/step
# Epoch 54/100
# 18/18 - 0s - loss: 0.0092 - accuracy: 0.9965 - val_loss: 0.3754 - val_accuracy: 0.9365 - 93ms/epoch - 5ms/step
# Epoch 55/100
# 18/18 - 0s - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.3799 - val_accuracy: 0.9365 - 79ms/epoch - 4ms/step
# Epoch 56/100
# 18/18 - 0s - loss: 0.0075 - accuracy: 0.9965 - val_loss: 0.3889 - val_accuracy: 0.9365 - 68ms/epoch - 4ms/step
# Epoch 57/100
# 18/18 - 0s - loss: 0.0074 - accuracy: 0.9965 - val_loss: 0.3977 - val_accuracy: 0.9365 - 82ms/epoch - 5ms/step
# Epoch 58/100
# 18/18 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.3914 - val_accuracy: 0.9206 - 89ms/epoch - 5ms/step
# Epoch 59/100
# 18/18 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4123 - val_accuracy: 0.9365 - 100ms/epoch - 6ms/step
# Epoch 60/100
# 18/18 - 0s - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.4134 - val_accuracy: 0.9365 - 62ms/epoch - 3ms/step
# Epoch 61/100
# 18/18 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.4232 - val_accuracy: 0.9365 - 91ms/epoch - 5ms/step
# Epoch 62/100
# 18/18 - 0s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.4365 - val_accuracy: 0.9365 - 81ms/epoch - 5ms/step
# Epoch 63/100
# 18/18 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.4311 - val_accuracy: 0.9365 - 67ms/epoch - 4ms/step
# Epoch 64/100
# 18/18 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4312 - val_accuracy: 0.9365 - 78ms/epoch - 4ms/step
# Epoch 65/100
# 18/18 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.4387 - val_accuracy: 0.9365 - 98ms/epoch - 5ms/step
# Epoch 66/100
# 18/18 - 0s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.4460 - val_accuracy: 0.9365 - 80ms/epoch - 4ms/step
# Epoch 67/100
# 18/18 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.4531 - val_accuracy: 0.9365 - 64ms/epoch - 4ms/step
# Epoch 68/100
# 18/18 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4556 - val_accuracy: 0.9365 - 86ms/epoch - 5ms/step
# Epoch 69/100
# 18/18 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.4561 - val_accuracy: 0.9365 - 94ms/epoch - 5ms/step
# Epoch 70/100
# 18/18 - 0s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4682 - val_accuracy: 0.9365 - 85ms/epoch - 5ms/step
# Epoch 71/100
# 18/18 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.4703 - val_accuracy: 0.9365 - 92ms/epoch - 5ms/step
# Epoch 72/100
# 18/18 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.4774 - val_accuracy: 0.9365 - 97ms/epoch - 5ms/step
# Epoch 73/100
# 18/18 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4812 - val_accuracy: 0.9365 - 86ms/epoch - 5ms/step
# Epoch 74/100
# 18/18 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4848 - val_accuracy: 0.9365 - 79ms/epoch - 4ms/step
# Epoch 75/100
# 18/18 - 0s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4997 - val_accuracy: 0.9365 - 86ms/epoch - 5ms/step
# Epoch 76/100
# 18/18 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.4960 - val_accuracy: 0.9365 - 87ms/epoch - 5ms/step
# Epoch 77/100
# 18/18 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5040 - val_accuracy: 0.9365 - 81ms/epoch - 5ms/step
# Epoch 78/100
# 18/18 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5052 - val_accuracy: 0.9365 - 91ms/epoch - 5ms/step
# Epoch 79/100
# 18/18 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5131 - val_accuracy: 0.9365 - 88ms/epoch - 5ms/step
# Epoch 80/100
# 18/18 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5110 - val_accuracy: 0.9365 - 75ms/epoch - 4ms/step
# Epoch 81/100
# 18/18 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5181 - val_accuracy: 0.9365 - 80ms/epoch - 4ms/step
# Epoch 82/100
# 18/18 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5309 - val_accuracy: 0.9365 - 88ms/epoch - 5ms/step
# Epoch 83/100
# 18/18 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5193 - val_accuracy: 0.9365 - 89ms/epoch - 5ms/step
# Epoch 84/100
# 18/18 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5286 - val_accuracy: 0.9365 - 98ms/epoch - 5ms/step
# Epoch 85/100
# 18/18 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5404 - val_accuracy: 0.9365 - 84ms/epoch - 5ms/step
# Epoch 86/100
# 18/18 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5365 - val_accuracy: 0.9365 - 87ms/epoch - 5ms/step
# Epoch 87/100
# 18/18 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5333 - val_accuracy: 0.9365 - 84ms/epoch - 5ms/step
# Epoch 88/100
# 18/18 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5468 - val_accuracy: 0.9365 - 73ms/epoch - 4ms/step
# Epoch 89/100
# 18/18 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.9365 - 89ms/epoch - 5ms/step
# Epoch 90/100
# 18/18 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5547 - val_accuracy: 0.9365 - 100ms/epoch - 6ms/step
# Epoch 91/100
# 18/18 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5589 - val_accuracy: 0.9365 - 104ms/epoch - 6ms/step
# Epoch 92/100
# 18/18 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5578 - val_accuracy: 0.9365 - 98ms/epoch - 5ms/step
# Epoch 93/100
# 18/18 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5659 - val_accuracy: 0.9365 - 96ms/epoch - 5ms/step
# Epoch 94/100
# 18/18 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5697 - val_accuracy: 0.9365 - 90ms/epoch - 5ms/step
# Epoch 95/100
# 18/18 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5643 - val_accuracy: 0.9365 - 91ms/epoch - 5ms/step
# Epoch 96/100
# 18/18 - 0s - loss: 9.2985e-04 - accuracy: 1.0000 - val_loss: 0.5779 - val_accuracy: 0.9365 - 86ms/epoch - 5ms/step
# Epoch 97/100
# 18/18 - 0s - loss: 9.4386e-04 - accuracy: 1.0000 - val_loss: 0.5774 - val_accuracy: 0.9365 - 81ms/epoch - 4ms/step
# Epoch 98/100
# 18/18 - 0s - loss: 8.6849e-04 - accuracy: 1.0000 - val_loss: 0.5753 - val_accuracy: 0.9365 - 96ms/epoch - 5ms/step
# Epoch 99/100
# 18/18 - 0s - loss: 8.5786e-04 - accuracy: 1.0000 - val_loss: 0.5831 - val_accuracy: 0.9365 - 70ms/epoch - 4ms/step
# Epoch 100/100
# 18/18 - 0s - loss: 8.3470e-04 - accuracy: 1.0000 - val_loss: 0.5808 - val_accuracy: 0.9365 - 80ms/epoch - 4ms/step

# %%
model1.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 26)                910
#
#  dense_9 (Dense)             (None, 18)                486
#
#  dense_10 (Dense)            (None, 10)                190
#
#  dense_11 (Dense)            (None, 2)                 22
#
# =================================================================
# Total params: 1608 (6.28 KB)
# Trainable params: 1608 (6.28 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
hist_df = pd.DataFrame(histroy.history)
hist_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.553530  0.753472  0.514139      0.761905
# 1  0.438369  0.857639  0.445451      0.809524
# 2  0.369782  0.875000  0.388246      0.841270
# 3  0.316250  0.899306  0.350870      0.841270
# 4  0.275735  0.902778  0.324768      0.857143

# %%
fn_plot_tf_hist(hist_df)

# %%
hist_df[hist_df['val_loss'] == hist_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 18  0.065481  0.982639  0.193683      0.936508

# %%
proba_model1 = tf.keras.Sequential([model1,
                                   tf.keras.layers.Softmax()])

y_pred = proba_model1(X_test)

# %%
cm = confusion_matrix(y_test, y_pred.numpy().argmax(axis = 1) )

disp = ConfusionMatrixDisplay(confusion_matrix= cm, display_labels=class_name)

fig, ax = plt.subplots(figsize=(5,5))

disp.plot(ax = ax, cmap = plt.cm.Blues);

# %% [markdown]
# ## L2 Regularizer

# %%
## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

regularizer = tf.keras.regularizers.L2(0.05)

model2 = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( input_shape =( 34, ) ),

    tf.keras.layers.Dense (26,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer,
                           kernel_regularizer = regularizer),   # ---- add L2 Regularizer
    
    tf.keras.layers.Dense (18,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer,
                           kernel_regularizer = regularizer),   # ---- add L2 Regularizer

   tf.keras.layers.Dense (10,
                           activation = tf.keras.activations.relu,
                           kernel_initializer = initalizer,
                           kernel_regularizer = regularizer),   # ---- add L2 Regularizer
    
    tf.keras.layers.Dense (2),
    
])

model2.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])


history = model2.fit( x = X_train, 
                     y= y_train,
                    epochs=EPOCHS,
                    batch_size = BATCH_SIZE,
                    validation_data=[X_test, y_test],
                    verbose = 2)

hist_df = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
# 18/18 - 1s - loss: 3.5576 - accuracy: 0.6389 - val_loss: 3.3436 - val_accuracy: 0.6032 - 877ms/epoch - 49ms/step
# Epoch 2/100
# 18/18 - 0s - loss: 3.1579 - accuracy: 0.7500 - val_loss: 2.9779 - val_accuracy: 0.7302 - 81ms/epoch - 4ms/step
# Epoch 3/100
# 18/18 - 0s - loss: 2.8072 - accuracy: 0.8403 - val_loss: 2.6561 - val_accuracy: 0.8095 - 89ms/epoch - 5ms/step
# Epoch 4/100
# 18/18 - 0s - loss: 2.5033 - accuracy: 0.8507 - val_loss: 2.3737 - val_accuracy: 0.8730 - 103ms/epoch - 6ms/step
# Epoch 5/100
# 18/18 - 0s - loss: 2.2361 - accuracy: 0.8611 - val_loss: 2.1266 - val_accuracy: 0.8889 - 90ms/epoch - 5ms/step
# Epoch 6/100
# 18/18 - 0s - loss: 2.0033 - accuracy: 0.8611 - val_loss: 1.9096 - val_accuracy: 0.8730 - 86ms/epoch - 5ms/step
# Epoch 7/100
# 18/18 - 0s - loss: 1.7968 - accuracy: 0.8785 - val_loss: 1.7192 - val_accuracy: 0.8730 - 99ms/epoch - 6ms/step
# Epoch 8/100
# 18/18 - 0s - loss: 1.6151 - accuracy: 0.8819 - val_loss: 1.5506 - val_accuracy: 0.8730 - 80ms/epoch - 4ms/step
# Epoch 9/100
# 18/18 - 0s - loss: 1.4547 - accuracy: 0.8854 - val_loss: 1.4042 - val_accuracy: 0.8730 - 84ms/epoch - 5ms/step
# Epoch 10/100
# 18/18 - 0s - loss: 1.3118 - accuracy: 0.9028 - val_loss: 1.2697 - val_accuracy: 0.8730 - 98ms/epoch - 5ms/step
# Epoch 11/100
# 18/18 - 0s - loss: 1.1790 - accuracy: 0.9062 - val_loss: 1.1542 - val_accuracy: 0.8730 - 80ms/epoch - 4ms/step
# Epoch 12/100
# 18/18 - 0s - loss: 1.0624 - accuracy: 0.9062 - val_loss: 1.0553 - val_accuracy: 0.8889 - 87ms/epoch - 5ms/step
# Epoch 13/100
# 18/18 - 0s - loss: 0.9651 - accuracy: 0.9132 - val_loss: 0.9733 - val_accuracy: 0.8889 - 89ms/epoch - 5ms/step
# Epoch 14/100
# 18/18 - 0s - loss: 0.8799 - accuracy: 0.9236 - val_loss: 0.9010 - val_accuracy: 0.8730 - 94ms/epoch - 5ms/step
# Epoch 15/100
# 18/18 - 0s - loss: 0.8098 - accuracy: 0.9306 - val_loss: 0.8407 - val_accuracy: 0.8889 - 85ms/epoch - 5ms/step
# Epoch 16/100
# 18/18 - 0s - loss: 0.7496 - accuracy: 0.9306 - val_loss: 0.7903 - val_accuracy: 0.8730 - 65ms/epoch - 4ms/step
# Epoch 17/100
# 18/18 - 0s - loss: 0.6973 - accuracy: 0.9340 - val_loss: 0.7425 - val_accuracy: 0.8730 - 72ms/epoch - 4ms/step
# Epoch 18/100
# 18/18 - 0s - loss: 0.6530 - accuracy: 0.9306 - val_loss: 0.7068 - val_accuracy: 0.8730 - 105ms/epoch - 6ms/step
# Epoch 19/100
# 18/18 - 0s - loss: 0.6156 - accuracy: 0.9340 - val_loss: 0.6685 - val_accuracy: 0.8730 - 63ms/epoch - 3ms/step
# Epoch 20/100
# 18/18 - 0s - loss: 0.5793 - accuracy: 0.9340 - val_loss: 0.6414 - val_accuracy: 0.8730 - 68ms/epoch - 4ms/step
# Epoch 21/100
# 18/18 - 0s - loss: 0.5511 - accuracy: 0.9375 - val_loss: 0.6112 - val_accuracy: 0.8730 - 87ms/epoch - 5ms/step
# Epoch 22/100
# 18/18 - 0s - loss: 0.5255 - accuracy: 0.9410 - val_loss: 0.5862 - val_accuracy: 0.8730 - 61ms/epoch - 3ms/step
# Epoch 23/100
# 18/18 - 0s - loss: 0.5016 - accuracy: 0.9375 - val_loss: 0.5640 - val_accuracy: 0.8730 - 64ms/epoch - 4ms/step
# Epoch 24/100
# 18/18 - 0s - loss: 0.4810 - accuracy: 0.9375 - val_loss: 0.5435 - val_accuracy: 0.8730 - 68ms/epoch - 4ms/step
# Epoch 25/100
# 18/18 - 0s - loss: 0.4653 - accuracy: 0.9375 - val_loss: 0.5243 - val_accuracy: 0.8730 - 91ms/epoch - 5ms/step
# Epoch 26/100
# 18/18 - 0s - loss: 0.4515 - accuracy: 0.9375 - val_loss: 0.5102 - val_accuracy: 0.8730 - 91ms/epoch - 5ms/step
# Epoch 27/100
# 18/18 - 0s - loss: 0.4374 - accuracy: 0.9375 - val_loss: 0.4956 - val_accuracy: 0.8730 - 93ms/epoch - 5ms/step
# Epoch 28/100
# 18/18 - 0s - loss: 0.4253 - accuracy: 0.9375 - val_loss: 0.4851 - val_accuracy: 0.8730 - 91ms/epoch - 5ms/step
# Epoch 29/100
# 18/18 - 0s - loss: 0.4167 - accuracy: 0.9375 - val_loss: 0.4749 - val_accuracy: 0.8730 - 100ms/epoch - 6ms/step
# Epoch 30/100
# 18/18 - 0s - loss: 0.4063 - accuracy: 0.9375 - val_loss: 0.4623 - val_accuracy: 0.8730 - 92ms/epoch - 5ms/step
# Epoch 31/100
# 18/18 - 0s - loss: 0.3974 - accuracy: 0.9479 - val_loss: 0.4556 - val_accuracy: 0.8730 - 104ms/epoch - 6ms/step
# Epoch 32/100
# 18/18 - 0s - loss: 0.3928 - accuracy: 0.9479 - val_loss: 0.4486 - val_accuracy: 0.8730 - 85ms/epoch - 5ms/step
# Epoch 33/100
# 18/18 - 0s - loss: 0.3838 - accuracy: 0.9410 - val_loss: 0.4413 - val_accuracy: 0.8730 - 76ms/epoch - 4ms/step
# Epoch 34/100
# 18/18 - 0s - loss: 0.3791 - accuracy: 0.9444 - val_loss: 0.4334 - val_accuracy: 0.8889 - 95ms/epoch - 5ms/step
# Epoch 35/100
# 18/18 - 0s - loss: 0.3752 - accuracy: 0.9479 - val_loss: 0.4252 - val_accuracy: 0.9048 - 84ms/epoch - 5ms/step
# Epoch 36/100
# 18/18 - 0s - loss: 0.3676 - accuracy: 0.9444 - val_loss: 0.4223 - val_accuracy: 0.8730 - 62ms/epoch - 3ms/step
# Epoch 37/100
# 18/18 - 0s - loss: 0.3630 - accuracy: 0.9479 - val_loss: 0.4145 - val_accuracy: 0.9206 - 79ms/epoch - 4ms/step
# Epoch 38/100
# 18/18 - 0s - loss: 0.3604 - accuracy: 0.9514 - val_loss: 0.4154 - val_accuracy: 0.9048 - 77ms/epoch - 4ms/step
# Epoch 39/100
# 18/18 - 0s - loss: 0.3570 - accuracy: 0.9549 - val_loss: 0.4060 - val_accuracy: 0.9048 - 63ms/epoch - 4ms/step
# Epoch 40/100
# 18/18 - 0s - loss: 0.3509 - accuracy: 0.9479 - val_loss: 0.4061 - val_accuracy: 0.9048 - 76ms/epoch - 4ms/step
# Epoch 41/100
# 18/18 - 0s - loss: 0.3490 - accuracy: 0.9479 - val_loss: 0.4016 - val_accuracy: 0.9048 - 69ms/epoch - 4ms/step
# Epoch 42/100
# 18/18 - 0s - loss: 0.3453 - accuracy: 0.9410 - val_loss: 0.3947 - val_accuracy: 0.9048 - 92ms/epoch - 5ms/step
# Epoch 43/100
# 18/18 - 0s - loss: 0.3437 - accuracy: 0.9514 - val_loss: 0.3909 - val_accuracy: 0.9048 - 63ms/epoch - 3ms/step
# Epoch 44/100
# 18/18 - 0s - loss: 0.3404 - accuracy: 0.9479 - val_loss: 0.3855 - val_accuracy: 0.9206 - 99ms/epoch - 6ms/step
# Epoch 45/100
# 18/18 - 0s - loss: 0.3366 - accuracy: 0.9549 - val_loss: 0.3864 - val_accuracy: 0.9048 - 89ms/epoch - 5ms/step
# Epoch 46/100
# 18/18 - 0s - loss: 0.3365 - accuracy: 0.9479 - val_loss: 0.3849 - val_accuracy: 0.9206 - 88ms/epoch - 5ms/step
# Epoch 47/100
# 18/18 - 0s - loss: 0.3364 - accuracy: 0.9410 - val_loss: 0.3805 - val_accuracy: 0.9048 - 100ms/epoch - 6ms/step
# Epoch 48/100
# 18/18 - 0s - loss: 0.3321 - accuracy: 0.9479 - val_loss: 0.3736 - val_accuracy: 0.9206 - 90ms/epoch - 5ms/step
# Epoch 49/100
# 18/18 - 0s - loss: 0.3279 - accuracy: 0.9479 - val_loss: 0.3818 - val_accuracy: 0.9048 - 84ms/epoch - 5ms/step
# Epoch 50/100
# 18/18 - 0s - loss: 0.3260 - accuracy: 0.9479 - val_loss: 0.3746 - val_accuracy: 0.9206 - 89ms/epoch - 5ms/step
# Epoch 51/100
# 18/18 - 0s - loss: 0.3234 - accuracy: 0.9514 - val_loss: 0.3733 - val_accuracy: 0.9206 - 80ms/epoch - 4ms/step
# Epoch 52/100
# 18/18 - 0s - loss: 0.3211 - accuracy: 0.9514 - val_loss: 0.3675 - val_accuracy: 0.9048 - 70ms/epoch - 4ms/step
# Epoch 53/100
# 18/18 - 0s - loss: 0.3220 - accuracy: 0.9549 - val_loss: 0.3681 - val_accuracy: 0.9206 - 77ms/epoch - 4ms/step
# Epoch 54/100
# 18/18 - 0s - loss: 0.3238 - accuracy: 0.9479 - val_loss: 0.3641 - val_accuracy: 0.9206 - 81ms/epoch - 5ms/step
# Epoch 55/100
# 18/18 - 0s - loss: 0.3188 - accuracy: 0.9583 - val_loss: 0.3677 - val_accuracy: 0.9048 - 81ms/epoch - 4ms/step
# Epoch 56/100
# 18/18 - 0s - loss: 0.3147 - accuracy: 0.9549 - val_loss: 0.3620 - val_accuracy: 0.9206 - 73ms/epoch - 4ms/step
# Epoch 57/100
# 18/18 - 0s - loss: 0.3123 - accuracy: 0.9583 - val_loss: 0.3612 - val_accuracy: 0.9206 - 86ms/epoch - 5ms/step
# Epoch 58/100
# 18/18 - 0s - loss: 0.3120 - accuracy: 0.9479 - val_loss: 0.3581 - val_accuracy: 0.9048 - 108ms/epoch - 6ms/step
# Epoch 59/100
# 18/18 - 0s - loss: 0.3105 - accuracy: 0.9549 - val_loss: 0.3537 - val_accuracy: 0.9206 - 92ms/epoch - 5ms/step
# Epoch 60/100
# 18/18 - 0s - loss: 0.3099 - accuracy: 0.9514 - val_loss: 0.3583 - val_accuracy: 0.9048 - 89ms/epoch - 5ms/step
# Epoch 61/100
# 18/18 - 0s - loss: 0.3071 - accuracy: 0.9618 - val_loss: 0.3549 - val_accuracy: 0.9206 - 103ms/epoch - 6ms/step
# Epoch 62/100
# 18/18 - 0s - loss: 0.3093 - accuracy: 0.9479 - val_loss: 0.3523 - val_accuracy: 0.9206 - 97ms/epoch - 5ms/step
# Epoch 63/100
# 18/18 - 0s - loss: 0.3028 - accuracy: 0.9653 - val_loss: 0.3533 - val_accuracy: 0.9048 - 100ms/epoch - 6ms/step
# Epoch 64/100
# 18/18 - 0s - loss: 0.3056 - accuracy: 0.9583 - val_loss: 0.3555 - val_accuracy: 0.9206 - 87ms/epoch - 5ms/step
# Epoch 65/100
# 18/18 - 0s - loss: 0.3029 - accuracy: 0.9653 - val_loss: 0.3514 - val_accuracy: 0.9206 - 82ms/epoch - 5ms/step
# Epoch 66/100
# 18/18 - 0s - loss: 0.2994 - accuracy: 0.9688 - val_loss: 0.3500 - val_accuracy: 0.9206 - 92ms/epoch - 5ms/step
# Epoch 67/100
# 18/18 - 0s - loss: 0.3031 - accuracy: 0.9479 - val_loss: 0.3452 - val_accuracy: 0.9048 - 95ms/epoch - 5ms/step
# Epoch 68/100
# 18/18 - 0s - loss: 0.2988 - accuracy: 0.9653 - val_loss: 0.3444 - val_accuracy: 0.9206 - 95ms/epoch - 5ms/step
# Epoch 69/100
# 18/18 - 0s - loss: 0.2966 - accuracy: 0.9722 - val_loss: 0.3438 - val_accuracy: 0.9206 - 98ms/epoch - 5ms/step
# Epoch 70/100
# 18/18 - 0s - loss: 0.2954 - accuracy: 0.9653 - val_loss: 0.3426 - val_accuracy: 0.9206 - 95ms/epoch - 5ms/step
# Epoch 71/100
# 18/18 - 0s - loss: 0.2943 - accuracy: 0.9583 - val_loss: 0.3392 - val_accuracy: 0.9206 - 94ms/epoch - 5ms/step
# Epoch 72/100
# 18/18 - 0s - loss: 0.2936 - accuracy: 0.9688 - val_loss: 0.3415 - val_accuracy: 0.9206 - 65ms/epoch - 4ms/step
# Epoch 73/100
# 18/18 - 0s - loss: 0.2928 - accuracy: 0.9688 - val_loss: 0.3409 - val_accuracy: 0.9206 - 81ms/epoch - 5ms/step
# Epoch 74/100
# 18/18 - 0s - loss: 0.2927 - accuracy: 0.9653 - val_loss: 0.3369 - val_accuracy: 0.9206 - 77ms/epoch - 4ms/step
# Epoch 75/100
# 18/18 - 0s - loss: 0.2901 - accuracy: 0.9653 - val_loss: 0.3386 - val_accuracy: 0.9206 - 70ms/epoch - 4ms/step
# Epoch 76/100
# 18/18 - 0s - loss: 0.2886 - accuracy: 0.9653 - val_loss: 0.3397 - val_accuracy: 0.9048 - 99ms/epoch - 5ms/step
# Epoch 77/100
# 18/18 - 0s - loss: 0.2870 - accuracy: 0.9688 - val_loss: 0.3393 - val_accuracy: 0.9048 - 74ms/epoch - 4ms/step
# Epoch 78/100
# 18/18 - 0s - loss: 0.2877 - accuracy: 0.9653 - val_loss: 0.3309 - val_accuracy: 0.9206 - 87ms/epoch - 5ms/step
# Epoch 79/100
# 18/18 - 0s - loss: 0.2894 - accuracy: 0.9618 - val_loss: 0.3360 - val_accuracy: 0.9048 - 86ms/epoch - 5ms/step
# Epoch 80/100
# 18/18 - 0s - loss: 0.2854 - accuracy: 0.9688 - val_loss: 0.3316 - val_accuracy: 0.9206 - 112ms/epoch - 6ms/step
# Epoch 81/100
# 18/18 - 0s - loss: 0.2845 - accuracy: 0.9757 - val_loss: 0.3312 - val_accuracy: 0.9206 - 98ms/epoch - 5ms/step
# Epoch 82/100
# 18/18 - 0s - loss: 0.2857 - accuracy: 0.9618 - val_loss: 0.3337 - val_accuracy: 0.9206 - 91ms/epoch - 5ms/step
# Epoch 83/100
# 18/18 - 0s - loss: 0.2863 - accuracy: 0.9722 - val_loss: 0.3338 - val_accuracy: 0.9206 - 89ms/epoch - 5ms/step
# Epoch 84/100
# 18/18 - 0s - loss: 0.2828 - accuracy: 0.9688 - val_loss: 0.3323 - val_accuracy: 0.9206 - 94ms/epoch - 5ms/step
# Epoch 85/100
# 18/18 - 0s - loss: 0.2824 - accuracy: 0.9653 - val_loss: 0.3353 - val_accuracy: 0.9206 - 86ms/epoch - 5ms/step
# Epoch 86/100
# 18/18 - 0s - loss: 0.2801 - accuracy: 0.9688 - val_loss: 0.3275 - val_accuracy: 0.9206 - 84ms/epoch - 5ms/step
# Epoch 87/100
# 18/18 - 0s - loss: 0.2806 - accuracy: 0.9722 - val_loss: 0.3303 - val_accuracy: 0.9206 - 70ms/epoch - 4ms/step
# Epoch 88/100
# 18/18 - 0s - loss: 0.2815 - accuracy: 0.9583 - val_loss: 0.3271 - val_accuracy: 0.9206 - 79ms/epoch - 4ms/step
# Epoch 89/100
# 18/18 - 0s - loss: 0.2787 - accuracy: 0.9757 - val_loss: 0.3247 - val_accuracy: 0.9206 - 61ms/epoch - 3ms/step
# Epoch 90/100
# 18/18 - 0s - loss: 0.2770 - accuracy: 0.9688 - val_loss: 0.3270 - val_accuracy: 0.9206 - 94ms/epoch - 5ms/step
# Epoch 91/100
# 18/18 - 0s - loss: 0.2784 - accuracy: 0.9653 - val_loss: 0.3301 - val_accuracy: 0.9206 - 94ms/epoch - 5ms/step
# Epoch 92/100
# 18/18 - 0s - loss: 0.2736 - accuracy: 0.9757 - val_loss: 0.3231 - val_accuracy: 0.9206 - 92ms/epoch - 5ms/step
# Epoch 93/100
# 18/18 - 0s - loss: 0.2756 - accuracy: 0.9722 - val_loss: 0.3261 - val_accuracy: 0.9206 - 69ms/epoch - 4ms/step
# Epoch 94/100
# 18/18 - 0s - loss: 0.2746 - accuracy: 0.9757 - val_loss: 0.3267 - val_accuracy: 0.9206 - 82ms/epoch - 5ms/step
# Epoch 95/100
# 18/18 - 0s - loss: 0.2742 - accuracy: 0.9688 - val_loss: 0.3219 - val_accuracy: 0.9365 - 99ms/epoch - 5ms/step
# Epoch 96/100
# 18/18 - 0s - loss: 0.2736 - accuracy: 0.9688 - val_loss: 0.3271 - val_accuracy: 0.9206 - 91ms/epoch - 5ms/step
# Epoch 97/100
# 18/18 - 0s - loss: 0.2741 - accuracy: 0.9757 - val_loss: 0.3228 - val_accuracy: 0.9524 - 70ms/epoch - 4ms/step
# Epoch 98/100
# 18/18 - 0s - loss: 0.2710 - accuracy: 0.9618 - val_loss: 0.3205 - val_accuracy: 0.9365 - 84ms/epoch - 5ms/step
# Epoch 99/100
# 18/18 - 0s - loss: 0.2705 - accuracy: 0.9757 - val_loss: 0.3207 - val_accuracy: 0.9206 - 96ms/epoch - 5ms/step
# Epoch 100/100
# 18/18 - 0s - loss: 0.2683 - accuracy: 0.9757 - val_loss: 0.3198 - val_accuracy: 0.9365 - 95ms/epoch - 5ms/step

# %%
fn_plot_tf_hist(hist_df)

# %% [markdown]
# ## Batch Normalization

# %%
## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model3 = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( input_shape =(34,)  ),
    
    tf.keras.layers.Dense (26,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    
    tf.keras.layers.Dense (18,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    tf.keras.layers.Dense (10,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    tf.keras.layers.Dense (2),
    
])


model3.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])


history = model3.fit( x = X_train, 
                     y= y_train,
                    epochs=EPOCHS,
                    batch_size = BATCH_SIZE,
                    validation_data=[X_test, y_test],
                    verbose = 2)

hist_df = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
# 18/18 - 2s - loss: 0.6930 - accuracy: 0.6771 - val_loss: 0.7536 - val_accuracy: 0.6349 - 2s/epoch - 87ms/step
# Epoch 2/100
# 18/18 - 0s - loss: 0.5995 - accuracy: 0.7153 - val_loss: 0.6725 - val_accuracy: 0.7143 - 92ms/epoch - 5ms/step
# Epoch 3/100
# 18/18 - 0s - loss: 0.5440 - accuracy: 0.7535 - val_loss: 0.5984 - val_accuracy: 0.7460 - 95ms/epoch - 5ms/step
# Epoch 4/100
# 18/18 - 0s - loss: 0.4942 - accuracy: 0.7812 - val_loss: 0.5403 - val_accuracy: 0.8095 - 125ms/epoch - 7ms/step
# Epoch 5/100
# 18/18 - 0s - loss: 0.4558 - accuracy: 0.8160 - val_loss: 0.4889 - val_accuracy: 0.8571 - 128ms/epoch - 7ms/step
# Epoch 6/100
# 18/18 - 0s - loss: 0.4030 - accuracy: 0.8403 - val_loss: 0.4343 - val_accuracy: 0.8889 - 113ms/epoch - 6ms/step
# Epoch 7/100
# 18/18 - 0s - loss: 0.3949 - accuracy: 0.8576 - val_loss: 0.3875 - val_accuracy: 0.9206 - 113ms/epoch - 6ms/step
# Epoch 8/100
# 18/18 - 0s - loss: 0.3765 - accuracy: 0.8368 - val_loss: 0.3472 - val_accuracy: 0.9365 - 101ms/epoch - 6ms/step
# Epoch 9/100
# 18/18 - 0s - loss: 0.3276 - accuracy: 0.8854 - val_loss: 0.3145 - val_accuracy: 0.9206 - 103ms/epoch - 6ms/step
# Epoch 10/100
# 18/18 - 0s - loss: 0.3080 - accuracy: 0.8889 - val_loss: 0.2887 - val_accuracy: 0.9206 - 109ms/epoch - 6ms/step
# Epoch 11/100
# 18/18 - 0s - loss: 0.2701 - accuracy: 0.9062 - val_loss: 0.2657 - val_accuracy: 0.9206 - 99ms/epoch - 6ms/step
# Epoch 12/100
# 18/18 - 0s - loss: 0.2655 - accuracy: 0.9062 - val_loss: 0.2377 - val_accuracy: 0.9365 - 103ms/epoch - 6ms/step
# Epoch 13/100
# 18/18 - 0s - loss: 0.2344 - accuracy: 0.9236 - val_loss: 0.2194 - val_accuracy: 0.9365 - 113ms/epoch - 6ms/step
# Epoch 14/100
# 18/18 - 0s - loss: 0.2174 - accuracy: 0.9271 - val_loss: 0.2026 - val_accuracy: 0.9365 - 117ms/epoch - 6ms/step
# Epoch 15/100
# 18/18 - 0s - loss: 0.2235 - accuracy: 0.9132 - val_loss: 0.1876 - val_accuracy: 0.9365 - 106ms/epoch - 6ms/step
# Epoch 16/100
# 18/18 - 0s - loss: 0.2009 - accuracy: 0.9375 - val_loss: 0.1736 - val_accuracy: 0.9206 - 105ms/epoch - 6ms/step
# Epoch 17/100
# 18/18 - 0s - loss: 0.1666 - accuracy: 0.9583 - val_loss: 0.1560 - val_accuracy: 0.9524 - 104ms/epoch - 6ms/step
# Epoch 18/100
# 18/18 - 0s - loss: 0.2249 - accuracy: 0.9236 - val_loss: 0.1455 - val_accuracy: 0.9683 - 107ms/epoch - 6ms/step
# Epoch 19/100
# 18/18 - 0s - loss: 0.1818 - accuracy: 0.9479 - val_loss: 0.1449 - val_accuracy: 0.9524 - 111ms/epoch - 6ms/step
# Epoch 20/100
# 18/18 - 0s - loss: 0.1767 - accuracy: 0.9583 - val_loss: 0.1392 - val_accuracy: 0.9524 - 101ms/epoch - 6ms/step
# Epoch 21/100
# 18/18 - 0s - loss: 0.1503 - accuracy: 0.9688 - val_loss: 0.1259 - val_accuracy: 0.9683 - 113ms/epoch - 6ms/step
# Epoch 22/100
# 18/18 - 0s - loss: 0.1524 - accuracy: 0.9514 - val_loss: 0.1215 - val_accuracy: 0.9683 - 107ms/epoch - 6ms/step
# Epoch 23/100
# 18/18 - 0s - loss: 0.2080 - accuracy: 0.9271 - val_loss: 0.1130 - val_accuracy: 0.9683 - 106ms/epoch - 6ms/step
# Epoch 24/100
# 18/18 - 0s - loss: 0.1336 - accuracy: 0.9549 - val_loss: 0.1129 - val_accuracy: 0.9524 - 106ms/epoch - 6ms/step
# Epoch 25/100
# 18/18 - 0s - loss: 0.1610 - accuracy: 0.9375 - val_loss: 0.1086 - val_accuracy: 0.9683 - 118ms/epoch - 7ms/step
# Epoch 26/100
# 18/18 - 0s - loss: 0.1545 - accuracy: 0.9549 - val_loss: 0.1090 - val_accuracy: 0.9683 - 127ms/epoch - 7ms/step
# Epoch 27/100
# 18/18 - 0s - loss: 0.1273 - accuracy: 0.9653 - val_loss: 0.1068 - val_accuracy: 0.9683 - 110ms/epoch - 6ms/step
# Epoch 28/100
# 18/18 - 0s - loss: 0.1437 - accuracy: 0.9514 - val_loss: 0.1010 - val_accuracy: 0.9841 - 110ms/epoch - 6ms/step
# Epoch 29/100
# 18/18 - 0s - loss: 0.1405 - accuracy: 0.9410 - val_loss: 0.0953 - val_accuracy: 0.9841 - 118ms/epoch - 7ms/step
# Epoch 30/100
# 18/18 - 0s - loss: 0.1349 - accuracy: 0.9375 - val_loss: 0.0914 - val_accuracy: 0.9683 - 114ms/epoch - 6ms/step
# Epoch 31/100
# 18/18 - 0s - loss: 0.1237 - accuracy: 0.9653 - val_loss: 0.0957 - val_accuracy: 0.9683 - 117ms/epoch - 7ms/step
# Epoch 32/100
# 18/18 - 0s - loss: 0.1217 - accuracy: 0.9583 - val_loss: 0.1021 - val_accuracy: 0.9683 - 123ms/epoch - 7ms/step
# Epoch 33/100
# 18/18 - 0s - loss: 0.1127 - accuracy: 0.9688 - val_loss: 0.0949 - val_accuracy: 0.9683 - 110ms/epoch - 6ms/step
# Epoch 34/100
# 18/18 - 0s - loss: 0.1092 - accuracy: 0.9583 - val_loss: 0.0920 - val_accuracy: 0.9683 - 113ms/epoch - 6ms/step
# Epoch 35/100
# 18/18 - 0s - loss: 0.1238 - accuracy: 0.9514 - val_loss: 0.1058 - val_accuracy: 0.9683 - 110ms/epoch - 6ms/step
# Epoch 36/100
# 18/18 - 0s - loss: 0.1139 - accuracy: 0.9583 - val_loss: 0.0963 - val_accuracy: 0.9683 - 109ms/epoch - 6ms/step
# Epoch 37/100
# 18/18 - 0s - loss: 0.1038 - accuracy: 0.9688 - val_loss: 0.0911 - val_accuracy: 0.9841 - 105ms/epoch - 6ms/step
# Epoch 38/100
# 18/18 - 0s - loss: 0.1331 - accuracy: 0.9479 - val_loss: 0.0967 - val_accuracy: 0.9841 - 111ms/epoch - 6ms/step
# Epoch 39/100
# 18/18 - 0s - loss: 0.1190 - accuracy: 0.9618 - val_loss: 0.0951 - val_accuracy: 0.9841 - 112ms/epoch - 6ms/step
# Epoch 40/100
# 18/18 - 0s - loss: 0.1774 - accuracy: 0.9271 - val_loss: 0.0971 - val_accuracy: 0.9524 - 113ms/epoch - 6ms/step
# Epoch 41/100
# 18/18 - 0s - loss: 0.1361 - accuracy: 0.9549 - val_loss: 0.0923 - val_accuracy: 0.9683 - 113ms/epoch - 6ms/step
# Epoch 42/100
# 18/18 - 0s - loss: 0.1291 - accuracy: 0.9444 - val_loss: 0.0835 - val_accuracy: 0.9683 - 119ms/epoch - 7ms/step
# Epoch 43/100
# 18/18 - 0s - loss: 0.1381 - accuracy: 0.9410 - val_loss: 0.0839 - val_accuracy: 0.9683 - 120ms/epoch - 7ms/step
# Epoch 44/100
# 18/18 - 0s - loss: 0.1743 - accuracy: 0.9306 - val_loss: 0.0936 - val_accuracy: 0.9683 - 102ms/epoch - 6ms/step
# Epoch 45/100
# 18/18 - 0s - loss: 0.1114 - accuracy: 0.9514 - val_loss: 0.1086 - val_accuracy: 0.9683 - 102ms/epoch - 6ms/step
# Epoch 46/100
# 18/18 - 0s - loss: 0.0979 - accuracy: 0.9792 - val_loss: 0.1008 - val_accuracy: 0.9683 - 89ms/epoch - 5ms/step
# Epoch 47/100
# 18/18 - 0s - loss: 0.1120 - accuracy: 0.9653 - val_loss: 0.0977 - val_accuracy: 0.9683 - 89ms/epoch - 5ms/step
# Epoch 48/100
# 18/18 - 0s - loss: 0.0909 - accuracy: 0.9757 - val_loss: 0.1049 - val_accuracy: 0.9524 - 111ms/epoch - 6ms/step
# Epoch 49/100
# 18/18 - 0s - loss: 0.0981 - accuracy: 0.9653 - val_loss: 0.0984 - val_accuracy: 0.9524 - 97ms/epoch - 5ms/step
# Epoch 50/100
# 18/18 - 0s - loss: 0.1188 - accuracy: 0.9583 - val_loss: 0.0886 - val_accuracy: 0.9841 - 111ms/epoch - 6ms/step
# Epoch 51/100
# 18/18 - 0s - loss: 0.0924 - accuracy: 0.9618 - val_loss: 0.0869 - val_accuracy: 0.9841 - 106ms/epoch - 6ms/step
# Epoch 52/100
# 18/18 - 0s - loss: 0.0743 - accuracy: 0.9792 - val_loss: 0.0881 - val_accuracy: 0.9841 - 87ms/epoch - 5ms/step
# Epoch 53/100
# 18/18 - 0s - loss: 0.0772 - accuracy: 0.9826 - val_loss: 0.0914 - val_accuracy: 0.9841 - 120ms/epoch - 7ms/step
# Epoch 54/100
# 18/18 - 0s - loss: 0.0582 - accuracy: 0.9861 - val_loss: 0.1059 - val_accuracy: 0.9524 - 115ms/epoch - 6ms/step
# Epoch 55/100
# 18/18 - 0s - loss: 0.0766 - accuracy: 0.9826 - val_loss: 0.1069 - val_accuracy: 0.9683 - 117ms/epoch - 6ms/step
# Epoch 56/100
# 18/18 - 0s - loss: 0.1252 - accuracy: 0.9653 - val_loss: 0.0989 - val_accuracy: 0.9524 - 112ms/epoch - 6ms/step
# Epoch 57/100
# 18/18 - 0s - loss: 0.0608 - accuracy: 0.9861 - val_loss: 0.0903 - val_accuracy: 0.9683 - 107ms/epoch - 6ms/step
# Epoch 58/100
# 18/18 - 0s - loss: 0.0857 - accuracy: 0.9688 - val_loss: 0.1081 - val_accuracy: 0.9524 - 110ms/epoch - 6ms/step
# Epoch 59/100
# 18/18 - 0s - loss: 0.0843 - accuracy: 0.9792 - val_loss: 0.0965 - val_accuracy: 0.9365 - 111ms/epoch - 6ms/step
# Epoch 60/100
# 18/18 - 0s - loss: 0.0742 - accuracy: 0.9688 - val_loss: 0.0935 - val_accuracy: 0.9524 - 119ms/epoch - 7ms/step
# Epoch 61/100
# 18/18 - 0s - loss: 0.1063 - accuracy: 0.9549 - val_loss: 0.0955 - val_accuracy: 0.9524 - 114ms/epoch - 6ms/step
# Epoch 62/100
# 18/18 - 0s - loss: 0.0680 - accuracy: 0.9826 - val_loss: 0.0925 - val_accuracy: 0.9524 - 114ms/epoch - 6ms/step
# Epoch 63/100
# 18/18 - 0s - loss: 0.0668 - accuracy: 0.9792 - val_loss: 0.0855 - val_accuracy: 0.9524 - 112ms/epoch - 6ms/step
# Epoch 64/100
# 18/18 - 0s - loss: 0.0734 - accuracy: 0.9826 - val_loss: 0.0849 - val_accuracy: 0.9683 - 118ms/epoch - 7ms/step
# Epoch 65/100
# 18/18 - 0s - loss: 0.0853 - accuracy: 0.9583 - val_loss: 0.0891 - val_accuracy: 0.9524 - 117ms/epoch - 6ms/step
# Epoch 66/100
# 18/18 - 0s - loss: 0.0865 - accuracy: 0.9722 - val_loss: 0.1089 - val_accuracy: 0.9365 - 111ms/epoch - 6ms/step
# Epoch 67/100
# 18/18 - 0s - loss: 0.0620 - accuracy: 0.9861 - val_loss: 0.1096 - val_accuracy: 0.9524 - 101ms/epoch - 6ms/step
# Epoch 68/100
# 18/18 - 0s - loss: 0.1005 - accuracy: 0.9653 - val_loss: 0.1009 - val_accuracy: 0.9524 - 117ms/epoch - 7ms/step
# Epoch 69/100
# 18/18 - 0s - loss: 0.0766 - accuracy: 0.9826 - val_loss: 0.0876 - val_accuracy: 0.9524 - 125ms/epoch - 7ms/step
# Epoch 70/100
# 18/18 - 0s - loss: 0.0513 - accuracy: 0.9861 - val_loss: 0.0795 - val_accuracy: 0.9524 - 117ms/epoch - 6ms/step
# Epoch 71/100
# 18/18 - 0s - loss: 0.0568 - accuracy: 0.9931 - val_loss: 0.0785 - val_accuracy: 0.9524 - 111ms/epoch - 6ms/step
# Epoch 72/100
# 18/18 - 0s - loss: 0.0769 - accuracy: 0.9792 - val_loss: 0.0725 - val_accuracy: 0.9524 - 113ms/epoch - 6ms/step
# Epoch 73/100
# 18/18 - 0s - loss: 0.0495 - accuracy: 0.9896 - val_loss: 0.0764 - val_accuracy: 0.9524 - 99ms/epoch - 6ms/step
# Epoch 74/100
# 18/18 - 0s - loss: 0.0657 - accuracy: 0.9722 - val_loss: 0.0816 - val_accuracy: 0.9524 - 104ms/epoch - 6ms/step
# Epoch 75/100
# 18/18 - 0s - loss: 0.0581 - accuracy: 0.9826 - val_loss: 0.0845 - val_accuracy: 0.9524 - 72ms/epoch - 4ms/step
# Epoch 76/100
# 18/18 - 0s - loss: 0.0670 - accuracy: 0.9757 - val_loss: 0.0750 - val_accuracy: 0.9524 - 108ms/epoch - 6ms/step
# Epoch 77/100
# 18/18 - 0s - loss: 0.0953 - accuracy: 0.9653 - val_loss: 0.0740 - val_accuracy: 0.9683 - 109ms/epoch - 6ms/step
# Epoch 78/100
# 18/18 - 0s - loss: 0.0668 - accuracy: 0.9792 - val_loss: 0.0729 - val_accuracy: 0.9683 - 120ms/epoch - 7ms/step
# Epoch 79/100
# 18/18 - 0s - loss: 0.0810 - accuracy: 0.9722 - val_loss: 0.0785 - val_accuracy: 0.9683 - 100ms/epoch - 6ms/step
# Epoch 80/100
# 18/18 - 0s - loss: 0.0520 - accuracy: 0.9826 - val_loss: 0.0908 - val_accuracy: 0.9524 - 106ms/epoch - 6ms/step
# Epoch 81/100
# 18/18 - 0s - loss: 0.0699 - accuracy: 0.9757 - val_loss: 0.0986 - val_accuracy: 0.9524 - 105ms/epoch - 6ms/step
# Epoch 82/100
# 18/18 - 0s - loss: 0.1692 - accuracy: 0.9375 - val_loss: 0.0990 - val_accuracy: 0.9524 - 105ms/epoch - 6ms/step
# Epoch 83/100
# 18/18 - 0s - loss: 0.0763 - accuracy: 0.9722 - val_loss: 0.1094 - val_accuracy: 0.9365 - 115ms/epoch - 6ms/step
# Epoch 84/100
# 18/18 - 0s - loss: 0.0599 - accuracy: 0.9826 - val_loss: 0.1089 - val_accuracy: 0.9365 - 116ms/epoch - 6ms/step
# Epoch 85/100
# 18/18 - 0s - loss: 0.0591 - accuracy: 0.9826 - val_loss: 0.1187 - val_accuracy: 0.9365 - 116ms/epoch - 6ms/step
# Epoch 86/100
# 18/18 - 0s - loss: 0.0532 - accuracy: 0.9861 - val_loss: 0.1123 - val_accuracy: 0.9365 - 99ms/epoch - 5ms/step
# Epoch 87/100
# 18/18 - 0s - loss: 0.0893 - accuracy: 0.9688 - val_loss: 0.1059 - val_accuracy: 0.9365 - 112ms/epoch - 6ms/step
# Epoch 88/100
# 18/18 - 0s - loss: 0.0676 - accuracy: 0.9757 - val_loss: 0.1200 - val_accuracy: 0.9365 - 104ms/epoch - 6ms/step
# Epoch 89/100
# 18/18 - 0s - loss: 0.0676 - accuracy: 0.9826 - val_loss: 0.1273 - val_accuracy: 0.9365 - 106ms/epoch - 6ms/step
# Epoch 90/100
# 18/18 - 0s - loss: 0.0783 - accuracy: 0.9757 - val_loss: 0.1169 - val_accuracy: 0.9524 - 98ms/epoch - 5ms/step
# Epoch 91/100
# 18/18 - 0s - loss: 0.0527 - accuracy: 0.9861 - val_loss: 0.0911 - val_accuracy: 0.9524 - 111ms/epoch - 6ms/step
# Epoch 92/100
# 18/18 - 0s - loss: 0.0907 - accuracy: 0.9792 - val_loss: 0.0928 - val_accuracy: 0.9524 - 103ms/epoch - 6ms/step
# Epoch 93/100
# 18/18 - 0s - loss: 0.0564 - accuracy: 0.9861 - val_loss: 0.0946 - val_accuracy: 0.9524 - 97ms/epoch - 5ms/step
# Epoch 94/100
# 18/18 - 0s - loss: 0.0665 - accuracy: 0.9757 - val_loss: 0.0960 - val_accuracy: 0.9365 - 97ms/epoch - 5ms/step
# Epoch 95/100
# 18/18 - 0s - loss: 0.0850 - accuracy: 0.9757 - val_loss: 0.0904 - val_accuracy: 0.9524 - 116ms/epoch - 6ms/step
# Epoch 96/100
# 18/18 - 0s - loss: 0.0885 - accuracy: 0.9722 - val_loss: 0.1109 - val_accuracy: 0.9365 - 106ms/epoch - 6ms/step
# Epoch 97/100
# 18/18 - 0s - loss: 0.0433 - accuracy: 0.9826 - val_loss: 0.1205 - val_accuracy: 0.9206 - 97ms/epoch - 5ms/step
# Epoch 98/100
# 18/18 - 0s - loss: 0.1051 - accuracy: 0.9688 - val_loss: 0.1144 - val_accuracy: 0.9206 - 111ms/epoch - 6ms/step
# Epoch 99/100
# 18/18 - 0s - loss: 0.0664 - accuracy: 0.9792 - val_loss: 0.0947 - val_accuracy: 0.9524 - 123ms/epoch - 7ms/step
# Epoch 100/100
# 18/18 - 0s - loss: 0.0641 - accuracy: 0.9757 - val_loss: 0.0970 - val_accuracy: 0.9524 - 116ms/epoch - 6ms/step

# %%
hist_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   0.693015  0.677083  0.753618      0.634921
# 1   0.599482  0.715278  0.672489      0.714286
# 2   0.544011  0.753472  0.598393      0.746032
# 3   0.494188  0.781250  0.540312      0.809524
# 4   0.455786  0.815972  0.488859      0.857143
# ..       ...       ...       ...           ...
# 95  0.088518  0.972222  0.110888      0.936508
# 96  0.043260  0.982639  0.120520      0.920635
# 97  0.105117  0.968750  0.114372      0.920635
# 98  0.066360  0.979167  0.094652      0.952381
# 99  0.064081  0.975694  0.097019      0.952381
#
# [100 rows x 4 columns]

# %%
fn_plot_tf_hist(hist_df)

# %%
hist_df[hist_df['val_loss'] == hist_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 71  0.076937  0.979167  0.072487      0.952381

# %% [markdown]
# ## DROP OUTS

# %%
rate1 = 0.2
rate2 = 0.3
rate3 = 0.4

## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

model4 = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( input_shape =(34,)  ),
    
    tf.keras.layers.Dense (26,
                           activation = 'relu',
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dropout(rate1 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (18,
                           activation = 'relu',
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dropout(rate2 , seed = RANDOM_STATE),

    tf.keras.layers.Dense (10,
                           activation = 'relu',
                           kernel_initializer = initalizer),
    
    tf.keras.layers.Dropout(rate3 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (2),
    
])


model4.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])


history = model4.fit( x = X_train, 
                     y= y_train,
                    epochs=EPOCHS,
                    batch_size = BATCH_SIZE,
                    validation_data=[X_test, y_test],
                    verbose = 2)

hist_df = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
# 18/18 - 1s - loss: 0.9137 - accuracy: 0.5938 - val_loss: 0.8471 - val_accuracy: 0.6032 - 958ms/epoch - 53ms/step
# Epoch 2/100
# 18/18 - 0s - loss: 0.8140 - accuracy: 0.6007 - val_loss: 0.7504 - val_accuracy: 0.6032 - 86ms/epoch - 5ms/step
# Epoch 3/100
# 18/18 - 0s - loss: 0.6959 - accuracy: 0.6562 - val_loss: 0.6835 - val_accuracy: 0.6190 - 86ms/epoch - 5ms/step
# Epoch 4/100
# 18/18 - 0s - loss: 0.6516 - accuracy: 0.6493 - val_loss: 0.6154 - val_accuracy: 0.6667 - 88ms/epoch - 5ms/step
# Epoch 5/100
# 18/18 - 0s - loss: 0.6533 - accuracy: 0.6771 - val_loss: 0.5693 - val_accuracy: 0.7460 - 98ms/epoch - 5ms/step
# Epoch 6/100
# 18/18 - 0s - loss: 0.5906 - accuracy: 0.7083 - val_loss: 0.5320 - val_accuracy: 0.7460 - 102ms/epoch - 6ms/step
# Epoch 7/100
# 18/18 - 0s - loss: 0.5830 - accuracy: 0.7188 - val_loss: 0.5058 - val_accuracy: 0.7460 - 102ms/epoch - 6ms/step
# Epoch 8/100
# 18/18 - 0s - loss: 0.5296 - accuracy: 0.7500 - val_loss: 0.4898 - val_accuracy: 0.7460 - 91ms/epoch - 5ms/step
# Epoch 9/100
# 18/18 - 0s - loss: 0.5040 - accuracy: 0.7743 - val_loss: 0.4721 - val_accuracy: 0.7460 - 75ms/epoch - 4ms/step
# Epoch 10/100
# 18/18 - 0s - loss: 0.5347 - accuracy: 0.7188 - val_loss: 0.4522 - val_accuracy: 0.7778 - 91ms/epoch - 5ms/step
# Epoch 11/100
# 18/18 - 0s - loss: 0.4924 - accuracy: 0.7674 - val_loss: 0.4324 - val_accuracy: 0.7937 - 92ms/epoch - 5ms/step
# Epoch 12/100
# 18/18 - 0s - loss: 0.4701 - accuracy: 0.8090 - val_loss: 0.4158 - val_accuracy: 0.8413 - 84ms/epoch - 5ms/step
# Epoch 13/100
# 18/18 - 0s - loss: 0.4733 - accuracy: 0.8160 - val_loss: 0.4059 - val_accuracy: 0.8254 - 109ms/epoch - 6ms/step
# Epoch 14/100
# 18/18 - 0s - loss: 0.4420 - accuracy: 0.7951 - val_loss: 0.3957 - val_accuracy: 0.8095 - 108ms/epoch - 6ms/step
# Epoch 15/100
# 18/18 - 0s - loss: 0.4308 - accuracy: 0.8194 - val_loss: 0.3796 - val_accuracy: 0.8095 - 87ms/epoch - 5ms/step
# Epoch 16/100
# 18/18 - 0s - loss: 0.3845 - accuracy: 0.8611 - val_loss: 0.3635 - val_accuracy: 0.8254 - 88ms/epoch - 5ms/step
# Epoch 17/100
# 18/18 - 0s - loss: 0.3980 - accuracy: 0.8333 - val_loss: 0.3534 - val_accuracy: 0.8413 - 94ms/epoch - 5ms/step
# Epoch 18/100
# 18/18 - 0s - loss: 0.3758 - accuracy: 0.8438 - val_loss: 0.3425 - val_accuracy: 0.8413 - 79ms/epoch - 4ms/step
# Epoch 19/100
# 18/18 - 0s - loss: 0.3392 - accuracy: 0.8472 - val_loss: 0.3233 - val_accuracy: 0.8413 - 90ms/epoch - 5ms/step
# Epoch 20/100
# 18/18 - 0s - loss: 0.3533 - accuracy: 0.8542 - val_loss: 0.3158 - val_accuracy: 0.8413 - 76ms/epoch - 4ms/step
# Epoch 21/100
# 18/18 - 0s - loss: 0.3328 - accuracy: 0.8542 - val_loss: 0.3147 - val_accuracy: 0.8413 - 87ms/epoch - 5ms/step
# Epoch 22/100
# 18/18 - 0s - loss: 0.3676 - accuracy: 0.8750 - val_loss: 0.3004 - val_accuracy: 0.8413 - 83ms/epoch - 5ms/step
# Epoch 23/100
# 18/18 - 0s - loss: 0.3223 - accuracy: 0.8750 - val_loss: 0.2844 - val_accuracy: 0.8413 - 108ms/epoch - 6ms/step
# Epoch 24/100
# 18/18 - 0s - loss: 0.3639 - accuracy: 0.8819 - val_loss: 0.2676 - val_accuracy: 0.8571 - 93ms/epoch - 5ms/step
# Epoch 25/100
# 18/18 - 0s - loss: 0.2974 - accuracy: 0.8924 - val_loss: 0.2596 - val_accuracy: 0.8571 - 90ms/epoch - 5ms/step
# Epoch 26/100
# 18/18 - 0s - loss: 0.2792 - accuracy: 0.8889 - val_loss: 0.2548 - val_accuracy: 0.8571 - 87ms/epoch - 5ms/step
# Epoch 27/100
# 18/18 - 0s - loss: 0.2784 - accuracy: 0.8993 - val_loss: 0.2383 - val_accuracy: 0.8571 - 91ms/epoch - 5ms/step
# Epoch 28/100
# 18/18 - 0s - loss: 0.2544 - accuracy: 0.9028 - val_loss: 0.2356 - val_accuracy: 0.8571 - 89ms/epoch - 5ms/step
# Epoch 29/100
# 18/18 - 0s - loss: 0.2681 - accuracy: 0.8958 - val_loss: 0.2415 - val_accuracy: 0.8571 - 95ms/epoch - 5ms/step
# Epoch 30/100
# 18/18 - 0s - loss: 0.2461 - accuracy: 0.9201 - val_loss: 0.2230 - val_accuracy: 0.8730 - 89ms/epoch - 5ms/step
# Epoch 31/100
# 18/18 - 0s - loss: 0.2574 - accuracy: 0.9340 - val_loss: 0.2082 - val_accuracy: 0.8889 - 96ms/epoch - 5ms/step
# Epoch 32/100
# 18/18 - 0s - loss: 0.2521 - accuracy: 0.9028 - val_loss: 0.2111 - val_accuracy: 0.8889 - 84ms/epoch - 5ms/step
# Epoch 33/100
# 18/18 - 0s - loss: 0.2309 - accuracy: 0.9062 - val_loss: 0.2141 - val_accuracy: 0.8730 - 92ms/epoch - 5ms/step
# Epoch 34/100
# 18/18 - 0s - loss: 0.2216 - accuracy: 0.9236 - val_loss: 0.2102 - val_accuracy: 0.8889 - 93ms/epoch - 5ms/step
# Epoch 35/100
# 18/18 - 0s - loss: 0.2129 - accuracy: 0.9375 - val_loss: 0.1935 - val_accuracy: 0.9048 - 92ms/epoch - 5ms/step
# Epoch 36/100
# 18/18 - 0s - loss: 0.2480 - accuracy: 0.9271 - val_loss: 0.1882 - val_accuracy: 0.9048 - 111ms/epoch - 6ms/step
# Epoch 37/100
# 18/18 - 0s - loss: 0.2169 - accuracy: 0.9410 - val_loss: 0.2013 - val_accuracy: 0.9206 - 75ms/epoch - 4ms/step
# Epoch 38/100
# 18/18 - 0s - loss: 0.1601 - accuracy: 0.9375 - val_loss: 0.2132 - val_accuracy: 0.9048 - 94ms/epoch - 5ms/step
# Epoch 39/100
# 18/18 - 0s - loss: 0.2080 - accuracy: 0.9410 - val_loss: 0.1750 - val_accuracy: 0.9524 - 95ms/epoch - 5ms/step
# Epoch 40/100
# 18/18 - 0s - loss: 0.1675 - accuracy: 0.9375 - val_loss: 0.1657 - val_accuracy: 0.9524 - 78ms/epoch - 4ms/step
# Epoch 41/100
# 18/18 - 0s - loss: 0.1668 - accuracy: 0.9583 - val_loss: 0.1538 - val_accuracy: 0.9524 - 87ms/epoch - 5ms/step
# Epoch 42/100
# 18/18 - 0s - loss: 0.1949 - accuracy: 0.9375 - val_loss: 0.1486 - val_accuracy: 0.9683 - 88ms/epoch - 5ms/step
# Epoch 43/100
# 18/18 - 0s - loss: 0.1546 - accuracy: 0.9444 - val_loss: 0.1480 - val_accuracy: 0.9683 - 80ms/epoch - 4ms/step
# Epoch 44/100
# 18/18 - 0s - loss: 0.1615 - accuracy: 0.9549 - val_loss: 0.1485 - val_accuracy: 0.9683 - 84ms/epoch - 5ms/step
# Epoch 45/100
# 18/18 - 0s - loss: 0.1510 - accuracy: 0.9479 - val_loss: 0.1525 - val_accuracy: 0.9683 - 90ms/epoch - 5ms/step
# Epoch 46/100
# 18/18 - 0s - loss: 0.1621 - accuracy: 0.9340 - val_loss: 0.1554 - val_accuracy: 0.9524 - 107ms/epoch - 6ms/step
# Epoch 47/100
# 18/18 - 0s - loss: 0.1762 - accuracy: 0.9410 - val_loss: 0.1459 - val_accuracy: 0.9683 - 101ms/epoch - 6ms/step
# Epoch 48/100
# 18/18 - 0s - loss: 0.1831 - accuracy: 0.9306 - val_loss: 0.1389 - val_accuracy: 0.9524 - 90ms/epoch - 5ms/step
# Epoch 49/100
# 18/18 - 0s - loss: 0.1238 - accuracy: 0.9653 - val_loss: 0.1380 - val_accuracy: 0.9524 - 94ms/epoch - 5ms/step
# Epoch 50/100
# 18/18 - 0s - loss: 0.1339 - accuracy: 0.9618 - val_loss: 0.1418 - val_accuracy: 0.9524 - 71ms/epoch - 4ms/step
# Epoch 51/100
# 18/18 - 0s - loss: 0.1391 - accuracy: 0.9549 - val_loss: 0.1422 - val_accuracy: 0.9365 - 97ms/epoch - 5ms/step
# Epoch 52/100
# 18/18 - 0s - loss: 0.1591 - accuracy: 0.9479 - val_loss: 0.1471 - val_accuracy: 0.9524 - 101ms/epoch - 6ms/step
# Epoch 53/100
# 18/18 - 0s - loss: 0.1314 - accuracy: 0.9583 - val_loss: 0.1383 - val_accuracy: 0.9683 - 104ms/epoch - 6ms/step
# Epoch 54/100
# 18/18 - 0s - loss: 0.1298 - accuracy: 0.9549 - val_loss: 0.1221 - val_accuracy: 0.9683 - 84ms/epoch - 5ms/step
# Epoch 55/100
# 18/18 - 0s - loss: 0.1278 - accuracy: 0.9583 - val_loss: 0.1337 - val_accuracy: 0.9683 - 99ms/epoch - 5ms/step
# Epoch 56/100
# 18/18 - 0s - loss: 0.1525 - accuracy: 0.9653 - val_loss: 0.1341 - val_accuracy: 0.9524 - 84ms/epoch - 5ms/step
# Epoch 57/100
# 18/18 - 0s - loss: 0.1312 - accuracy: 0.9549 - val_loss: 0.1390 - val_accuracy: 0.9524 - 92ms/epoch - 5ms/step
# Epoch 58/100
# 18/18 - 0s - loss: 0.1376 - accuracy: 0.9549 - val_loss: 0.1424 - val_accuracy: 0.9365 - 96ms/epoch - 5ms/step
# Epoch 59/100
# 18/18 - 0s - loss: 0.1498 - accuracy: 0.9583 - val_loss: 0.1481 - val_accuracy: 0.9365 - 99ms/epoch - 6ms/step
# Epoch 60/100
# 18/18 - 0s - loss: 0.1105 - accuracy: 0.9688 - val_loss: 0.1464 - val_accuracy: 0.9524 - 94ms/epoch - 5ms/step
# Epoch 61/100
# 18/18 - 0s - loss: 0.1562 - accuracy: 0.9444 - val_loss: 0.1307 - val_accuracy: 0.9524 - 64ms/epoch - 4ms/step
# Epoch 62/100
# 18/18 - 0s - loss: 0.1165 - accuracy: 0.9618 - val_loss: 0.1305 - val_accuracy: 0.9524 - 67ms/epoch - 4ms/step
# Epoch 63/100
# 18/18 - 0s - loss: 0.1200 - accuracy: 0.9514 - val_loss: 0.1243 - val_accuracy: 0.9524 - 82ms/epoch - 5ms/step
# Epoch 64/100
# 18/18 - 0s - loss: 0.1186 - accuracy: 0.9688 - val_loss: 0.1212 - val_accuracy: 0.9683 - 87ms/epoch - 5ms/step
# Epoch 65/100
# 18/18 - 0s - loss: 0.0890 - accuracy: 0.9722 - val_loss: 0.1115 - val_accuracy: 0.9683 - 87ms/epoch - 5ms/step
# Epoch 66/100
# 18/18 - 0s - loss: 0.1240 - accuracy: 0.9653 - val_loss: 0.1057 - val_accuracy: 0.9683 - 75ms/epoch - 4ms/step
# Epoch 67/100
# 18/18 - 0s - loss: 0.0988 - accuracy: 0.9722 - val_loss: 0.1064 - val_accuracy: 0.9524 - 97ms/epoch - 5ms/step
# Epoch 68/100
# 18/18 - 0s - loss: 0.0985 - accuracy: 0.9792 - val_loss: 0.1063 - val_accuracy: 0.9524 - 78ms/epoch - 4ms/step
# Epoch 69/100
# 18/18 - 0s - loss: 0.0883 - accuracy: 0.9757 - val_loss: 0.1122 - val_accuracy: 0.9524 - 87ms/epoch - 5ms/step
# Epoch 70/100
# 18/18 - 0s - loss: 0.0864 - accuracy: 0.9792 - val_loss: 0.1109 - val_accuracy: 0.9524 - 100ms/epoch - 6ms/step
# Epoch 71/100
# 18/18 - 0s - loss: 0.1100 - accuracy: 0.9688 - val_loss: 0.1109 - val_accuracy: 0.9524 - 85ms/epoch - 5ms/step
# Epoch 72/100
# 18/18 - 0s - loss: 0.1048 - accuracy: 0.9688 - val_loss: 0.1148 - val_accuracy: 0.9524 - 95ms/epoch - 5ms/step
# Epoch 73/100
# 18/18 - 0s - loss: 0.0710 - accuracy: 0.9757 - val_loss: 0.1212 - val_accuracy: 0.9683 - 98ms/epoch - 5ms/step
# Epoch 74/100
# 18/18 - 0s - loss: 0.1072 - accuracy: 0.9618 - val_loss: 0.1184 - val_accuracy: 0.9683 - 81ms/epoch - 4ms/step
# Epoch 75/100
# 18/18 - 0s - loss: 0.0943 - accuracy: 0.9583 - val_loss: 0.1277 - val_accuracy: 0.9683 - 89ms/epoch - 5ms/step
# Epoch 76/100
# 18/18 - 0s - loss: 0.0645 - accuracy: 0.9826 - val_loss: 0.1316 - val_accuracy: 0.9683 - 74ms/epoch - 4ms/step
# Epoch 77/100
# 18/18 - 0s - loss: 0.0833 - accuracy: 0.9688 - val_loss: 0.1354 - val_accuracy: 0.9524 - 89ms/epoch - 5ms/step
# Epoch 78/100
# 18/18 - 0s - loss: 0.0765 - accuracy: 0.9722 - val_loss: 0.1238 - val_accuracy: 0.9524 - 89ms/epoch - 5ms/step
# Epoch 79/100
# 18/18 - 0s - loss: 0.0755 - accuracy: 0.9722 - val_loss: 0.1360 - val_accuracy: 0.9365 - 66ms/epoch - 4ms/step
# Epoch 80/100
# 18/18 - 0s - loss: 0.1110 - accuracy: 0.9653 - val_loss: 0.1478 - val_accuracy: 0.9365 - 87ms/epoch - 5ms/step
# Epoch 81/100
# 18/18 - 0s - loss: 0.0891 - accuracy: 0.9618 - val_loss: 0.1420 - val_accuracy: 0.9524 - 67ms/epoch - 4ms/step
# Epoch 82/100
# 18/18 - 0s - loss: 0.0835 - accuracy: 0.9757 - val_loss: 0.1570 - val_accuracy: 0.9365 - 82ms/epoch - 5ms/step
# Epoch 83/100
# 18/18 - 0s - loss: 0.0603 - accuracy: 0.9826 - val_loss: 0.1381 - val_accuracy: 0.9365 - 95ms/epoch - 5ms/step
# Epoch 84/100
# 18/18 - 0s - loss: 0.0780 - accuracy: 0.9826 - val_loss: 0.1359 - val_accuracy: 0.9365 - 92ms/epoch - 5ms/step
# Epoch 85/100
# 18/18 - 0s - loss: 0.1005 - accuracy: 0.9688 - val_loss: 0.1123 - val_accuracy: 0.9524 - 91ms/epoch - 5ms/step
# Epoch 86/100
# 18/18 - 0s - loss: 0.0607 - accuracy: 0.9826 - val_loss: 0.1190 - val_accuracy: 0.9524 - 91ms/epoch - 5ms/step
# Epoch 87/100
# 18/18 - 0s - loss: 0.1027 - accuracy: 0.9688 - val_loss: 0.1308 - val_accuracy: 0.9524 - 101ms/epoch - 6ms/step
# Epoch 88/100
# 18/18 - 0s - loss: 0.0630 - accuracy: 0.9757 - val_loss: 0.1059 - val_accuracy: 0.9683 - 88ms/epoch - 5ms/step
# Epoch 89/100
# 18/18 - 0s - loss: 0.1289 - accuracy: 0.9514 - val_loss: 0.0998 - val_accuracy: 0.9841 - 95ms/epoch - 5ms/step
# Epoch 90/100
# 18/18 - 0s - loss: 0.0609 - accuracy: 0.9861 - val_loss: 0.1067 - val_accuracy: 0.9683 - 87ms/epoch - 5ms/step
# Epoch 91/100
# 18/18 - 0s - loss: 0.0821 - accuracy: 0.9722 - val_loss: 0.1188 - val_accuracy: 0.9524 - 95ms/epoch - 5ms/step
# Epoch 92/100
# 18/18 - 0s - loss: 0.0613 - accuracy: 0.9896 - val_loss: 0.1038 - val_accuracy: 0.9683 - 74ms/epoch - 4ms/step
# Epoch 93/100
# 18/18 - 0s - loss: 0.0739 - accuracy: 0.9688 - val_loss: 0.0955 - val_accuracy: 0.9683 - 97ms/epoch - 5ms/step
# Epoch 94/100
# 18/18 - 0s - loss: 0.0664 - accuracy: 0.9792 - val_loss: 0.0910 - val_accuracy: 0.9841 - 92ms/epoch - 5ms/step
# Epoch 95/100
# 18/18 - 0s - loss: 0.0674 - accuracy: 0.9757 - val_loss: 0.0826 - val_accuracy: 0.9841 - 75ms/epoch - 4ms/step
# Epoch 96/100
# 18/18 - 0s - loss: 0.0842 - accuracy: 0.9757 - val_loss: 0.0765 - val_accuracy: 0.9841 - 83ms/epoch - 5ms/step
# Epoch 97/100
# 18/18 - 0s - loss: 0.0722 - accuracy: 0.9792 - val_loss: 0.0760 - val_accuracy: 0.9841 - 90ms/epoch - 5ms/step
# Epoch 98/100
# 18/18 - 0s - loss: 0.0667 - accuracy: 0.9757 - val_loss: 0.0779 - val_accuracy: 0.9841 - 92ms/epoch - 5ms/step
# Epoch 99/100
# 18/18 - 0s - loss: 0.0590 - accuracy: 0.9826 - val_loss: 0.0749 - val_accuracy: 0.9841 - 85ms/epoch - 5ms/step
# Epoch 100/100
# 18/18 - 0s - loss: 0.0605 - accuracy: 0.9792 - val_loss: 0.0759 - val_accuracy: 0.9841 - 99ms/epoch - 5ms/step

# %%
fn_plot_tf_hist(hist_df)

# %%
hist_df[hist_df['val_loss'] == hist_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 98  0.058999  0.982639  0.074865      0.984127

# %% [markdown]
# ### All In

# %%
rate1 = 0.05
rate2 = 0.05
rate3 = 0.05

## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.AdamW(learning_rate=ALPHA, weight_decay=WEIGHT_DECAY) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

# Suppressing regularization
#regularizer = tf.keras.regularizers.L2(0.05)
regularizer = None

model = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( input_shape =(34,)  ),
    
    tf.keras.layers.Dense (26,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    #tf.keras.layers.Dropout(rate1 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (18,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    #tf.keras.layers.Dropout(rate2 , seed = RANDOM_STATE),

    tf.keras.layers.Dense (10,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    #tf.keras.layers.Dropout(rate3 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (2),
    
])

model.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])

# %%
checkpoint_filepath = os.path.join(modelDir, subDir, 'weights_all_in')

chkpt_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor = 'val_loss',
    mode = 'auto',
    verbose = 2,
    save_best_only = True
)

es_callback = tf.keras.callbacks.EarlyStopping(
    monitor = 'val_loss',
    patience=PATIENCE,
    mode='auto',
    verbose = 2,
    baseline =None,
    restore_best_weights=True)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=LR_FACTOR,
    patience=LR_PATIENCE,
    verbose=2,
    mode='auto',
    min_lr=0.00001)

# %%
history = model.fit( x = X_train, 
                     y = y_train,
                    epochs = EPOCHS,
                    batch_size = BATCH_SIZE,
                    validation_data=[X_test, y_test],
                    verbose = 2,
                    callbacks = [es_callback, chkpt_callback, lr_callback])

hist_df = pd.DataFrame(history.history)
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.62097, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 2s - loss: 0.7070 - accuracy: 0.6146 - val_loss: 0.6210 - val_accuracy: 0.5714 - lr: 0.0010 - 2s/epoch - 108ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.62097 to 0.52728, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.5318 - accuracy: 0.7465 - val_loss: 0.5273 - val_accuracy: 0.9048 - lr: 0.0010 - 119ms/epoch - 7ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.52728 to 0.45321, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.4396 - accuracy: 0.8507 - val_loss: 0.4532 - val_accuracy: 0.9365 - lr: 0.0010 - 135ms/epoch - 7ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.45321 to 0.39311, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.3843 - accuracy: 0.8611 - val_loss: 0.3931 - val_accuracy: 0.9206 - lr: 0.0010 - 136ms/epoch - 8ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.39311 to 0.35193, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.3709 - accuracy: 0.8611 - val_loss: 0.3519 - val_accuracy: 0.9206 - lr: 0.0010 - 131ms/epoch - 7ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.35193 to 0.31450, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.3368 - accuracy: 0.8889 - val_loss: 0.3145 - val_accuracy: 0.9206 - lr: 0.0010 - 139ms/epoch - 8ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.31450 to 0.28689, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.3263 - accuracy: 0.8819 - val_loss: 0.2869 - val_accuracy: 0.9365 - lr: 0.0010 - 142ms/epoch - 8ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.28689 to 0.26395, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.3228 - accuracy: 0.8889 - val_loss: 0.2640 - val_accuracy: 0.9365 - lr: 0.0010 - 142ms/epoch - 8ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.26395 to 0.24352, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.2764 - accuracy: 0.9028 - val_loss: 0.2435 - val_accuracy: 0.9365 - lr: 0.0010 - 132ms/epoch - 7ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.24352 to 0.22569, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.2581 - accuracy: 0.9167 - val_loss: 0.2257 - val_accuracy: 0.9365 - lr: 0.0010 - 114ms/epoch - 6ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.22569 to 0.20846, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.2268 - accuracy: 0.9375 - val_loss: 0.2085 - val_accuracy: 0.9365 - lr: 0.0010 - 118ms/epoch - 7ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.20846 to 0.19318, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.2386 - accuracy: 0.9028 - val_loss: 0.1932 - val_accuracy: 0.9524 - lr: 0.0010 - 120ms/epoch - 7ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.19318 to 0.17978, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1985 - accuracy: 0.9375 - val_loss: 0.1798 - val_accuracy: 0.9524 - lr: 0.0010 - 115ms/epoch - 6ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.17978 to 0.16619, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1875 - accuracy: 0.9410 - val_loss: 0.1662 - val_accuracy: 0.9365 - lr: 0.0010 - 131ms/epoch - 7ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.16619 to 0.15830, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.2022 - accuracy: 0.9167 - val_loss: 0.1583 - val_accuracy: 0.9841 - lr: 0.0010 - 150ms/epoch - 8ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.15830 to 0.14694, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1901 - accuracy: 0.9410 - val_loss: 0.1469 - val_accuracy: 0.9841 - lr: 0.0010 - 161ms/epoch - 9ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.14694 to 0.13821, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1593 - accuracy: 0.9514 - val_loss: 0.1382 - val_accuracy: 0.9683 - lr: 0.0010 - 161ms/epoch - 9ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.13821 to 0.12702, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1995 - accuracy: 0.9340 - val_loss: 0.1270 - val_accuracy: 0.9683 - lr: 0.0010 - 109ms/epoch - 6ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.12702 to 0.11911, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1663 - accuracy: 0.9583 - val_loss: 0.1191 - val_accuracy: 1.0000 - lr: 0.0010 - 157ms/epoch - 9ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.11911 to 0.11343, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1566 - accuracy: 0.9549 - val_loss: 0.1134 - val_accuracy: 1.0000 - lr: 0.0010 - 165ms/epoch - 9ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.11343 to 0.10606, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1434 - accuracy: 0.9583 - val_loss: 0.1061 - val_accuracy: 1.0000 - lr: 0.0010 - 167ms/epoch - 9ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.10606 to 0.10139, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1263 - accuracy: 0.9688 - val_loss: 0.1014 - val_accuracy: 1.0000 - lr: 0.0010 - 142ms/epoch - 8ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.10139 to 0.09820, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1983 - accuracy: 0.9306 - val_loss: 0.0982 - val_accuracy: 0.9841 - lr: 0.0010 - 147ms/epoch - 8ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.09820 to 0.09440, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1330 - accuracy: 0.9722 - val_loss: 0.0944 - val_accuracy: 1.0000 - lr: 0.0010 - 142ms/epoch - 8ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.09440 to 0.09087, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1531 - accuracy: 0.9514 - val_loss: 0.0909 - val_accuracy: 1.0000 - lr: 0.0010 - 134ms/epoch - 7ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.09087 to 0.09065, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1453 - accuracy: 0.9479 - val_loss: 0.0906 - val_accuracy: 1.0000 - lr: 0.0010 - 136ms/epoch - 8ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.09065
# 18/18 - 0s - loss: 0.1106 - accuracy: 0.9653 - val_loss: 0.0907 - val_accuracy: 1.0000 - lr: 0.0010 - 109ms/epoch - 6ms/step
# Epoch 28/100
#
# Epoch 28: val_loss improved from 0.09065 to 0.08865, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1395 - accuracy: 0.9583 - val_loss: 0.0886 - val_accuracy: 1.0000 - lr: 0.0010 - 159ms/epoch - 9ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.08865 to 0.08043, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1348 - accuracy: 0.9410 - val_loss: 0.0804 - val_accuracy: 1.0000 - lr: 0.0010 - 144ms/epoch - 8ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.08043 to 0.07599, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1596 - accuracy: 0.9340 - val_loss: 0.0760 - val_accuracy: 1.0000 - lr: 0.0010 - 134ms/epoch - 7ms/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.07599 to 0.07271, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1304 - accuracy: 0.9514 - val_loss: 0.0727 - val_accuracy: 1.0000 - lr: 0.0010 - 164ms/epoch - 9ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.07271 to 0.07119, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1035 - accuracy: 0.9653 - val_loss: 0.0712 - val_accuracy: 1.0000 - lr: 0.0010 - 131ms/epoch - 7ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.07119
# 18/18 - 0s - loss: 0.1195 - accuracy: 0.9618 - val_loss: 0.0743 - val_accuracy: 1.0000 - lr: 0.0010 - 107ms/epoch - 6ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.07119
# 18/18 - 0s - loss: 0.1050 - accuracy: 0.9688 - val_loss: 0.0738 - val_accuracy: 1.0000 - lr: 0.0010 - 104ms/epoch - 6ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.07119
# 18/18 - 0s - loss: 0.1099 - accuracy: 0.9583 - val_loss: 0.0729 - val_accuracy: 1.0000 - lr: 0.0010 - 97ms/epoch - 5ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.07119 to 0.07025, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1251 - accuracy: 0.9653 - val_loss: 0.0703 - val_accuracy: 1.0000 - lr: 0.0010 - 137ms/epoch - 8ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.07025 to 0.06512, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1053 - accuracy: 0.9653 - val_loss: 0.0651 - val_accuracy: 1.0000 - lr: 0.0010 - 164ms/epoch - 9ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.06512
# 18/18 - 0s - loss: 0.1339 - accuracy: 0.9410 - val_loss: 0.0661 - val_accuracy: 1.0000 - lr: 0.0010 - 120ms/epoch - 7ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.06512
# 18/18 - 0s - loss: 0.1460 - accuracy: 0.9549 - val_loss: 0.0726 - val_accuracy: 0.9683 - lr: 0.0010 - 104ms/epoch - 6ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.06512
# 18/18 - 0s - loss: 0.1948 - accuracy: 0.9201 - val_loss: 0.0712 - val_accuracy: 0.9841 - lr: 0.0010 - 109ms/epoch - 6ms/step
# Epoch 41/100
#
# Epoch 41: val_loss improved from 0.06512 to 0.06497, saving model to /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/weights_all_in
# 18/18 - 0s - loss: 0.1238 - accuracy: 0.9618 - val_loss: 0.0650 - val_accuracy: 0.9841 - lr: 0.0010 - 149ms/epoch - 8ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.1400 - accuracy: 0.9514 - val_loss: 0.0710 - val_accuracy: 0.9841 - lr: 0.0010 - 104ms/epoch - 6ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.1108 - accuracy: 0.9653 - val_loss: 0.0731 - val_accuracy: 0.9683 - lr: 0.0010 - 114ms/epoch - 6ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.1787 - accuracy: 0.9271 - val_loss: 0.0661 - val_accuracy: 0.9841 - lr: 0.0010 - 114ms/epoch - 6ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.1110 - accuracy: 0.9583 - val_loss: 0.0678 - val_accuracy: 0.9841 - lr: 0.0010 - 113ms/epoch - 6ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.06497
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 18/18 - 0s - loss: 0.0993 - accuracy: 0.9618 - val_loss: 0.0702 - val_accuracy: 0.9841 - lr: 0.0010 - 114ms/epoch - 6ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.1011 - accuracy: 0.9653 - val_loss: 0.0699 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 119ms/epoch - 7ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.1012 - accuracy: 0.9688 - val_loss: 0.0701 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 121ms/epoch - 7ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.0954 - accuracy: 0.9688 - val_loss: 0.0693 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 115ms/epoch - 6ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.1335 - accuracy: 0.9583 - val_loss: 0.0696 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 124ms/epoch - 7ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.06497
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 18/18 - 0s - loss: 0.0908 - accuracy: 0.9722 - val_loss: 0.0706 - val_accuracy: 1.0000 - lr: 1.0000e-04 - 114ms/epoch - 6ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.0701 - accuracy: 0.9792 - val_loss: 0.0712 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 127ms/epoch - 7ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.0922 - accuracy: 0.9722 - val_loss: 0.0715 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 119ms/epoch - 7ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.0692 - accuracy: 0.9792 - val_loss: 0.0712 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 113ms/epoch - 6ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.0949 - accuracy: 0.9653 - val_loss: 0.0716 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 121ms/epoch - 7ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.06497
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1e-05.
# 18/18 - 0s - loss: 0.1161 - accuracy: 0.9618 - val_loss: 0.0717 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 118ms/epoch - 7ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.0750 - accuracy: 0.9826 - val_loss: 0.0723 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 125ms/epoch - 7ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.1065 - accuracy: 0.9688 - val_loss: 0.0714 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 110ms/epoch - 6ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.0914 - accuracy: 0.9826 - val_loss: 0.0712 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 131ms/epoch - 7ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.0750 - accuracy: 0.9722 - val_loss: 0.0715 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 117ms/epoch - 6ms/step
# Epoch 61/100
# Restoring model weights from the end of the best epoch: 41.
#
# Epoch 61: val_loss did not improve from 0.06497
# 18/18 - 0s - loss: 0.1229 - accuracy: 0.9618 - val_loss: 0.0714 - val_accuracy: 1.0000 - lr: 1.0000e-05 - 149ms/epoch - 8ms/step
# Epoch 61: early stopping

# %%
fn_plot_tf_hist(hist_df)

# %%
loss_dict = model.evaluate(X_test, y_test, verbose=1 , return_dict=True)
# Out:
# 2/2 [==============================] - 0s 5ms/step - loss: 0.0650 - accuracy: 0.9841

# %%
loss_dict
# Out:
# {'loss': 0.06497281789779663, 'accuracy': 0.9841269850730896}

# %%
hist_df[hist_df['val_loss'] == hist_df['val_loss'].min()]
# Out:
#         loss  accuracy  val_loss  val_accuracy     lr
# 40  0.123781  0.961806  0.064973      0.984127  0.001

# %%
del model
del model1
del model2
del model3
del model4

# %%
## Some model functions

initalizer = tf.keras.initializers.GlorotUniform(seed = RANDOM_STATE)

optimizer = tf.keras.optimizers.Adam(learning_rate=ALPHA) # using Adam optimizer

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits = True)

rate = 0.2

model = tf.keras.models.Sequential([
    
    tf.keras.layers.InputLayer( input_shape =(34,)  ),
    
    tf.keras.layers.Dense (26,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    #tf.keras.layers.Dropout(rate1 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (18,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    #tf.keras.layers.Dropout(rate2 , seed = RANDOM_STATE),

    tf.keras.layers.Dense (10,
                           kernel_initializer = initalizer),
    
    tf.keras.layers.BatchNormalization(),
    
    tf.keras.layers.Activation(activation='relu'),

    #tf.keras.layers.Dropout(rate3 , seed = RANDOM_STATE),
    
    tf.keras.layers.Dense (2),
    
])

model.compile(optimizer=optimizer,
               loss = loss_fn,
               metrics= ['accuracy'])

# %%
res = model.evaluate(X_test, y_test, verbose=2, return_dict=True)

res['accuracy']
# Out:
# 2/2 - 0s - loss: 0.8734 - accuracy: 0.3651 - 260ms/epoch - 130ms/step
# 0.3650793731212616

# %%
model.load_weights(checkpoint_filepath)

# %%
res = model.evaluate(X_test, y_test, verbose=2, return_dict=True)

res['accuracy']
# Out:
# 2/2 - 0s - loss: 0.0650 - accuracy: 0.9841 - 25ms/epoch - 13ms/step
# 0.9841269850730896

# %% [markdown]
# ## Save Complete Model

# %%
model_path = os.path.join(modelDir, subDir, 'complete_all_in')

tf.keras.models.save_model(model, model_path)
# Out:
# INFO:tensorflow:Assets written to: /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/complete_all_in/assets
# INFO:tensorflow:Assets written to: /home/pgdai/Desktop/March24-DAI-Workspace/DNN-May24/LectureStuff/Day9/models/ionosphere/complete_all_in/assets

# %%
model1 = tf.keras.models.load_model(model_path)

# %%
res = model1.evaluate(X_test, y_test, verbose=2, return_dict=True)

res['accuracy']
# Out:
# 2/2 - 0s - loss: 0.0650 - accuracy: 0.9841 - 162ms/epoch - 81ms/step
# 0.9841269850730896

# %%
model1.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 26)                910
#
#  batch_normalization_9 (Bat  (None, 26)                104
#  chNormalization)
#
#  activation_9 (Activation)   (None, 26)                0
#
#  dense_29 (Dense)            (None, 18)                486
#
#  batch_normalization_10 (Ba  (None, 18)                72
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 18)                0
#
#  dense_30 (Dense)            (None, 10)                190
#
#  batch_normalization_11 (Ba  (None, 10)                40
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 10)                0
#
#  dense_31 (Dense)            (None, 2)                 22
#
# =================================================================
# Total params: 1824 (7.12 KB)
# Trainable params: 1716 (6.70 KB)
# Non-trainable params: 108 (432.00 Byte)
# _________________________________________________________________
